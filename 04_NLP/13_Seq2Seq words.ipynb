# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import torch
from tqdm.auto import tqdm
import random
import os

def reset_seeds(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

#DATA_PATH = "/content/drive/MyDrive/04_nlp/data/"
DATA_PATH = os.getcwd()
SEED = 42

device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %% [markdown]
# # 번역: 한국어 -> 영어

# %%
train = pd.read_csv(f"{DATA_PATH}/data/en2ko/translate_en_ko.csv")
train.shape
# Out:
# (5794, 2)

# %% [markdown]
# # 텍스트 정제

# %%
train["ko"] = train["ko"].str.replace("[^가-힣 0-9,.!?\"\']","", regex=True)
train["en"] = train["en"].str.replace("[^a-zA-Z 0-9,.!?\"\']","", regex=True).str.lower()

# %%
# !pip install kiwipiepy
# Out:
# Requirement already satisfied: kiwipiepy in c:\users\hopio\anaconda3\lib\site-packages (0.18.0)
# Requirement already satisfied: kiwipiepy-model<0.19,>=0.18 in c:\users\hopio\anaconda3\lib\site-packages (from kiwipiepy) (0.18.0)
# Requirement already satisfied: numpy<2 in c:\users\hopio\anaconda3\lib\site-packages (from kiwipiepy) (1.26.4)
# Requirement already satisfied: tqdm in c:\users\hopio\anaconda3\lib\site-packages (from kiwipiepy) (4.66.4)
# Requirement already satisfied: colorama in c:\users\hopio\anaconda3\lib\site-packages (from tqdm->kiwipiepy) (0.4.6)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\hopio\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\hopio\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\hopio\anaconda3\Lib\site-packages)

# %% [markdown]
# # 한국어 토큰화

# %%
from kiwipiepy import Kiwi

kiwi = Kiwi()

# %%
result = kiwi.tokenize(train["ko"])
src_data = []
for tokens in tqdm(result):
    tokens = [ t.form for t in tokens]
    src_data.append(tokens)
# Out:
# 0it [00:00, ?it/s]

# %%
src_data
# Out:
# [['이', '제품', '들', '은', '같', '은', '품질', '이', '다', '.'],
#  ['미팅', '이', '취소', '되', '었', '다', '.'],
#  ['그', '들', '이', '이것', '을', '찾', '었', '다', '.'],
#  ['톰',
#   '은',
#   '메리',
#   '에게',
#   '왜',
#   '그',
#   '가',
#   '늦',
#   '게',
#   '까지',
#   '일',
#   '하',
#   '어야',
#   '하',
#   '었',
#   '는지',
#   '알리',
#   '어',
#   '주',
#   '지',
#   '않',
#   '었',
#   '다',
#   '.'],
#  ['먼저', '가', '세요', '.'],
#  ['계속', '웃', '어', '.'],
#  ['비', '가', '내리', '면', '집', '에', '있', '을', '것', '이', '다', '.'],
#  ['나', '피', '나', '어'],
#  ['톰', '이', '승낙', '하', '었', '어', '.'],
#  ['방금', '나', 'ᆯ', '모욕', '하', '었', '어', '?'],
#  ['나', 'ᆫ', '집중', '하', '려고', '애', '를', '쓰', '고', '있', '어', '.'],
#  ['너', 'ᆫ', '왜', '그렇', '게', '바보', '같이', '굴', '어', '?'],
#  ['끼', '어', '들', '어서', '죄송하', 'ᆸ니다', '.'],
#  ['톰', '은', '기말', '시험', '공부', '를', '안', '하', '었', '어', '.'],
#  ['그런', '일', '이', '생기', 'ᆫ다면', '어쩌', 'ᆯ', '거', '이', '야', '?'],
#  ['톰', '은', '맥주', '를', '원', '하', 'ᆫ다', '.'],
#  ['그거', 'ᆫ', '톰', '이', '이야기', '하', 'ᆫ', '것', '이', '아니', '다', '.'],
#  ['메리',
#   '는',
#   '톰',
#   '의',
#   '자켓',
#   '에서',
#   '길',
#   'ᆫ',
#   '금발',
#   '머리카락',
#   '한',
#   '올',
#   '을',
#   '발견',
#   '하',
#   '었',
#   '다',
#   '.'],
#  ['톰', '에게', '말', '하', '어', '.'],
#  ['제발', '떠나', '어', '주', '어', '.'],
#  ['이', '컵', '가지', '어도', '되', '어요', '?'],
#  ['나', 'ᆫ', '혼자', '서', '가', '어야', '하', '어', '.'],
#  ['톰', '은', '폭력', '적', '이', '야', '.'],
#  ['나', 'ᆫ', '톰', '과', '함께', '거기', '에', '가', 'ᆯ', '거', '이', '야', '.'],
#  ['톰', '이', '수영', '하', '러', '가', 'ᆫ다고', '말', '하', '었', '어', '.'],
#  ['그', '는', '계획', '을', '실행', '하', '었', '다', '.'],
#  ['안', '으로', '들어오', '어', '.'],
#  ['저', '가', '그러', '다가', '다치', '었었', '어요', '.'],
#  ['그', '들', '은', '채식주의자', '이', '다', '.'],
#  ['톰',
#   '은',
#   '직업',
#   '을',
#   '유지',
#   '하',
#   'ᆯ',
#   '수',
#   '없',
#   '어',
#   '.',
#   '걔',
#   '는',
#   '항상',
#   '해고',
#   '되',
#   '어',
#   '.'],
#  ['톰', '과', '대화', '하', 'ᆯ', '기회', '이', '라도', '생기', '었', '어', '?'],
#  ['톰', '의', '프랑스', '실력', '이', '많이', '오르', 'ᆫ', '것', '같', '어', '.'],
#  ['톰', '은', '경찰', '에게', '항복', '하', '었', '다', '.'],
#  ['그것',
#   '을',
#   '오늘',
#   '안',
#   '하',
#   '어도',
#   '되',
#   'ᆯ',
#   '것',
#   '같',
#   '다는',
#   '거',
#   'ᆯ',
#   '알',
#   '어'],
#  ['톰', '이', '운전', '하', '었', '어', '.'],
#  ['그', '데이터', '는', '완전히', '쓸모없', '었', '어', '.'],
#  ['나', 'ᆫ', '딱히', '선호', '하', '는', '거', 'ᆫ', '없', '어', '.'],
#  ['나', '가', '늦', '었', '기', '때문', '에', '비행기', '를', '놓치', '었', '어', '.'],
#  ['뭐', '이', '든', '먹', '어', '보', '어요', '.'],
#  ['나', 'ᆫ', '그저', '최선', '을', '다', '하', '고', '있', '을', '뿐', '이', '다', '.'],
#  ['공짜', '이', '에요', '.'],
#  ['해변', '의', '모래', '가', '흰색', '이', '었', '다', '.'],
#  ['언어', '가', '좋', '습니다', '.'],
#  ['반도체',
#   '는',
#   '한국',
#   '에',
#   '대하',
#   'ᆫ',
#   '미국',
#   '의',
#   '수출',
#   '1',
#   '위',
#   '이',
#   '었',
#   '어',
#   '.'],
#  ['톰', '은', '더', '크', 'ᆫ', '할인', '을', '원하', '었', '습니다', '.'],
#  ['전화기', '가', '울리', '었', '다', '.'],
#  ['너', '한', '번', '이', '라도', '사랑', '하', '어', '보', 'ᆫ', '적', '있', '어', '?'],
#  ['파란색', '이', '야', '?'],
#  ['톰', '은', '설거지', '를', '하', '지', '않', '었', '다', '.'],
#  ['은행', '문', '은', '닫히', '어', '있', '었', '어요', '?'],
#  ['지구', '에', '는', '여섯', '개', '의', '대륙', '이', '있', '어', '.'],
#  ['노래', '하', '는', '거', '좋', '어', '하', '어', '?'],
#  ['톰', '은', '보스턴', '에', '가', '기', '로', '결정', '하', '었', '다', '.'],
#  ['당신', '이', '보험', '이', '있', '기', '를', '바라', 'ᆸ니다', '.'],
#  ['당신', '은', '나', '가', '결혼', '하', 'ᆫ', '것', '을', '알', 'ᆫ다', '.'],
#  ['너', '지루', '하', '구나', '.'],
#  ['이', '책', '을', '읽', '는', '것', '은', '나', '에게', '쉽', '다', '.'],
#  ['여기', '뭐', '이', 'ᆫ가', '가', '잘못', '되', '었', '다', '.'],
#  ['창문', '을', '닫', '지', '말', '어', '.'],
#  ['나',
#   '가',
#   '어리',
#   '었',
#   '을',
#   '때',
#   '어떻',
#   '게',
#   '수영',
#   '하',
#   '는',
#   '지',
#   '를',
#   '배우',
#   '었',
#   '어',
#   '.'],
#  ['그', '들', '은', '떠나', '었', '어', '.'],
#  ['톰', '은', '매일', '피아노', '를', '연습', '하', '어', '.'],
#  ['톰',
#   '이',
#   '왜',
#   '그런',
#   '짓',
#   '을',
#   '하',
#   '었',
#   '는지',
#   '이해',
#   '하',
#   '기',
#   '너무',
#   '어렵',
#   '다는',
#   '것',
#   '을',
#   '알',
#   'ᆫ다',
#   '.'],
#  ['안녕', '아가씨', '들', '.'],
#  ['그', '가', '문', '을', '열', '려고', '하', '었', '다', '.'],
#  ['설마', '.'],
#  ['나',
#   '는',
#   '톰',
#   '과',
#   '같이',
#   '여행',
#   '하',
#   '기',
#   '를',
#   '기대',
#   '하',
#   '고',
#   '있',
#   '다',
#   '.'],
#  ['나', '는', '모래', '가', '싫', '다', '.'],
#  ['탐', '은', '현재', '작', '은', '아파트', '에서', '혼자', '살', '고', '있', '다', '.'],
#  ['이것', '은', '자살', '이', 'ᆸ니다', '.'],
#  ['뭐', '에', '대하', '어', '쓰', '고', '있', '어', '?'],
#  ['톰', '은', '버릇', '이', '없', '다', '.'],
#  ['저거', 'ᆫ', '뭐', '이', '야', '?'],
#  ['톰', '은', '자신', '의', '머리', '를', '자르', '었', '다', '.'],
#  ['이스탄불', '에', '는', '모기', '가', '얼마나', '많', '나요', '?'],
#  ['다른', '것', '을', '제안', '하', 'ᆯ', '수', '는', '없', '니', ',', '톰', '?'],
#  ['톰', '은', '경기', '에서', '이기', '었', '다', '.'],
#  ['달리기', '를', '매일', '하', '시', '나요', '?'],
#  ['누구',
#   '이',
#   'ᆫ가',
#   '는',
#   '농부',
#   ',',
#   '누구',
#   '이',
#   'ᆫ가',
#   '는',
#   '사냥',
#   '꾼',
#   '이',
#   '었',
#   '다',
#   '.'],
#  ['우리', '는', '좋', '은', '친구', '이', '다', '.'],
#  ['그', '들', '을', '찾', '어라', '.'],
#  ['나', '는', '톰', '을', '믿', '지', '않', '었', '어야', '하', '었', '어', '.'],
#  ['톰',
#   '은',
#   '어머님',
#   '이',
#   '교통사고',
#   '로',
#   '돌아가',
#   '시',
#   '었',
#   '을',
#   '때',
#   '세',
#   '살',
#   '이',
#   '었',
#   '어',
#   '.'],
#  ['뇌', '는', '신체', '에너지', '중', '25', '를', '소비', '하', '어', '.'],
#  ['그', '사람', '은', '인간', '심리', '에', '높', '은', '식견', '이', '있', '어', '.'],
#  ['톰', '은', '뛰어나', 'ᆫ', '문제', '해결', '능력', '을', '가지', '고', '있', '어', '.'],
#  ['영어', '로', '러브레터', '를', '쓰', '는', '것', '은', '쉽', '지', '않', '다', '.'],
#  ['몇몇',
#   '외국어',
#   '선생',
#   '님',
#   '이',
#   '한',
#   '번',
#   '도',
#   '원어민',
#   '과',
#   '공부',
#   '하',
#   '어',
#   '보',
#   'ᆫ',
#   '적',
#   '도',
#   '없',
#   '으면서',
#   '대학',
#   '을',
#   '나오',
#   'ᆯ',
#   '수',
#   '있',
#   '었',
#   '다는',
#   '거',
#   'ᆫ',
#   '창피',
#   '하',
#   'ᆫ',
#   '일',
#   '이',
#   'ᆫ',
#   '것',
#   '같',
#   '어',
#   '.'],
#  ['누구', '이', 'ᆫ가', '비명', '을', '지르', '었', '어', '.'],
#  ['잘', '하', '었', '어', '!'],
#  ['톰', '이', '확인', '하', '러', '가', 'ᆯ', '거', '이', '야', '.'],
#  ['나', '는', '톰', '이', '캐나다', '사람', '이', 'ᆫ', '줄', '알', '었', '다', '.'],
#  ['톰', '이랑', '메리', '둘', '다', '너', 'ᆯ', '그립', '어', '하', '어', '.'],
#  ['톰', '과', '싸우', '는', '거', 'ᆫ', '무', '의미', '하', '었', '어', '.'],
#  ['너', '마약', '중독자', '이', '야', '?'],
#  ['모두', '떠나', '었', '어', '.'],
#  ['저', '에게', 'ᆫ', '딸', '이', '셋', '이', 'ᆸ니다', '.'],
#  ['잘', '되', '기', 'ᆯ', '바라', '어', '.'],
#  ['톰', '은', '나', '의', '친구', '이', '야', '.', '그', '사람', '을', '알', '어', '?'],
#  ['그', '사람', '은', '고양이', '를', '키우', '고', '싶', '어', '하', '어', '.'],
#  ['나', '는', '일요일', '에', '일', '하', 'ᆫ다', '.'],
#  ['나', '는', '방', '에서', '프랑스어', '공부', '하', '는', '중', '이', '야', '.'],
#  ['먹', '고', '마시', '고', '즐기', 'ᆸ시다', '.'],
#  ['은', '교외', '에서', '자라', '었', '다', '.'],
#  ['나',
#   'ᆫ',
#   '톰',
#   '한테',
#   '나',
#   '가',
#   '다음',
#   '부터',
#   'ᆫ',
#   '절대',
#   '안',
#   '그렇',
#   'ᆯ',
#   '거',
#   '이',
#   '라고',
#   '단언',
#   '하',
#   '었',
#   '어',
#   '.'],
#  ['당신', '먼저', '이', '에요', '.'],
#  ['조심', '하', '어', '.'],
#  ['물고기', '요', '.'],
#  ['감기', '는', '전염', '되', '어', '.'],
#  ['택시', '좀', '부르', '어', '주', '시', 'ᆯ', '수', '있', '나요', '?'],
#  ['톰', '집', '에', '가', '어', '보', 'ᆫ', '적', '있', '어', '?'],
#  ['우리', 'ᆫ', '아직', '도', '먹', '는', '중', '이', '야', '.'],
#  ['갈색', '드레스', '와', '어울리', '는', '모자', '를', '찾', '고', '있', '어요', '.'],
#  ['시끄럽', '어', '!'],
#  ['이빨', '하나', '가', '아프', '다', '.'],
#  ['그녀', '는', '피부색', '이', '검', '다', '.'],
#  ['톰', '에게', '사과', '하', '려고', '하', '었', '어', '.'],
#  ['톰', '이', '외롭', '어', '하', '는', '것', '같', '어', '.'],
#  ['우리',
#   '에게',
#   '필요',
#   '하',
#   'ᆫ',
#   '것',
#   '이',
#   '무엇',
#   '이',
#   'ᆫ지',
#   '하나님',
#   '께서',
#   '는',
#   '알',
#   '시',
#   'ᆫ다',
#   '.'],
#  ['나', 'ᆫ', '2013', '년', '에', '태어나', '었', '어', '.'],
#  ['그만', '흐느끼', '어', '.'],
#  ['나', '는', '그', '점', '에서', '그', '와', '의견', '이', '일치', '하', '었', '다', '.'],
#  ['나', 'ᆫ', '프랑스어', '를', '잘', '하', '어', '.'],
#  ['그날', '밤', '은', '춥', '었', '어', '.'],
#  ['누구', '이', 'ᆫ가', '톰', '한테', '말', '을', '걸', '고', '있', '었', '어', '.'],
#  ['나', '는', '이것', '을', '사', '고', '싶', '다', '.'],
#  ['톰', '은', '난간', '만큼', '날씬하', '어', '.'],
#  ['이', '기술', '은', '배우', '기', '쉽', '지', '않', '어', '.'],
#  ['오해', '하', '지', '말', '어', '.'],
#  ['이것', '이', '당신', '이', '찾', '던', '사전', '이', 'ᆸ니까', '?'],
#  ['그', '사람', '은', '마약', '중독자', '이', '야', '.'],
#  ['나', 'ᆫ', '나', '가', '하', '는', '것', '이', '정말', '좋', '어', '.'],
#  ['나', 'ᆫ', '톰', '한테', '문자', '보내', '었', '어', '.'],
#  ['너',
#   '정말',
#   '톰',
#   '이',
#   '그거',
#   'ᆯ',
#   '하',
#   '도록',
#   '설득',
#   '하',
#   'ᆯ',
#   '수',
#   '있',
#   '다고',
#   '생각',
#   '하',
#   '어',
#   '?'],
#  ['톰', '은', '아직', '도', '솔로', '이', '야', '.'],
#  ['톰', '은', '한', '숨', '쉬', '었', '어', '.'],
#  ['취하', '어', '보', 'ᆫ', '적', '있', '어', '?'],
#  ['톰', '은', '여전히', '수영', '을', '잘', '못', '하', '지', '?'],
#  ['신중', '하', '게', '고르', '어', '.'],
#  ['그녀', '는', '숙제', '를', '다', '하', '었', '다', '.'],
#  ['그',
#   '는',
#   '항상',
#   '너',
#   'ᆯ',
#   '지켜보',
#   '었',
#   '어',
#   '.',
#   '너',
#   'ᆯ',
#   '좋아하',
#   '는',
#   '것',
#   '이',
#   '분명',
#   '하',
#   '어',
#   '.'],
#  ['나', 'ᆫ', '톰', '이', '마약', '중독자', '이', '라는', '거', 'ᆯ', '모르', '었', '어', '.'],
#  ['프랑스어', '를', '배우', '어야', '하', 'ᆯ까요', '?'],
#  ['그녀', '는', '강제', '로', '그', '를', '앉히', '었', '다', '.'],
#  ['이야기', '를', '마저', '듣', '어', '보', 'ᆸ시다', '.'],
#  ['톰', '이', '자기', '아내', '랑', '오', 'ᆯ까', ',', '아니', '면', '혼자', '오', 'ᆯ까', '?'],
#  ['단언',
#   '하',
#   '건대',
#   ',',
#   '그런',
#   '일',
#   '은',
#   '일어나',
#   '지',
#   '않',
#   '을',
#   '거',
#   '이',
#   '야',
#   '.'],
#  ['나', 'ᆫ', '절대', '이혼', '하', '지', '말', '었', '어야', '하', '었', '는데', '.'],
#  ['맥주', '두', '잔', '주', '세요', '.'],
#  ['이거', 'ᆫ', '그냥', '나', '의', '의견', '이', '다', '.'],
#  ['나', 'ᆫ', '이제', '편지', '안', '쓰', '어', '.'],
#  ['잠깐', '!'],
#  ['프랑스어', '를', '배우', '는', '거', 'ᆯ', '추천', '하', '어', '.'],
#  ['모래바람', '으로', '인하', '어', '비행', '편', '이', '연기', '되', '겠', '습니다', '.'],
#  ['우울증',
#   '은',
#   '아스퍼거',
#   '증후군',
#   '을',
#   '가지',
#   'ᆫ',
#   '청년',
#   '들',
#   '에게',
#   '있',
#   '어',
#   '흔',
#   '하',
#   'ᆫ',
#   '질병',
#   '이',
#   '야',
#   '.'],
#  ['괜찮', '네요', '.'],
#  ['톰',
#   '은',
#   '가끔',
#   '나',
#   '가',
#   '톰',
#   '의',
#   '차',
#   '를',
#   '쓰',
#   '도록',
#   '하',
#   '어',
#   '주',
#   '어',
#   '.'],
#  ['나', '는', '톰', '과', '테니스', '를', '자주', '하', 'ᆫ다', '.'],
#  ['나', 'ᆫ', '그냥', '티비', '보', '고', '있', '어', '.'],
#  ['이', '선글라스', '얼마', '이', '었', '어', '?'],
#  ['저', '고양이', '를', '마지막', '으로', '보', '었', '을', '때', '가', '언제', '이', '야', '?'],
#  ['침착', '하', '어', '.'],
#  ['정말', '한', '번', '이', '라도', '사랑', '에', '빠지', 'ᆫ', '적', '있', '어', '?'],
#  ['톰', '의', '파일', '이', '어디', '있', '지', '?'],
#  ['톰',
#   '은',
#   '경험',
#   '이',
#   '있',
#   '는',
#   '사람',
#   '을',
#   '고용',
#   '하',
#   '고',
#   '싶',
#   '다고',
#   '말',
#   '하',
#   '었',
#   '다',
#   '.'],
#  ['이', '빵', '맛있', '어', '보이', '네', '.'],
#  ['톰', '은', '탱고', '추', '는', '방법', '을', '배우', '고', '싶', '었', '다', '.'],
#  ['우리',
#   '집',
#   '을',
#   '칠',
#   '하',
#   '는데',
#   '생각',
#   '보다',
#   '시간',
#   '이',
#   '오래',
#   '걸리',
#   '었',
#   '다',
#   '.'],
#  ['톰', '은', '소심', '하', 'ᆫ', '애', '이', '야', '.'],
#  ['끝내주', '네', '!'],
#  ['톰', '은', '무시', '하', '어', '.'],
#  ['도와주', '어', '.'],
#  ['톰', '은', '운전', '하', '는', '법', '을', '배우', '고', '있', '어', '.'],
#  ['너', '가', '나', 'ᆯ', '싫어하', 'ᆫ다고', '생각', '하', '었', '어', '.'],
#  ['톰', '과', '마리', '는', '같', '은', '배', '를', '타', '었', '다', '.'],
#  ['보이', '어', '주', '어', '.'],
#  ['그', '는', '그녀', '가', '떠나', '기', 'ᆯ', '원', '하', '지', '않', '었', '다', '.'],
#  ['헬리콥터', '타', '어', '보', 'ᆫ', '적', '있', '어', '?'],
#  ['톰', '은', '거의', '늘', '자기', '방', '에', '만', '있', '어', '.'],
#  ['비', '가', '오', 'ᆯ', '것', '같', '어', '.'],
#  ['일본', '에', '는', '펭귄', '을', '키우', '는', '사람', '이', '있', '대', '.'],
#  ['그', '는', '열차', '를', '좋아하', 'ᆫ다', '.'],
#  ['자연', '스럽', '게', '행동', '하', '려고', '노력', '하', '고', '있', '어', '.'],
#  ['되', 'ᆯ', '수', '있', '는', '한', '여기', '서', '빠져나가', '고', '싶', '어', '.'],
#  ['샴폐', '이', 'ᆫ', '좀', '.'],
#  ['1', '더하기', '1', '은', '2', '이', '야', '.'],
#  ['저', '가', '누구', '이', 'ᆫ지', '알', '시', '나요', '?'],
#  ['과민', '반응', '그만', '하', '어', '.'],
#  ['그', '는', '우리', '에게', '도움', '을', '청', '하', '었', '다', '.'],
#  ['비와', '이', '라는', '호수', '만큼', '크', 'ᆫ', '호수', '은', '일본', '에', '없', '어', '.'],
#  ['톰', '은', '매우', '무례', '하', '었', '다', '.'],
#  ['그것', '이', '불', '가능', '하', '단', '거', 'ᆫ', '알', '고', '있', '지', '?'],
#  ['우리', '는', '죽', '기', '위하', '어', '태어나', '었', '어', '.'],
#  ['네', '나이프', '좀', '빌리', '어', '주', 'ᆯ래', '?'],
#  ['그', '는', '교회', '에', '거의', '가', '지', '않', '는다', '.'],
#  ['나', '는', '톰', '이랑', '은', '달리', '아이', '를', '갖', '고', '싶', '어', '.'],
#  ['사고', '가', '벌어지', '었', '다', '.'],
#  ['우리', '는', '다', '톰', '이', '탈출', '하', 'ᆫ', '줄', '알', '었', '다', '.'],
#  ['한번', '시도', '하', '어', '보', '었', '어', '?'],
#  ['톰', '은', '지금', '침대', '신세', '이', '야', '.'],
#  ['그', '는', '영화관', '에', '가', '는', '것', '을', '좋아하', 'ᆫ다', '.'],
#  ['다른', '남자', '와', '결혼', '하', '었', '다면', '좋', '었', '을', '터', '이', 'ᆫ데', '.'],
#  ['신선', '하', 'ᆫ', '파스타', '있', '어요', '?'],
#  ['저거', 'ᆯ', '잡', '고', '있', '어', '.'],
#  ['헌혈', '하', '어', '보', 'ᆫ', '적', '이', '있', '니', '?'],
#  ['너', '는', '톰', '을', '포기', '하', 'ᆯ', '수', '없', '다', '.'],
#  ['평범하', 'ᆫ', '폭풍', '이', '아니', '었', '다', '.'],
#  ['톰', '은', '이제', '는', '게으르', 'ᆫ', '소년', '이', '아니', '다', '.'],
#  ['그', '는', '작년', '에', '유언장', '을', '쓰', '었', '습니다', '.'],
#  ['톰', '의', '태도', '가', '변하', '었', '어', '.'],
#  ['나', '가', '다른', '곳', '에', '있', '다면', '좋', '을', '터', '이', 'ᆫ데', '.'],
#  ['우리', '아버지', '는', '집', '에', '계시', 'ᆫ다', '.'],
#  ['너',
#   '결혼',
#   '하',
#   'ᆫ',
#   '거',
#   '톰',
#   '한테',
#   '말',
#   '안',
#   '하',
#   '었',
#   '구나',
#   ',',
#   '그치',
#   '?'],
#  ['그', '는', '불어', '로', '말', '하', '고', '쓰', 'ᆯ', '수', '있', '다', '.'],
#  ['카페인', '이', '필요', '하', '다', '.'],
#  ['너', '의', '인생', '에', '여자', '가', '있', '어', '?'],
#  ['나', '는', '살', '빼', '는', '방법', '을', '알', '고', '싶', '다', '.'],
#  ['달', '이', '지', '었', '다', '.'],
#  ['진정하', '어', '.'],
#  ['톰', '은', '무슬림', '이', '다', '.'],
#  ['톰', '은', '머리', '뒤', '로', '손', '을', '꽉', '잡', '었', '어', '.'],
#  ['늦', '어서', '죄송', '하', 'ᆸ니다', '.'],
#  ['이렇', '게', '나', '끔찍', '하', '다니', '!'],
#  ['누구', '이', 'ᆫ가', '에게', '묻', '어', '보', '어', '.'],
#  ['잎', '들', '이', '노랗', '다', '.'],
#  ['크로아티아어', '가', '흥미', '롭', '은', '언어', '이', '라고', '생각', '하', '세요', '?'],
#  ['우리', 'ᆫ', '성공', '하', '었', '어', '.'],
#  ['사람', '들', '이', '말', '하', '는', '전부', '를', '믿', '지', '는', '말', '어', '.'],
#  ['톰',
#   '은',
#   '나',
#   '가',
#   '시금치',
#   '를',
#   '싫어하',
#   'ᆫ다는',
#   '것',
#   '을',
#   '알',
#   '고',
#   '있',
#   '다',
#   '.'],
#  ['톰', '은', '노랗', 'ᆫ', '셔츠', '를', '입', '고', '있', '어', '.'],
#  ['나', 'ᆫ', '노래', '부르', '고', '있', '을', '때', '가', '가장', '행복', '하', '어', '.'],
#  ['나', '랑', '같이', '아침', '먹', '을래', '?'],
#  ['오늘', '저녁', '6', '시', '까지', '준비', '되', 'ᆯ', '것', '이', '다', '.'],
#  ['톰', '은', '보스턴', '에서', '제일', '실력', '있', '는', '드러머', '이', '다', '.'],
#  ['만지', '어', '보', '어도', '되', '어', '?'],
#  ['그', '는', '무례', '하', 'ᆫ', '사람', '이', '다', '.'],
#  ['어제', '일식', '보', '었', '어', '?'],
#  ['내', '생각', '에', '톰', '은', '아주', '신나', '어', '하', 'ᆯ', '것', '같', '어', '.'],
#  ['이곳', '은', '나', '의', '학교', '이', '다', '.'],
#  ['계란', '얼마나', '사', '었', '어', '?'],
#  ['아니야', '!'],
#  ['나', 'ᆫ', '내일', '가', 'ᆯ', '수', '있', '어', '.'],
#  ['그', '들', '은', '아니', '라고', '하', '었', '다', '.'],
#  ['현미경', '아래', '에서', 'ᆫ', '몇몇', '바이러스', '는', '꽤', '아름답', '어', '보이', '어', '.'],
#  ['걔', '는', '반', '에서', '꼴찌', '이', '었', '어', '.'],
#  ['나',
#   'ᆫ',
#   '더',
#   '열심히',
#   '안',
#   '하',
#   'ᆫ',
#   '거',
#   'ᆯ',
#   '후회',
#   '하',
#   '고',
#   '있',
#   '어',
#   '.'],
#  ['너', '는', '무슨', '신문', '읽', '어', '?'],
#  ['톰', '은', '깊', '게', '숨', '을', '쉬', '었', '다', '.'],
#  ['톰',
#   '은',
#   '몇',
#   '달',
#   '동안',
#   '메리',
#   '를',
#   '보',
#   '지',
#   '못',
#   '하',
#   '었',
#   '다고',
#   '나',
#   '에게',
#   '말',
#   '하',
#   '었',
#   '다',
#   '.'],
#  ['기다리', '어', '.'],
#  ['제발', '앉', '어', '.'],
#  ['노래', '부르', '고', '춤추', '자', '.'],
#  ['그것', '이', '사실', '이', '야', '?'],
#  ['체크아웃', '하', '고', '싶', '습니다', '.'],
#  ['우리', '차', '는', '너희', '차', '보다', '3', '년', '더', '오래되', '었', '다', '.'],
#  ['기억', '을', '억지로', '잊', '게', '하', 'ᆯ', '수', '는', '없', '어', '.'],
#  ['톰', '은', '늦잠', '자', '었', '어', '.'],
#  ['너', '이거', '한', '번', '맛보', '어야', '하', '어', '.', '이거', '맛있', '거든', '.'],
#  ['톰', '이', '우리', '한테', '크리스마스', '선물', '을', '보내', '었', '어', '.'],
#  ['나', 'ᆫ', '조심', '성', '이', '있', '는', '사람', '이', '다', '.'],
#  ['너', '가', '부럽', '다고', '말', '하', '어야', '하', 'ᆯ', '것', '같', '어', '.'],
#  ['이', '가', '위', '잘', '안', '듣', '어', '.'],
#  ['아이', '들', '은', '몇', '명', '다치', '었', '어', '?'],
#  ['나', '는', '너', '의', '질문', '에', '답', '하', 'ᆯ', '수', '없', '어', '.'],
#  ['많이', '안', '기다리', '어도', '되', '면', '좋', '겠', '다'],
#  ['톰', '은', '훌륭', '하', 'ᆫ', '프랑스어', '선생', '님', '이', '야', '.'],
#  ['나', 'ᆫ', '톰', '한테', '프랑스어', '를', '가르치', 'ᆯ', '수', '있', '어', '.'],
#  ['톰', '은', '돈', '을', '꽤', '많이', '갖', '고', '있', '어', '.'],
#  ['법', '이전', '에', '모두', '는', '평등', '하', '어', '.'],
#  ['이거', '아직', '도', '못', '끝내', '었', '어', '.'],
#  ['정말로', '톰', '과', '함께', '보스턴', '에', '가', '고', '싶', '어', '?'],
#  ['나', '는', '너', '의', '엄마', '를', '알', 'ᆫ다', '.'],
#  ['나', '가', '총', '소리', '를', '듣', '었', '다고', '생각', '하', '었', '어', '.'],
#  ['나',
#   '는',
#   '탐',
#   '이',
#   '하',
#   '고',
#   '있',
#   '는',
#   '일',
#   '이',
#   '놀랍',
#   '다고',
#   '생각',
#   '하',
#   'ᆫ다',
#   '.'],
#  ['우리', 'ᆫ', '늦잠', '자', '었', '어', '.'],
#  ['많', '은', '사람', '들', '이', '저런', '식', '으로', '행동', '하', '어', '.'],
#  ['도와주', '어', '!'],
#  ['톰', '은', '나', '보다', '돈', '이', '많', '어', '.'],
#  ['나', '는', '내일', '죽', '을지', '도', '모르', 'ᆫ다', '.'],
#  ['밖', '에', '비', '가', '내리', '고', '있', '었', '다', '.'],
#  ['나', 'ᆫ', '심지어', '여기', '없', '었', '어', '.'],
#  ['나',
#   'ᆫ',
#   '톰',
#   '이',
#   '나',
#   '한테',
#   '말',
#   '하',
#   'ᆫ',
#   '모든',
#   '것',
#   '을',
#   '기억',
#   '하',
#   '었',
#   '으면',
#   '좋',
#   '겠',
#   '어',
#   '.'],
#  ['그래서', '?'],
#  ['이거', '무슨', '냄새', '이', '지', '?'],
#  ['아기', '가', '침대', '에서', '울', '고', '있', '었', '어', '.'],
#  ['톰', '의', '얼굴', '이', '빨개지', '었', '어', '.'],
#  ['대답', '은', '그렇', '다', '이', '다', '.'],
#  ['알', '겠', '어', '!'],
#  ['톰', '은', '나이', '에', '비하', '어', '늙', '어', '보이', '어', '.'],
#  ['노래', '를', '부르', '고', '춤', '을', '추', 'ᆸ시다', '.'],
#  ['나', 'ᆫ', '프랑스', '를', '정말', '좋아하', '어', '.'],
#  ['나',
#   '는',
#   '톰',
#   '이',
#   '매우',
#   '관대',
#   '하',
#   'ᆫ',
#   '사람',
#   '이',
#   '라는',
#   '것',
#   '을',
#   '알',
#   'ᆫ다',
#   '.'],
#  ['톰', '을', '돌보', '어', '주', '어서', '고맙', '어요', '.'],
#  ['나', '가', '먹', '을', '것', '을', '더', '사', '었', '어야', '하', '었', '는데', '.'],
#  ['여기', '서', '죽', '기', '싫', '어', '.'],
#  ['한', '시간', '넘', '게', '걸리', 'ᆯ', '것', '같', '어', '.'],
#  ['나', '는', '보스턴', '에', '알', '는', '사람', '이', '없', '다', '.'],
#  ['톰', '은', '보통', '프랑스어', '로', '노래', '하', '지', 'ᆫ', '않', '어', '.'],
#  ['나', '는', '앞', '으로', '나아가', 'ᆯ', '것', '이', '다', '.'],
#  ['톰',
#   '과',
#   '함께',
#   '이',
#   '라면',
#   '더',
#   '행복',
#   '하',
#   '어',
#   '지',
#   'ᆯ',
#   '것',
#   '같',
#   '니',
#   '?'],
#  ['여기', '나', '혼자', '이', '에요', '?'],
#  ['뭐', '하', '는', '거', '이', '야', '?'],
#  ['이것', '이', '무슨', '뜻', '이', '에요', '?'],
#  ['우리', 'ᆫ', '저기', '에', '있', '는', '지하철', '타', 'ᆯ', '수', '있', '어', '.'],
#  ['좀', '쉬', '어', '.'],
#  ['폐', '를', '끼치', '어서', '진심', '으로', '죄송하', 'ᆸ니다', '.'],
#  ['그', '들', '은', '이', '맨션', '12', '층', '에', '살', 'ᆫ다', '.'],
#  ['오늘', '은', '얼마나', '잃', '었', '어', '?'],
#  ['나', 'ᆫ', '정말로', '돕', '고', '싶', '었', '어', '.'],
#  ['너',
#   '가',
#   '톰',
#   '을',
#   '그렇',
#   '게',
#   '사랑',
#   '하',
#   'ᆯ',
#   '줄',
#   '은',
#   '모르',
#   '었',
#   '어',
#   '.'],
#  ['저', '가', '하', '는', '일', '은', '차', '를', '팔', '는', '거', '이', 'ᆸ니다', '.'],
#  ['정말', '흥미', '롭', '은데', '!'],
#  ['그녀', '는', '개', '한', '마리', '와', '고양이', '여섯', '마리', '를', '키우', 'ᆫ다', '.'],
#  ['아무',
#   '도',
#   '나',
#   '의',
#   '생일',
#   '을',
#   '기억',
#   '하',
#   '어',
#   '주',
#   '지',
#   '않',
#   '었',
#   '어',
#   '.'],
#  ['힘들', '지', '않', '다', '.'],
#  ['톰', '은', '진화', '론', '을', '믿', '지', '않', '어', '.'],
#  ['그', '는', '프랑스어', '와', '웹', '디자인', '을', '공부', '하', '고', '있', '다', '.'],
#  ['예', '를', '들', '어', '주', '시', '겠', '습니까', '?'],
#  ['그거', 'ᆫ', '무시', '하', '어', '.'],
#  ['너', '의', '계획', '은', '실패', '하', '었', '어', '.'],
#  ['톰', '은', '아주', '수다', '쟁이', '이', '야', '.'],
#  ['빨간불', '에', '멈추', '었', '어', '?'],
#  ['날씨', '좋', '지', '않', '어', '?'],
#  ['이거', '정말', '기분', '좋', '다', '.'],
#  ['그것', '이', '우리', '가', '원하', '었', '던', '것', '의', '전부', '이', '야', '.'],
#  ['톰', '은', '자신', '이', '약하', '다고', '말', '하', '었', '다', '.'],
#  ['아침', '에', '무슨', '일', '이', '있', '었', '니', '?'],
#  ['항생제', '는', '바이러스', '를', '죽이', 'ᆯ', '수', '없', '어', '.'],
#  ['당신', '은', '나', '의', '것', '이', 'ᆸ니다', '.'],
#  ['어디', '서', '쓰', '는', '법', '을', '배우', '었', '어', '?'],
#  ['톰',
#   '은',
#   '해',
#   'ᆯ러',
#   '윈',
#   '을',
#   '맞',
#   '어',
#   '카우보이',
#   '처럼',
#   '옷',
#   '을',
#   '입',
#   '었',
#   '다',
#   '.'],
#  ['나', '는', '부득이', '하', '게', '가', '었', '다', '.'],
#  ['나', '는', '이번', '주', '에', '저거', 'ᆯ', '하', 'ᆯ', '시간', '이', '있', '어', '.'],
#  ['톰', '이', '진짜', '보스턴', '을', '좋아하', '는지', '궁금하', '네', '.'],
#  ['톰', '이', '무척', '외롭', '었', '다고', '말', '하', '었', '어', '.'],
#  ['한심', '하', 'ᆫ', '것', '같', '어', '.'],
#  ['톰', '은', '철로', '만큼', '날씬하', '어', '.'],
#  ['바보',
#   '같',
#   '은',
#   '짓',
#   '은',
#   '하',
#   '지',
#   '않',
#   '겠',
#   '다고',
#   '나',
#   '한테',
#   '약속',
#   '하',
#   '어',
#   '.'],
#  ['그것',
#   '을',
#   '오늘',
#   '안',
#   '하',
#   '어도',
#   '되',
#   'ᆯ',
#   '것',
#   '같',
#   '다는',
#   '거',
#   'ᆯ',
#   '알',
#   '어'],
#  ['너', '도', '마찬가지', '로', '프랑스어', '를', '배우', 'ᆯ', '수', '있', '어', '.'],
#  ['톰', '과', '메리', '는', '지난주', '에', '헤어지', '었', '다', '.'],
#  ['합리', '적', '으로', '들리', '네', '.'],
#  ['이거', 'ᆫ', '톰', '이', '하', '려고', '하', 'ᆫ', '것', '이', '아니', '야', '.'],
#  ['이것', '이', '바로', '나', '가', '가장', '좋아하', '는', '프랑스', '단어', '이', '야', '.'],
#  ['말', '하', '려', '하', '지', '말', '어', '.', '차라리', '에너지', '를', '아끼', '어', '.'],
#  ['저희', '에게', '알리', '어', '주', '세요', '.'],
#  ['이런', '일', '에', '시간', '을', '낭비', '하', '고', '싶', '지', '않', '다', '.'],
#  ['나',
#   '는',
#   '어젯밤',
#   '에',
#   '책',
#   '을',
#   '읽',
#   '느라',
#   '두',
#   '시간',
#   '을',
#   '보내',
#   '었',
#   '어',
#   '.'],
#  ['나', '는', '음악', '을', '사랑', '하', 'ᆫ다', '.'],
#  ['톰', '은', '오늘', '밤', '집', '에', '머물', '고', '싶', '어', '하', 'ᆫ다', '.'],
#  ['나', 'ᆫ', '그', '프로젝트', '에', '대하', '어', '아직', '긍정', '적', '이', '야', '.'],
#  ['톰', '이', '뜨개질', '하', '고', '있', '어', '.'],
#  ['물', '좀', '끓이', '어', '.'],
#  ['톰', '은', '훌륭하', 'ᆫ', '매니저', '이', '야', '.'],
#  ['이것', '은', '사실', '이', '아니', '다', '.'],
#  ['일', '은', '잘', '되', '니', '?'],
#  ['나', 'ᆫ', '너', 'ᆯ', '절대로', '용서', '하', '지', '않', '을', '거', '이', '야', '.'],
#  ['그', '가', '거리', '를', '건너', '는', '것', '을', '보', '었', '다', '.'],
#  ['나', '의', '시계', '는', '당신', '의', '것', '과', '다르', '다', '.'],
#  ['톰', '은', '떠나', 'ᆯ', '준비', '가', '거의', '다', '되', '었', '대', '.'],
#  ['지금', '월요일', '이', '라는', '것', '을', '자각', '하', '고', '있', '어', '.'],
#  ['스트레스',
#   '의',
#   '일반',
#   '적',
#   '원인',
#   '은',
#   '업무',
#   '와',
#   '인간',
#   '관계',
#   '에',
#   '있',
#   '어',
#   '.'],
#  ['이거', 'ᆫ', '나', '의', '강아지', '이', '야', '.'],
#  ['문자', '하', '어', '주', '어', '.'],
#  ['너', '도', '포함', '이', '야', '?'],
#  ['저것', '이', '불안', '하', '게', '만드', '네', '.'],
#  ['우리', '에게', '거짓말', '하', '지', '말', '어', '.'],
#  ['나', 'ᆫ', '톰', '이', '살인자', '이', '라고', '믿', '지', '않', '어', '.'],
#  ['톰', '이', '사과', '하', '었', '어', '.'],
#  ['그', '를', '깨우', '지', '말', '어', '.'],
#  ['물고기', '좋', '어', '하', '어', '?'],
#  ['나', '가', '내', 'ᆯ게', '.'],
#  ['나', '는', '톰', '이', '뛰어나', '다고', '생각', '하', 'ᆫ다', '.'],
#  ['이거', 'ᆯ', '하', '려면', '시간', '이', '얼마나', '걸리', '어', '?'],
#  ['집', '에', '아무', '도', '없', '었', '다', '.'],
#  ['모두', '일어서', '었', '어', '.'],
#  ['누구', '이', 'ᆫ가', '죽', '었', '어', '.'],
#  ['너희', '둘', '무엇', '에', '관하', '어', '논쟁', '하', '고', '있', '니', '?'],
#  ['나',
#   '는',
#   '톰',
#   '이',
#   '프랑스어',
#   '를',
#   '하',
#   'ᆫ다는',
#   '것',
#   '을',
#   '잊',
#   '고',
#   '있',
#   '었',
#   '다',
#   '.'],
#  ['어떤', '테니스', '선수', '가', '가장', '좋', '어', '?'],
#  ['나', '는', '맥주', '가', '좋', '어', '.'],
#  ['여기', '서', '기다리', '어', '.'],
#  ['교직', '에', '돌아가', 'ᆯ', '생각', '을', '하', '고', '있', '다', '.'],
#  ['톰', '은', '문제아', '이', '었', '어', '.'],
#  ['나', '는', '지나', 'ᆫ', '밤', '에', '도착', '하', '었', '다', '.'],
#  ['그', '는', '지름길', '로', '가', '었', '다', '.'],
#  ['폭풍', '이', '다가오', 'ᆫ다', '.'],
#  ['톰', '이', '끙끙대', '었', '어', '.'],
#  ['톰', '은', '집중', '하', '려고', '애쓰', '고', '있', '어', '.'],
#  ['우리', '는', '보스턴', '에', '가', '었', '다', '.'],
#  ['나', '는', '인간', '이', '야', '.'],
#  ['작년', '에', '눈', '이', '엄청', '내리', '었', '어', '.'],
#  ['변호사', '들', '은', '모두', '거짓말', '쟁이', '이', '다', '.'],
#  ['우리', 'ᆫ', '시간', '을', '아끼', '기', '위하', '어서', '컴퓨터', '를', '쓰', '었', '어', '.'],
#  ['보', '어', '보', '어', '!', '고양이', '가', '부엌', '에', '있', '어', '.'],
#  ['계획',
#   '을',
#   '세우',
#   '는',
#   '것',
#   '과',
#   '그것',
#   '을',
#   '실행',
#   '하',
#   '는',
#   '것',
#   '은',
#   '별개',
#   '의',
#   '문제',
#   '이',
#   '다',
#   '.'],
#  ['개', '한', '마리', '가', '톰', '을', '따라가', '고', '있', '었', '어', '.'],
#  ['어떤', '종교', '는', '장기', '기증', '을', '금지', '하', '기', '도', '하', '어', '.'],
#  ['나', '는', '더', '이상', '젊', '지', '않', '다', '.'],
#  ['나중', '에', '다시', '돌아오', '겠', '습니다', '.'],
#  ['이', '게임', '은', '정말로', '재미', '있', '다', '.'],
#  ['외로움', '보다', '더', '끔찍', '하', 'ᆫ', '것', '은', '없', '어', '.'],
#  ['나오', '어', '메리', '는', '약혼', '하', '었', '어', '.'],
#  ['네', '.', '그', '남자', '와', '키스', '하', '었', '어요', '.'],
#  ['받아들이', 'ᆯ게요', '.'],
#  ['나',
#   '는',
#   '우리',
#   '가',
#   '이기',
#   'ᆯ',
#   '가능',
#   '성',
#   '이',
#   '전혀',
#   '없',
#   '다고',
#   '생각',
#   '하',
#   '었',
#   '어',
#   '.'],
#  ['그때', '갑자기', ',', '그녀', '가', '웃', '기', '시작', '하', '었', '다', '.'],
#  ['아무런', '느낌', '도', '안', '나', '어', '.'],
#  ['스푸트니크',
#   '는',
#   '1957',
#   '년',
#   '10',
#   '월',
#   '4',
#   '일',
#   '에',
#   '발사',
#   '되',
#   '었',
#   '다',
#   '.'],
#  ['거의', '다', '저', '의', '시간', '에', '도착', '하', '었', '다', '.'],
#  ['여기', '에', '아이', '들', '이', '있', '어', '.'],
#  ['우리', '는', '동의', '하', '어', '.'],
#  ['톰', '은', '메리', '가', '그거', 'ᆯ', '못', '하', '도록', '막', '었', '어', '.'],
#  ['나',
#   '가',
#   '원어민',
#   '이랑',
#   '공부',
#   '하',
#   'ᆫ다면',
#   '나',
#   '의',
#   '프랑스어',
#   '실력',
#   '은',
#   '훨씬',
#   '더',
#   '낫',
#   '을',
#   '터',
#   '이',
#   'ᆫ데',
#   '.'],
#  ['그', '는', '웃', '었', '다', '.'],
#  ['톰', '은', '그렇', '게', '멀리', '까지', '걸어가', '기', '에', 'ᆫ', '너무', '약하', '다', '.'],
#  ['우리', '는', '당신', '의', '조언', '이', '필요', '하', '다', '.'],
#  ['톰', '은', '좋', '은', '친구', '이', '죠', ',', '아니', 'ᆫ가', '요', '?'],
#  ['이렇게', '나', '슬프', '다니', '!'],
#  ['일부', '애', '들', '은', '야채', '를', '안', '좋아하', '어', '.'],
#  ['이', '해변', '에', '오', '어', '보', 'ᆫ', '적', '있', '어', '?'],
#  ['톰', '은', '자기', '컴퓨터', '를', '끄', '었', '어', '.'],
#  ['저', '버스', '는', '어디', '로', '가', '나요', '?'],
#  ['아무', '일', '도', '없', '었', '어', '.'],
#  ['나', '는', '두', '번', '자살', '시도', '를', '하', '었', '어', '.'],
#  ['그', '들', '은', '당신', '을', '지켜보', '고', '있', '다', '.'],
#  ['나', '가', '돈', '은', '없', '어도', '꿈', '은', '있', '어', '.'],
#  ['톰', '은', '그', '의', '턱수염', '을', '땋', '었', '다', '.'],
#  ['톰', '은', '힘', '든', '시간', '을', '보내', '게', '되', 'ᆯ', '거', '이', '야', '.'],
#  ['뭐', '이', 'ᆫ가', '가', '일어나', '는', '중', '이', '야', '.'],
#  ['절도', '를', '하', 'ᆫ', '사람', '은', '벌', '을', '받', '어', '마땅', '하', '다', '.'],
#  ['말', '도', '안', '되', 'ᆫ다', '.'],
#  ['도움', '이', '필요', '하', '시', 'ᆸ니까', '?'],
#  ['우리', '좀', '바보짓', '을', '하', '어야', '하', 'ᆯ', '것', '같', '어', '.'],
#  ['톰', '은', '아침', '마다', '여섯', '시', '삼십', '분', '에', '일어나', '어', '.'],
#  ['너', '후회', '하', 'ᆯ', '거', '이', '야', '.'],
#  ['톰', '은', '메리', '를', '계속', '하', '어서', '지키', '어', '보', '었', '다', '.'],
#  ['그', '들', '은', '초록색', '이', '다', '.'],
#  ['신', '께서', '당신', '을', '축복', '하', '시', '기', 'ᆯ', '.'],
#  ['톰', '은', '전기', '기사', '이', '다', '.'],
#  ['톰', '은', '오두막', '에서', '혼자', '살', '고', '있', '어', '.'],
#  ['죄송', '하', '지만', ',', '무슨', '말', '이', 'ᆫ지', '모르', '겠', '어요', '.'],
#  ['1950', '년', '에', ',', '북한', '은', '남한', '을', '침공', '하', '었', '다', '.'],
#  ['근육',
#   '은',
#   '수백',
#   '개',
#   '의',
#   '얇',
#   '은',
#   '섬유',
#   '로',
#   '만들',
#   '어',
#   '지',
#   '어',
#   '있',
#   '어',
#   '.'],
#  ['나', '는', '모델', '을', '꿈꾸', '곤', '하', '었', '다', '.'],
#  ['레스토랑', '에서', '보', '자', '.'],
#  ['나', 'ᆫ', '프랑스어', '로', '되', 'ᆫ', '책', '을', '읽', '었', '어', '.'],
#  ['아무', '도', '죽', '지', '않', '었', '어', '.'],
#  ['숟가락', '집', '어', '.'],
#  ['그리스', '에', '는', '섬', '이', '많', '다', '.'],
#  ['나', '의', '사과', '주스', '어디', '있', '어', '?'],
#  ['실례', '하', 'ᆸ니다', '.', '출구', '가', '어디', '이', 'ᆫ가', '요', '?'],
#  ['부르', '었', '어', '?'],
#  ['걔', '가', '갑자기', '오', '어서', '우리', '는', '다', '놀라', '었', '어'],
#  ['애석',
#   '하',
#   '게',
#   '도',
#   '우리',
#   '한테',
#   '그거',
#   'ᆯ',
#   '말',
#   '하',
#   '어',
#   '주',
#   'ᆫ',
#   '사람',
#   '이',
#   '없',
#   '었',
#   '어',
#   '.'],
#  ['그', '는', '매우', '빨리', '뛰', 'ᆫ다', '.'],
#  ['떨리', '어요', '.'],
#  ['나', '는', '속', '는', '것', '이', '싫', '다', '.'],
#  ['이', '사진', '일주일', '전', '에', '찍', '었', '어', '.'],
#  ['나', 'ᆫ', '오해', '하', '었', '어', '.'],
#  ['지금', '까지', '너', '에게', '솔직하', '지', '못', '하', '었', '어', '.'],
#  ['나', '는', '왜', '프랑스어', '를', '배우', '어야', '하', '는가', '?'],
#  ['드라이버', '어디', '있', '어', '?'],
#  ['그', '사람', '들', '모두', '틀리', '었', '어', '.'],
#  ['그녀', '는', '발', '이', '작', '다', '.'],
#  ['톰', '이', '머리', '를', '자르', '었', '다', '.'],
#  ['제', '이름', '기억', '하', '시', 'ᆸ니까', '?'],
#  ['가', '자', '!'],
#  ['톰', '을', '잡', '어', '.'],
#  ['나', 'ᆫ', '다시', '혼자', '가', '되', '고', '싶', '지', '않', '어', '.'],
#  ['그것', '을', '하', '시', '기', '를', '권고', '하', 'ᆸ니다', '.'],
#  ['점심', '먹', '을', '시간', '이', '다', '.'],
#  ['시계', '를', '보', '세요', '.'],
#  ['누구', '나', '거짓말', '하', '어', '.'],
#  ['고맙', '어', '.'],
#  ['톰', '이', '졸업', '하', '었', '어', '.'],
#  ['나', '가', '더', '젊', '었', '으면', '좋', '겠', '어', '.'],
#  ['톰', '은', '메리', '의', '곁', '을', '떠나', '었', '다', '.'],
#  ['톰',
#   ',',
#   '메리',
#   ',',
#   '존',
#   ',',
#   '앨리스',
#   '는',
#   '모두',
#   '수영',
#   '을',
#   '하',
#   'ᆯ',
#   '수',
#   '있',
#   '어',
#   '.'],
#  ['불타', '네', '.'],
#  ['톰', '이', '죽', '었', '어', '.'],
#  ['톰', '은', '낙천', '적', '이', '다', '.'],
#  ['나', '는', '프랑스어', '수업', '을', '듣', '고', '있', '어', '.'],
#  ['대략', '너', '가', '침대', '에', '가', '었었', '던', '시간', '이', '야', '.'],
#  ['기름값', '이', '오르', '었', '다', '.'],
#  ['계속', '노래', '하', '어', '.'],
#  ['다시', '하', '어', '.'],
#  ['톰', '은', '심각하', 'ᆫ', '부상', '을', '당하', 'ᆯ', '수', '도', '있', '었', '다', '.'],
#  ['보스턴', '에서', '몇', '년', '동안', '살', '었', '어', '?'],
#  ['톰', '은', '어디', '에', '숨', '어', '있', '어', '?'],
#  ['나', '가', '총', '소리', '를', '듣', '었', '다고', '생각', '하', '었', '어', '.'],
#  ['톰', '은', '나', '가', '로맨틱하', '다고', '생각', '하', '어', '.'],
#  ['전', '에', '만나', '었', '던', '것', '기억', '하', '어요', '.'],
#  ['그', '는', '나', '를', '기다리', '게', '하', '었', '다', '.'],
#  ['그', '들', '이', '메리', '를', '즐겁', '게', '하', '었', '다', '.'],
#  ['너', '빼', '고', '가', '어', '버리', '어서', '미안', '하', '어', '.'],
#  ['너', '는', '너', '의', '손', '으로', '그것', '을', '하', '어야', '하', 'ᆫ다', '.'],
#  ['이', '방', '은', '너무', '크', '어요', '.'],
#  ['톰', '은', '그것', '을', '위하', '어', '달리', '었', '다', '.'],
#  ['너',
#   '진짜',
#   '우리',
#   '가',
#   '돕',
#   '을',
#   '수',
#   '있',
#   '을',
#   '거',
#   '이',
#   '라고',
#   '생각',
#   '하',
#   '어',
#   '?'],
#  ['톰', '은', '재능', '이', '있', '다', '.'],
#  ['나', '는', '솔직', '하', 'ᆫ', '사람', '이', '다', '.'],
#  ['사고', '가', '벌어지', '었', '다', '.'],
#  ['나', 'ᆫ', '너', 'ᆯ', '사랑', '하', 'ᆫ', '적', '이', '없', '어', '.'],
#  ['서두르', '어', ',', '비행기', '놓치', '겠', '어', '.'],
#  ['멈추', '어', '!', '도둑', '이', '야', '!'],
#  ['금방', '돌아오', 'ᆯ', '것', '이', '.'],
#  ['모두', '들', '거기', '있', '을', '거', '이', '야', '.'],
#  ['톰', '도', '메리', '도', '안', '다치', '었', '어', '.'],
#  ['계획', '이', '뭐', '이', '에요', '?'],
#  ['너', '더', '이상', '나', '한테', '화내', '지', '않', '는', '거', '이', '지', '?'],
#  ['차', '를', '바꾸', '어야', '겠', '다', '.'],
#  ['너', '가', '고등', '학교', '선생', '님', '이', '라는', '것', '이', '사실', '이', '니', '?'],
#  ['여기', '정말', '덥', '어', '지', '었', '다', '.'],
#  ['사직',
#   '하',
#   'ᆯ',
#   '것',
#   '을',
#   '생각',
#   '하',
#   '어',
#   '보',
#   'ᆫ',
#   '적',
#   '이',
#   '있',
#   '나요',
#   '?'],
#  ['나무', '가', '타', 'ᆫ다', '.'],
#  ['돕', '어', '주', '어서', '고맙', '어', ',', '톰', '.'],
#  ['우리',
#   '부모',
#   '님',
#   '께서',
#   '는',
#   '나',
#   '를',
#   '배웅',
#   '하',
#   '러',
#   '공항',
#   '에',
#   '오시',
#   '었',
#   '다',
#   '.'],
#  ['톰', '은', '지나', 'ᆫ', '밤', '에', '저녁', '을', '거르', '었', '다', '.'],
#  ['동작', '하', '네', '.'],
#  ['전자', '담배', '는', '얼마나', '안전', '하', '어', '?'],
#  ['나', '는', '이', '오토바이', '가', '얼마', '이', 'ᆫ지', '모르', 'ᆫ다', '.'],
#  ['나', '는', '수감', '되', '었', '다', '.'],
#  ['톰', '은', '애', '같이', '굴', '어', '.'],
#  ['나', '에게', '는', '누나', '가', '있', '다', '.'],
#  ['톰', '은', '그', '산', '을', '올라가', '었', '다', '.'],
#  ['거기', '있', '습니다', '.'],
#  ['이', '사과', '는', '매우', '신선', '하', '어', '보이', 'ᆫ다', '.'],
#  ['모자', '와', '선글라스', '를', '쓰', '는', '것', '이', '좋', '다', '.'],
#  ['차', '를', '새로', '사', 'ᆯ', '생각', '이', '다', '.'],
#  ['조심', '하', '어', '!'],
#  ['너', '좋아하', '어', '?'],
#  ['나',
#   '는',
#   '너',
#   '가',
#   '그렇',
#   '게',
#   '하',
#   '도록',
#   '강요',
#   '하',
#   '지',
#   '는',
#   '않',
#   '겠',
#   '지만',
#   '그렇',
#   '게',
#   '하',
#   '어야',
#   '하',
#   'ᆯ',
#   '거',
#   '이',
#   '야'],
#  ['그', '를', '놓', '어', '주', '어', '.'],
#  ['지금', '나', '를', '유혹', '하', '는', '거', '이', '야', '?'],
#  ['톰', '은', '너무', '늙', '었', '어', '.'],
#  ['이', '길', '이', '어디', '로', '가', '는지', '알리', '어', '주', 'ᆯ래', '?'],
#  ['빨리', ',', '이쪽', '으로', '숨', '어', '!'],
#  ['리눅스', '는', '오픈', '소스', '소프트웨어', '이', '야', '.'],
#  ['당신', '말', '이', '맞', '어요', '.'],
#  ['나', 'ᆫ', '겨울', '이', '좋', '어', '.'],
#  ['나', '는', '독서', '를', '즐기', 'ᆫ다', '.'],
#  ['나', 'ᆫ', '극히', '낯', '을', '가리', '어', '.'],
#  ['이거', '갖', '고', '싶', '어', '.'],
#  ['이렇', '게', '멋지', 'ᆯ', '수', '가', '!'],
#  ['톰', '을', '설득', '하', '려고', '시간', '을', '낭비', '하', '지', '말', '어', '.'],
#  ['계속', '춤추', '고', '있', '어', '보', '어', '.'],
#  ['톰', '은', '마약', '중독자', '가', '알', '냐', '.'],
#  ['저', '는', '아직', '학교', '에', '다니', '어요', '.'],
#  ['톰', '은', '더', '할인', '하', '어', '주', '기', '를', '원하', '었', '다', '.'],
#  ['기분', '이', '훨씬', '낫', '다', '.'],
#  ['이거', 'ᆫ', '부', '정확', '하', '다고', '생각', '하', '어', '.'],
#  ['그', '는', '너무', '빨리', '말', '하', 'ᆫ다', '.'],
#  ['우리', '는', '어제', '즐겁', '게', '지내', '었', '다', '.'],
#  ['너', '의', '행동', '을', '정당화', '하', 'ᆯ', '수', '있', '니', '?'],
#  ['나', '의', '딸', '은', '3', '살', '이', 'ᆯ', '뿐', '이', '야', '.'],
#  ['사실', '상', '우리', '는', '다른', '방법', '이', '없', '다'],
#  ['너', 'ᆫ', '참', '눈치', '가', '빠르', '네', '.'],
#  ['동물', '에게', '영혼', '이', '있', '다고', '생각', '하', '어', '?'],
#  ['아', '제발', '!'],
#  ['나', 'ᆫ', '갑자기', '너무', '걱정', '이', '되', '었', '어', '.'],
#  ['걔', '언제', '오', 'ᆯ지', '모르', '겠', '어'],
#  ['나', '너무', '뚱뚱', '하', '어', '.'],
#  ['톰', '은', '벽', '을', '세우', '고', '있', '다', '.'],
#  ['그것', '이', '나', '의', '유일', '하', 'ᆫ', '관심사', '이', '야', '.'],
#  ['그', '사람', '은', '충동', '적', '으로', '얘기', '하', '어', '.'],
#  ['만일',
#   '너',
#   '의',
#   '사정',
#   '도',
#   '잘',
#   '모르',
#   '는',
#   '사람',
#   '이',
#   '원어민',
#   '같',
#   '다고',
#   '말',
#   '하',
#   'ᆫ다면',
#   '그거',
#   'ᆫ',
#   '그',
#   '사람',
#   '이',
#   '너',
#   '가',
#   '원어민',
#   '이',
#   '아니',
#   '라고',
#   '깨닫',
#   '게',
#   '하',
#   '어',
#   '주',
#   '는',
#   '뭐',
#   '이',
#   'ᆫ가',
#   '를',
#   '네',
#   '말',
#   '속',
#   '에서',
#   '캐치',
#   '하',
#   '어',
#   '내',
#   'ᆫ',
#   '것',
#   '이',
#   '겠',
#   '지',
#   '.',
#   '다르',
#   '게',
#   '표현',
#   '하',
#   '자면',
#   '너',
#   'ᆫ',
#   '원어민',
#   '처럼',
#   '말',
#   '하',
#   '지',
#   '않',
#   '어',
#   '.'],
#  ['제발', '진정하', '어', '.'],
#  ['그것', '은', '보스턴', '에서', '일어나', '었', '습니다', '.'],
#  ['톰', '은', '달리기', '선수', '이', '야', '.'],
#  ['톰', '은', '맥주', '를', '마시', 'ᆫ다', '.'],
#  ['너',
#   '가',
#   '아직',
#   '만나',
#   'ᆫ',
#   '적',
#   '없',
#   '는',
#   '여자',
#   '애',
#   '들',
#   '도',
#   '여기',
#   '있',
#   '어',
#   '?'],
#  ['잠', '이', '오', '어', '.'],
#  ['대부분', '의', '사람', '들', '은', '나', '가', '미치', '었', '다고', '생각', '하', '어'],
#  ['그', '호수', '의', '오래', '되', 'ᆫ', '교회', '는', '정말', '아름답', '다', '.'],
#  ['아무', '도', '안', '오', '었', '어', '.'],
#  ['너', 'ᆫ', '왜', '맨날', '학교', '에', '늦', '니', '?'],
#  ['얼마나', '깊', '게', '?'],
#  ['공격', '!'],
#  ['아무', '에게', '도', '듣', '어', '보', 'ᆫ', '적', '이', '없', '어', '.'],
#  ['나', '도', '캐나다', '사람', '이', '에요', '.'],
#  ['재미없', '는', '부분', '은', '건너뛰', 'ᆸ시다', '.'],
#  ['너', '거기', '있', '어', '?'],
#  ['나', '가', '직접', '먹', '을', '것', '을', '사', '었', '다', '.'],
#  ['계속', '말', '하', '고', '있', '어', '보', '어', '.'],
#  ['나', '는', '너', '의', '이름', '이', '마음', '에', '들', '지', '않', '는다', '.'],
#  ['우리', '는', '곧', '진실', '을', '알', '게', '되', 'ᆯ', '거', '이', '야', '.'],
#  ['톰', '은', '이해', '하', '고', '있', '다는', '듯이', '고개', '를', '끄덕이', '었', '다', '.'],
#  ['커피', '와', '차', '중', '에', '어떤', '거', 'ᆯ', '들', '시', '겠', '어요', '?'],
#  ['나', 'ᆫ', '혼자', '서', '먹', '는', '것', '을', '싫어하', '어', '.'],
#  ['톰',
#   '은',
#   '때때로',
#   '같이',
#   '운동',
#   '하',
#   '자고',
#   '조르',
#   '어',
#   '대',
#   '었',
#   '지만',
#   '나',
#   '는',
#   '정말',
#   '운동',
#   '에',
#   '관심',
#   '이',
#   '없',
#   '다',
#   '.'],
#  ['지하철', '로', '가', '는', '길', '좀', '가르치', '어', '주', 'ᆯ', '수', '있', '어', '?'],
#  ['물', '좀', '마시', '어', '.'],
#  ['너', '의', '속임수', '에', '넌더리', '가', '나', 'ᆫ다', '.'],
#  ['그', '를', '알', '고', '계시', '었', '어요', '?'],
#  ['이', '이미', '떠나', 'ᆫ', '거', '이', 'ᆫ지', '궁금', '하', '어요', '.'],
#  ['톰', '은', '종이', '를', '접', '어', '메리', '에게', '건네', '었', '다', '.'],
#  ['나', '한테', '파일', '주', '어', '.'],
#  ['당신', '은', '무엇', '을', '하', '고', '있', '습니까', '?'],
#  ['나', '는', '지나', 'ᆫ', '주말', '에', '스키', '를', '타', '었', '다', '.'],
#  ['톰', '은', '나이', '에', '비하', '어', '키', '가', '작', '지', '.'],
#  ['다윈', '의', '진화', '이론', '을', '공부', '하', '어', '보', 'ᆫ', '적', '있', '어', '?'],
#  ['환영', '하', 'ᆸ니다', '.'],
#  ['톰', '이', '메리', '가', '뭐', 'ᆯ', '원하', '는지', '굼금', '하', '어', '하', '더라', '.'],
#  ['그', '는', '희', 'ᆫ', '옷', '을', '입', '고', '있', '다', '.'],
#  ['어디', '서', '살', 'ᆯ', '거', '이', '야', '?'],
#  ['기억', '나', '어', '?'],
#  ['잠깐', '만', '!'],
#  ['톰', '이랑', '메리', '는', '한', '때', '친구', '이', '었었', '지', '?'],
#  ['이것', '을', '원하', '시', 'ᆸ니까', '?'],
#  ['나',
#   'ᆫ',
#   '톰',
#   '이',
#   '저런',
#   '거',
#   'ᆯ',
#   '하',
#   'ᆯ',
#   '수',
#   '있',
#   '으리라고',
#   '생각',
#   '하',
#   '지',
#   '않',
#   '어',
#   '.'],
#  ['아마', '너', '는', '톰', '에게', '말', '하', '어야', '하', '어', '.'],
#  ['가만히', '있', '어', '.'],
#  ['나', '는', '죽', '는', '것', '이', '두렵', '다', '.'],
#  ['나', '가', '들어오', '어도', '되', 'ᆯ까', '?'],
#  ['톰', '이', '박수', '치', '었', '어', '.'],
#  ['춤추', '는', '것', '은', '질리', '었', '어', '.'],
#  ['나',
#   '는',
#   '토마토',
#   '를',
#   '먹',
#   '지',
#   '말',
#   'ᆫ',
#   '톰',
#   '은',
#   '먹',
#   '지',
#   '않',
#   '는다',
#   '.'],
#  ['우리',
#   '에게',
#   '이',
#   '모든',
#   '거',
#   'ᆯ',
#   '주',
#   'ᆫ',
#   '사람',
#   '이',
#   '바로',
#   '당신',
#   '이',
#   '다',
#   '.'],
#  ['계속', '땅', '파', '고', '있', '어', '보', '어', '.'],
#  ['톰',
#   '은',
#   '남',
#   '어',
#   '있',
#   '어도',
#   '되',
#   '어',
#   '.',
#   '너희',
#   '나머지',
#   '는',
#   '나가',
#   '어야',
#   '하',
#   '어',
#   '.'],
#  ['왼쪽', '으로', '돌', '어', '.'],
#  ['톰', '은', '메리', '를', '2013', '년', '에', '만나', '었', '어', '.'],
#  ['톰', '이', '헉', '소리', '를', '내', '었', '어', '.'],
#  ['계란', '값', '이', '오르', '었', '다', '.'],
#  ['그', '는', '단지', '시간', '을', '때우', '고', '있', '을', '뿐', '이', '다', '.'],
#  ['그녀', '는', '차', '한', '잔', '을', '주문', '하', '었', '다', '.'],
#  ['그', '는', '매우', '돈', '이', '많', '다고', '하', 'ᆫ다', '.'],
#  ['톰', '은', '읽', '을', '수', '있', '지', '?'],
#  ['모든',
#   '말',
#   '들',
#   '이',
#   '동등',
#   '하',
#   '게',
#   '태어나',
#   'ᆫ',
#   '거',
#   'ᆫ',
#   '아니',
#   '야',
#   '.',
#   '몇몇',
#   '은',
#   '이기',
#   '기',
#   '위하',
#   '어',
#   '태어나',
#   '었',
#   '어',
#   '.'],
#  ['나', '는', '소설', '번역', '은', '더', '이상', '안', '하', 'ᆯ', '거', '이', '야', '.'],
#  ['담배', '를', '줄이', '시', '어야', '하', '어요', '.'],
#  ['더', '빨리', '하', 'ᆯ수록', '좋', '다', '.'],
#  ['이해', '하', '어', '.'],
#  ['그녀', '는', '대범', '하', '다', '.'],
#  ['너', '가', '어제', '톰', '에게', '말', '하', '었', '지', '?'],
#  ['톰', '은', '꽤', '의욕', '있', '어', '.'],
#  ['누구', '나', '사랑', '받', '고', '싶', '어', '하', '어', '.'],
#  ['나', 'ᆫ', '가장', '최소한', '의', '정도', '만', '하', '었', '어', '.'],
#  ['일요일', '에', '뭐', '하', 'ᆯ', '거', '이', '야', '?'],
#  ['톰', '은', '책', '이', '흥미', '롭', '었', '다고', '말', '하', '었', '다', '.'],
#  ['그녀', '는', '근처', '에', '살', 'ᆫ다', '.'],
#  ['메리',
#   '가',
#   '보스턴',
#   '에',
#   '세',
#   '번',
#   '이나',
#   '가',
#   '었',
#   '다고',
#   '톰',
#   '이',
#   '말',
#   '하',
#   '더라',
#   '.'],
#  ['재밌', '잖아', '!'],
#  ['톰', '은', '나이', '에', '비하', '어', '키', '가', '크', '지', '않', '어', '.'],
#  ['그것', '이', '너', '가', '하', '고', '싶', '은', '말', '전부', '이', '니', '?'],
#  ['나', 'ᆫ', '고양이', '동영상', '에', '질리', '었', '어', '.'],
#  ['그거', 'ᆫ', '나', '의', '사전', '이', '야', '.'],
#  ['톰', '은', '메리', '이', '라는', '캐나다인', '과', '결혼', '하', '었', '어', '.'],
#  ['서두르', '어', ',', '학교', '늦', '겠', '다', '.'],
#  ['그', '의', '연설', '이', '길', '어서', '우리', '모두', '가', '지루', '하', '었', '다', '.'],
#  ['우리', '는', '톰', '이', '겪', '고', '있', '는', '것', '을', '알', '고', '있', '다', '.'],
#  ['나', '가', '입', '을', '열', '어서', '미안', '하', '어', '.'],
#  ['나',
#   '는',
#   '너',
#   '의',
#   '고양이',
#   '가',
#   '좋',
#   '은데',
#   ',',
#   '너',
#   '의',
#   '고양이',
#   '는',
#   '나',
#   '를',
#   '싫어하',
#   '네',
#   '.'],
#  ['차', '에', '타', '어', '.'],
#  ['너',
#   '가',
#   '아무것',
#   '도',
#   '안',
#   '먹',
#   '고',
#   '싶',
#   '어',
#   '하',
#   'ᆫ다고',
#   '생각',
#   '하',
#   '었',
#   '어',
#   '.'],
#  ['톰', '은', '좀', '소심하', 'ᆫ', '것', '같', '지', '않', '어', '?'],
#  ['무엇', '이', '외로움', '을', '부르', '어', '일으키', '어', '?'],
#  ['톰', '이', '돕', '어', '주', '리라는', '것', '을', '어떻', '게', '알', '었', '니', '?'],
#  ['이거', 'ᆫ', '싸우', 'ᆯ', '가치', '가', '있', '는', '결투', '이', '야', '.'],
#  ['그것', '은', '나', '의', '책임', '이', '다', '.'],
#  ['지금', '떠나', '야', '하', 'ᆫ다', '.'],
#  ['나', '는', '교사', '가', '아니', '다', '.'],
#  ['돌', '어', '.'],
#  ['어제', '나', '는', '집', '에', '있', '었', '어', '.'],
#  ['톰', '이', '익사', '하', '었', '어', '.'],
#  ['펠리컨', '은', '크', 'ᆫ', '부리', '를', '갖', '고', '있', '다', '.'],
#  ['톰', '은', '자살', '을', '시도', '하', '었', '다', '.'],
#  ['톰', '은', '집', '을', '다시', '페인트칠', '하', '기', '로', '마음먹', '었', '다', '.'],
#  ['우리', '한테', '필요', '하', 'ᆫ', '거', 'ᆫ', '휴식', '이', '야', '.'],
#  ['우리', '할아버지', '는', '5', '년', '전', '에', '돌아가', '시', '었', '다', '.'],
#  ['우리', 'ᆫ', '기다리', '었', '어', '.'],
#  ['나', '는', '웃', '었', '어', '.'],
#  ['나', '도', '나', '의', '자신', '을', '싫어하', '어', '.'],
#  ['우리', '모두', '보스턴', '출신', '이', '다', '.'],
#  ['톰',
#   '이',
#   '그거',
#   'ᆯ',
#   '하',
#   '었',
#   '다는',
#   '사실',
#   '은',
#   '부인',
#   '하',
#   'ᆯ',
#   '수',
#   '없',
#   '는',
#   '사실',
#   '이',
#   '야',
#   '.'],
#  ['이거', '가지', '어', '.'],
#  ['그', '에게', '기다리', '라고', '말', '하', '어', '주', '세요', '.'],
#  ['생각', '좀', '하', '어', '보', '어', '.'],
#  ['아프', '지', '않', '어', '.'],
#  ['톰', '은', '그만두', '고', '싶', '어', '하', 'ᆫ다', '.'],
#  ['나', 'ᆫ', '그거', 'ᆯ', '먹', '지', '말', '었', '어야', '하', '었', '어', '.'],
#  ['울', '는', '거', '이', '야', '?'],
#  ['톰', '은', '프랑스어', '를', '가르치', 'ᆫ', '경험', '이', '있', '어', '.'],
#  ['톰',
#   '은',
#   '개',
#   '한',
#   '마리',
#   '와',
#   '고양이',
#   '세',
#   '마리',
#   '를',
#   '키우',
#   '고',
#   '있',
#   '어',
#   '.'],
#  ['당신', '에게', '하', 'ᆫ', '시간', '이', '주어지', '었', '습니다', '.'],
#  ['우리',
#   '에게',
#   'ᆫ',
#   '그런',
#   '종류',
#   '의',
#   '바이러스',
#   '가',
#   '존재',
#   '하',
#   '는지',
#   '증거',
#   '가',
#   '없',
#   '어',
#   '.'],
#  ['물리', '는', '수학', '보다', '훨씬', '더', '어렵', '어', '.'],
#  ['그',
#   '소녀',
#   '들',
#   '은',
#   '내일',
#   '테니스',
#   '를',
#   '치',
#   '고',
#   '싶',
#   '어',
#   '하',
#   '지',
#   '않',
#   '는다',
#   '.'],
#  ['나', '는', '그것', '을', '구매', '하', 'ᆯ', '것', '이', '다', '.'],
#  ['가만히', '있', '으세요', '.'],
#  ['자살', '은', '고통', '스럽', '지', '않', '어', '.'],
#  ['나', '는', '모르', '어요', '.'],
#  ['사실', '우리', '는', '선택', '의', '여지', '가', '없', '다'],
#  ['톰', '은', '쿠키', '이', '라는', '강아지', '를', '키우', '고', '있', '어', '.'],
#  ['톰', '은', '메리', '를', '화나', '게', '하', '었', '어', '.'],
#  ['오늘', '약간', '머리', '가', '아프', '다', '.'],
#  ['도망', '치', 'ᆫ다', '.'],
#  ['나', '정말', '슬프', '어', '.'],
#  ['톰', '은', '운전', '면허', '시험', '에', '떨어지', 'ᆯ', '듯', '하', '다', '.'],
#  ['고양이', '는', '인간', '이', '아니', '야', '.'],
#  ['톰', '은', '다', '국어', '사용', '자', '이', '야', '.'],
#  ['그', '사람', '은', '꽃', '에', '물', '을', '주', '고', '있', '어', '.'],
#  ['나',
#   '가',
#   '어리',
#   'ᆯ',
#   '때',
#   '는',
#   '바다',
#   '에',
#   '수영',
#   '하',
#   '러',
#   '가',
#   '곤',
#   '하',
#   '었었',
#   '지',
#   '.'],
#  ['그', '는', '아침', '식사', '를', '하', '러', '내려오', '었', '다', '.'],
#  ['너', '는', '나', '의', '것', '을', '가지', 'ᆯ', '수', '있', '다', '.'],
#  ['톰',
#   '은',
#   '업계',
#   '에서',
#   '가장',
#   '존경',
#   '받',
#   '는',
#   '남성',
#   '중',
#   '한',
#   '사람',
#   '이',
#   '야',
#   '.'],
#  ['바구니', '에', '사과', '몇', '개', '가', '있', '다', '.'],
#  ['나', 'ᆫ', '말', '한', '마리', '를', '사', '었', '어', '.'],
#  ['나', '가', '이해', '하', '지', '못하', '는', '것', '이', '너무', '많', '어'],
#  ['나', '는', '과일', '을', '집', '어', '들', 'ᆫ', '사람', '이', '아니', '다', '.'],
#  ['진정하', '어', '!'],
#  ['오스트레일리아', '의', '사진', '이', '있', '나요', '?'],
#  ['늦', '어서', '미안', '하', '어', '.'],
#  ['우리', '가', '톰', '을', '돕', '을', '필요', '가', '있', '을', '수', '도', '있', '다', '.'],
#  ['그', '의', '국적', '은', '무엇', '이', 'ᆸ니까', '?'],
#  ['우리', 'ᆫ', '포기', '하', '지', '말', '었', '어야', '하', '었', '어', '.'],
#  ['너', 'ᆫ', '나', '의', '거', '이', '야', '.'],
#  ['톰', '은', '자폐증', '과', '심각하', 'ᆫ', '우울증', '으로', '진단', '받', '었', '어', '.'],
#  ['"', '누구', '이', '야', '?', '"', '"', '나', '이', '다', '"'],
#  ['톰',
#   '을',
#   '제외',
#   '하',
#   'ᆫ',
#   '가족',
#   '구성원',
#   '들',
#   '전부',
#   '프랑스어',
#   '를',
#   '하',
#   'ᆯ',
#   '수',
#   '있',
#   '어요',
#   '.'],
#  ['모두', '미소', '짓', '었', '어', '.'],
#  ['나', 'ᆫ', '거미', '안', '무섭', '어', '.'],
#  ['그', '사람', '은', '미혼', '이', '야', '.'],
#  ['그것',
#   '이',
#   '우연',
#   '이',
#   '아니',
#   '었',
#   '다는',
#   '것',
#   '을',
#   '알',
#   '고',
#   '있',
#   '었',
#   '어',
#   '.'],
#  ['이', '문장', '은', '무슨', '뜻', '이', 'ᆫ가', '요', '?'],
#  ['톰', '은', '항상', '나', '보다', '바쁘', '다', '.'],
#  ['이렇게', '귀엽', '다니', '!'],
#  ['조금', '만', '더', '느리', '게', '말씀', '하', '어', '주', '시', '겠', '어요', '?'],
#  ['오렌지', '는', '많', '은', '비타민', '르', 'ᆯ', '함유', '하', '고', '있', '다', '.'],
#  ['그', '는', '크', 'ᆫ', '바위', '뒤', '에', '숨', '었', '다', '.'],
#  ['왜', '이렇', '게', '행동', '하', '는', '거', '이', '야', '?'],
#  ['뇌', '를', '이식', '하', '는', '것', '이', '정말로', '가능', '하', '어', '?'],
#  ['톰', '이', '셔츠', '를', '뒤집', '어', '입', '었', '어', '.'],
#  ['우리', '오늘', '밤', '에', '파티', '가', '있', '어', '.'],
#  ['많', '은', '사람', '들', '은', '크리스마스', '때', '칠면조', '를', '먹', '어', '.'],
#  ['톰', '은', '지', '는', '것', '을', '싫어하', 'ᆫ다', '.'],
#  ['나', '는', '혼나', '고', '싶', '지', '않', '었', '어', '.'],
#  ['아무', '도', '나', '를', '도와주', '지', '않', '었', '다', '.'],
#  ['그거', 'ᆫ', '너', '가', '생각', '하', '는', '만큼', '어렵', '은', '거', 'ᆫ', '아냐', '.'],
#  ['톰', '은', '언제', '떠나', '어', '?'],
#  ['노예', '제도', '는', '반', '인륜', '적', '이', 'ᆫ', '범죄', '이', '야', '.'],
#  ['이거', 'ᆫ', '톰', '탓', '이', '야', '.'],
#  ['나', 'ᆫ', '고등학교', '에서', '인기', '가', '있', '었', '어', '.'],
#  ['나', '는', '답장', '을', '기다리', '고', '있', '다', '.'],
#  ['나',
#   'ᆫ',
#   '톰',
#   '이',
#   '메리',
#   '한테',
#   '조언',
#   '을',
#   '안',
#   '하',
#   '었',
#   '으면',
#   '좋',
#   '겠',
#   '어',
#   '.'],
#  ['나', '는', '집', '에', '있', '다', '.'],
#  ['나', '는', '나', '의', '자신', '이', '싫', '어', '.'],
#  ['너',
#   '가',
#   '고양이',
#   '알레르기',
#   '가',
#   '있',
#   '다는',
#   '거',
#   'ᆯ',
#   '톰',
#   '이',
#   '나',
#   '한테',
#   '말',
#   '하',
#   '었',
#   '어',
#   '.'],
#  ['그', '은행', '은', '어디', '에', '있', '어요', '?'],
#  ['이거', '가짜', '이', '야', '?'],
#  ['톰', '은', '얼굴', '을', '찡그리', '었', '어', '.'],
#  ['정말', '수영', '하', 'ᆯ', '줄', '모르', '어', '?'],
#  ['아무', '도', '일', '하', '고', '싶', '어', '하', '지', '않', '는다', '.'],
#  ['손대', '지', '말', '어', '.'],
#  ['톰', '은', '나', '보다', '돈', '이', '많', '어', '.'],
#  ['톰', '이', '그만두', '어', '.'],
#  ['이', '애', '는', '나', '의', '아기', '이', '다', '.'],
#  ['너',
#   '의',
#   '아버지',
#   '가',
#   '어머니',
#   '에게',
#   '만약',
#   '프랑스어',
#   '로',
#   '질문',
#   '을',
#   '하',
#   '면',
#   '그녀',
#   '는',
#   '프랑스어',
#   '로',
#   '대답',
#   '하',
#   '니',
#   '아니',
#   '면',
#   '영어',
#   '로',
#   '대답',
#   '하',
#   '니',
#   '?'],
#  ['우리', '는', '그', '문제', '를', '일', '주일', '안', '에', '해결', '하', '었', '다', '.'],
#  ['네', '손', '이', '얼음', '처럼', '차갑', '어', '.'],
#  ['톰', '이', '크리스마스', '트리', '아래', '에', '선물', '을', '놓', '었', '어', '.'],
#  ['계속', '집중', '하', '고', '있', '어', '보', '어', '.'],
#  ['나', 'ᆫ', '수박', '좋', '어', '하', '어', '.'],
#  ['흠',
#   ',',
#   '너',
#   '는',
#   '확실히',
#   '톰',
#   '에게',
#   '연애',
#   '감정',
#   '을',
#   '가지',
#   '고',
#   '있',
#   '군',
#   '.'],
#  ['왜', '안', '되', '어', '?'],
#  ['톰',
#   '은',
#   '더',
#   '이상',
#   '기다리',
#   '고',
#   '싶',
#   '지',
#   '않',
#   '다고',
#   '말',
#   '하',
#   '었',
#   '다',
#   '.'],
#  ['그것', '이', '나', '가', '보', 'ᆯ', '수', '있', '는', '것', '의', '전부', '이', '야', '.'],
#  ['우리', 'ᆫ', '기억', '하', '고', '있', '어', '.'],
#  ['이제', '다시', '기억', '이', '나', '네요', '.'],
#  ['톰', '과', '메리', '는', '가깝', '은', '친척', '이', '야', '.'],
#  ['톰', '은', '지', '기', '싫어하', 'ᆫ다', '.'],
#  ['너', '가', '그거', 'ᆯ', '하', '기', '전', '에', '톰', '한테', '물어보', '었', '어야지', '.'],
#  ['머리', '가', '아프', '어요', '.'],
#  ['그', '는', '그', '여자', '에게', '인사', '를', '건네', '었', '다', '.'],
#  ['반역자', '들', '이', '수도', '를', '점령', '하', '었', '다', '.'],
#  ['그녀', '는', '계란', '12', '개', '짜리', '두', '판', '을', '구매', '하', '었', '다', '.'],
#  ['미안', '하', 'ᆫ데', ',', '나', '바쁘', '어', '.'],
#  ['톰', '이', '물', '에', '빠지', '어', '죽', '었', '어', '.'],
#  ['이', '건물', '의', '지붕', '은', '초록색', '이', '야', '.'],
#  ['침술', '이', '정말로', '효과', '가', '있', '을까', '?'],
#  ['나', '는', '이유', '없이', '슬프', '었', '어', '.'],
#  ['나', '는', '한때', '헤로인', '중독자', '이', '었', '어', '.'],
#  ['톰', '은', '한때', '경찰', '이', '었었', '어', '.'],
#  ['너무', '좋', '어', '!'],
#  ['톰', '이', '빠져나가', '었', '어', '.'],
#  ['나', 'ᆫ', '오후', '에', '는', '집', '에', '있', '을려고', '.'],
#  ['항상', '너', '의', '자료', '를', '인용', '하', '도록', '하', '어', '.'],
#  ['그', '사람', '들', '은', '나', 'ᆯ', '믿', '어', '.'],
#  ['마지막', '피자', '한', '조각', '나', '가', '먹', '어도', '되', '어', '?'],
#  ['나', 'ᆫ', '프랑스인', '학생', '이', '야', '.'],
#  ['나',
#   'ᆫ',
#   '톰',
#   '이',
#   '내년',
#   '에',
#   '어디',
#   '에',
#   '살',
#   'ᆯ',
#   '것',
#   '이',
#   'ᆫ지',
#   '는',
#   '모르',
#   '겠',
#   '어',
#   '.'],
#  ['우선', '손', '부터', '씻', '어', '.'],
#  ['식물', '의', '모든', '부분', '이', '향기', '롭', '다', '.'],
#  ['너', 'ᆫ', '왜', '그렇', '게', '애', '같이', '굴', '어', '?'],
#  ['혼자', '서', '오', '어', '.'],
#  ['뱀', '들', '은', '냉혈동물', '이', '다', '.'],
#  ['저기', '를', '보', '어', '.'],
#  ['나', '는', '어제', '단지', '출근', '하', 'ᆯ', '수', '없', '었', '어', '.'],
#  ['나', '는', '톰', '을', '구하', '려고', '노력', '하', '었', '어', '.'],
#  ['너', '는', '어떤', '기분', '이', '니', '?'],
#  ['톰', '이', '대답', '하', '었', '어', '.'],
#  ['나', 'ᆫ', '이', '학교', '를', '좋아하', '어', '.'],
#  ['나', '는', '지나', 'ᆫ', '3', '년', '동안', '오스트레일리아', '에서', '살', '었', '다', '.'],
#  ['이', '보다', '더', '나쁘', 'ᆯ', '수', '는', '없', '었', '어', '.'],
#  ['달', '을', '보', '어', '.'],
#  ['뭐', '이', '라고', '하', '시', '었', '나요', '?'],
#  ['어제', '는', '좋', '은', '날', '이', '었', '다', '.'],
#  ['톰', '이', '아프', '어요', '.'],
#  ['뭐', '알', '어', '내', 'ᆫ', '거', '있', '어', '?'],
#  ['이것', '을', '나', '에게', '팩스', '로', '보내', '어', '주', '세요', '.'],
#  ['조용히', '하', '어', '주', '어', '.'],
#  ['톰', '은', '홀로', '앉', '었', '다', '.'],
#  ['신', '은', '존재', '하', '어', '.'],
#  ['톰', '이', '왜', '저러', '는지', '말', '하', '어', '주', 'ᆯ', '수', '있', '어', '?'],
#  ['나', '이제', '이해', '하', 'ᆫ', '것', '같', '어', '.'],
#  ['나', 'ᆫ', '톰', '이', '호주', '에', '가', '었', '으면', '하', '었', '어', '.'],
#  ['당신',
#   '은',
#   '그',
#   '여자',
#   '에게',
#   '거리',
#   '를',
#   '두',
#   '고',
#   '지내',
#   'ᆫ',
#   '것',
#   '에',
#   '대하',
#   '어',
#   '사과',
#   '하',
#   '어야',
#   '하',
#   'ᆫ다',
#   '.'],
#  ['누구', '가', '알', '어', '?'],
#  ['이것', '을', '뭐', '이', '라고', '부르', '어요', '?'],
#  ['실용',
#   '적',
#   '관점',
#   '으로',
#   '보',
#   '려고',
#   '노력',
#   '하',
#   '어야',
#   '하',
#   'ᆯ',
#   '것',
#   '같',
#   '어',
#   '.'],
#  ['나',
#   '가',
#   '하',
#   'ᆫ',
#   '것',
#   '이',
#   '틀리',
#   '었',
#   '다고',
#   '는',
#   '생각',
#   '하',
#   '지',
#   '않',
#   '었',
#   '어',
#   '.'],
#  ['저',
#   '여자',
#   '애',
#   '는',
#   '자기',
#   '가',
#   '공주',
#   '이',
#   '라는',
#   '망상',
#   '에',
#   '빠지',
#   '어',
#   '있',
#   '어',
#   '.'],
#  ['독일어', '문법', '에', '어려움', '을', '겪', '는', '중', '이', '야', '.'],
#  ['너', '의', '반', '에', '한국', '에서', '오', 'ᆫ', '학생', '이', '있', '니', '?'],
#  ['나', '는', '잠', '을', '잘', '자', '었', '다', '.'],
#  ['톰', '은', '오늘', '밤', '거기', '있', '을', '거', '이', '야', '.'],
#  ['나',
#   '가',
#   '그거',
#   'ᆯ',
#   '하',
#   'ᆯ',
#   '수',
#   '있',
#   '는',
#   '유일',
#   '하',
#   'ᆫ',
#   '사람',
#   '이',
#   '군',
#   '.'],
#  ['더', '빨리', '하', 'ᆯ수록', '좋', '다', '.'],
#  ['여름', '방학', '을', '어디', '서', '보내', '시', '었', '어요', '?'],
#  ['의심', '하', '어서', '정말', '미안', '하', '어', '.'],
#  ['와', '!', '오랜만', '이', '다', '.'],
#  ['지금', '바쁘', '어', '?'],
#  ['그', '버스', '가', '출발', '하', 'ᆫ', '지', '얼마나', '지나', '었', '습니까', '?'],
#  ['우울', '하', '어', '.'],
#  ['사고', '는', '부', '주의', '에서', '벌어지', '기', '마련', '이', '다', '.'],
#  ['이번', '여름', '방학', '때', '어디', '가', '고', '싶', '어', '?'],
#  ['톰',
#   '은',
#   '메리',
#   '가',
#   '무엇',
#   '을',
#   '하',
#   '는지',
#   '알아채',
#   '지',
#   '못',
#   '하',
#   '었',
#   '다',
#   '.'],
#  ['톰', '은', '싱글', '대디', '이', '야', '.'],
#  ['그만', '웃', '어', '.'],
#  ['톰', '이', '여기', '에', '있', '기', 'ᆯ', '두렵', '어', '하', '었', '어', '.'],
#  ['나', 'ᆫ', '유럽', '에', '가', '지', '않', '기', '로', '하', '었', '다', '.'],
#  ['나', '는', '아파트', '에서', '살', 'ᆫ다', '.'],
#  ['이것', '이', '무슨', '뜻', '이', 'ᆫ지', '알', '겠', '어요', '?'],
#  ['내일', '절', '에', '한', '번', '가', '어', '보', '자', '.'],
#  ['그',
#   '프로젝트',
#   '에',
#   '대하',
#   '어',
#   '나',
#   'ᆫ',
#   '아직',
#   '긍정',
#   '적',
#   '이',
#   'ᆫ',
#   '입장',
#   '이',
#   '야',
#   '.'],
#  ['나', 'ᆯ', '용서', '하', '어', '주', '리라고', '알', '고', '있', '어', '.'],
#  ['톰', '은', '거짓말', '쟁이', '가', '아니', '야', '.'],
#  ['그거', 'ᆫ', '너', '의', '편지', '를', '받', '기', '전', '에', '일어나', '었', '어', '.'],
#  ['톰', '이', '할아버지', '이', '라니', '믿', '을', '수', '없', '어', '.'],
#  ['정규직', '이', '임시직', '보다', '낫', '어', '.'],
#  ['나', '는', '도서관', '에서', '종종', '책', '을', '빌리', 'ᆫ다', '.'],
#  ['말',
#   '은',
#   '멈추',
#   '고',
#   '나',
#   '어서',
#   '움직이',
#   '는',
#   '거',
#   'ᆯ',
#   '거부',
#   '하',
#   '었',
#   '어',
#   '.'],
#  ['나', 'ᆫ', '프랑스', '소설', '은', '읽', '지', '않', '어', '.'],
#  ['톰', '이', '우리', '에게', '거짓말', '을', '하', '었', '다', '.'],
#  ['나', '는', '어제', '죽', '을', '뻔', '하', '었', '어', '.'],
#  ['동의', '하', '어', '.'],
#  ['우리', 'ᆯ', '왜', '따라오', '는', '거', '이', '야', '?'],
#  ['톰',
#   '이',
#   '웃',
#   '은',
#   '거',
#   'ᆯ',
#   '한',
#   '번',
#   '이',
#   '라도',
#   '보',
#   'ᆫ',
#   '적',
#   '있',
#   '어',
#   '?'],
#  ['저', '사람', '알', '어', '?'],
#  ['그거', 'ᆫ', '무슨', '언어', '이', '었', '지', '?'],
#  ['프랑스어', '하', 'ᆯ', '줄', '알', '는', '사람', '알', '세요', '?'],
#  ['그거', 'ᆫ', '사실', '이', '아니', '었', '다', '.'],
#  ['그녀', '에게', '는', '조그맣', 'ᆫ', '빵', '하나', '가', '있', '다', '.'],
#  ['톰', '이', '외롭', '다는', '거', 'ᆯ', '알', '고', '계시', '나요', '?'],
#  ['나', 'ᆫ', '이', '셔츠', '는', '사', '지', '않', '겠', '어', '.'],
#  ['이거', 'ᆯ', '가지', '어', '.'],
#  ['나', '어', '심각', '하', 'ᆫ', '중독자', '이', 'ᆫ', '것', '같', '어', '.'],
#  ['그거', 'ᆫ', '너', '가', '생각', '하', '는', '만큼', '어렵', '은', '거', 'ᆫ', '아냐', '.'],
#  ['톰', '은', '나', '가', '들리', '었', '을', '때', '없', '었', '다', '.'],
#  ['톰', '은', '진짜', '안전', '하', 'ᆯ', '거', '이', '라니까', '.'],
#  ['햄버거', '얼마나', '사', '었', '어', '?'],
#  ['톰', '파티', '에', '가', '었었', '어야지', '.'],
#  ['더', '간단하', '게', '설명', '하', '어', '주', '어', '.'],
#  ['톰', '이', '지각', '하', 'ᆯ', '거', '이', '라고', '예상', '하', '고', '있', '어', '?'],
#  ['질문', '이', '있', '다', '.'],
#  ['안녕', '!'],
#  ['왜', '나', '이', '야', '?'],
#  ['톰', '은', '요리', '를', '엄청', '잘', '하', 'ᆫ다', '.'],
#  ['나', '의', '생각', '에', 'ᆫ', '톰', '은', '지금', '오스트레일리아', '에', '없', '어', '.'],
#  ['그거',
#   'ᆫ',
#   '니',
#   '가',
#   '앉',
#   '어',
#   '있',
#   '는',
#   '가지',
#   '를',
#   '치',
#   '어',
#   '내',
#   '는',
#   '꼴',
#   '이',
#   '야',
#   '.'],
#  ['노래', '부탁', '하', '어', '.'],
#  ['잠', '이', '약', '보다', '낫', '다', '.'],
#  ['알', '어', '.'],
#  ['톰', '은', '나이', '에', '비하', '어', '키', '가', '크', '어', '.'],
#  ['톰', '은', '이미', '떠나', '었', '다', '.'],
#  ['장례식', '은', '어제', '이', '었', '다', '.'],
#  ['나', '는', '톰', '이', '뛰어나', '다고', '생각', '하', 'ᆫ다', '.'],
#  ['톰', '이', '물', '속', '으로', '뛰', '어', '들', '지', '않', '었', '어', '.'],
#  ['물', '한잔', '주', '세요', '.'],
#  ['아버지', '말', '좀', '듣', '어', '.'],
#  ['너', '의', '모습', '을', '드러내', '어', '.'],
#  ['톰', '은', '좀', '불안', '하', '어', '하', '고', '있', '어', '.'],
#  ['톰', '은', '선교사', '로서', '한국', '에', '가', '었', '다', '.'],
#  ['톰', '은', '모든', '거', 'ᆯ', '회피', '하', '고', '싶', '어', '하', '어', '.'],
#  ['나', '는', '티브이', '보', '느라', '지치', '었', '다', '.'],
#  ['그래', ',', '그것', '이', '나', '가', '말', '하', '려던', '것', '이', '었', '어', '.'],
#  ['톰', '은', '여기', '에', '두', '세요', '.'],
#  ['오늘', '밤', '무대', '에서', '쓰', 'ᆯ', '기타', '좀', '빌리', '어', '주', 'ᆯ래', '?'],
#  ['톰', '은', '야구', '모자', '를', '쓰', '고', '있', '어', '.'],
#  ['그',
#   '회사',
#   '회장',
#   '은',
#   '리베이트',
#   '를',
#   '지불',
#   '하',
#   'ᆫ',
#   '혐의',
#   '로',
#   '기소',
#   '되',
#   '었',
#   '다',
#   '.'],
#  ['말', '조심', '하', '어야', '하', 'ᆫ다', '.'],
#  ['프랑스어', '공부', '계속', '하', '어', '.'],
#  ['치킨', '주', '세요', '.'],
#  ['지금', '어디', '가', '는', '길', '이', '세요', '?'],
#  ['맛있', '는', '저녁', '식사', '에', '감사', '드리', 'ᆸ니다', '.'],
#  ['나', '는', '톰', '에게', '전하', 'ᆯ', '긴급', '하', 'ᆫ', '메시지', '가', '있', '다', '.'],
#  ['톰', '은', '미치', '었', '을까', '?'],
#  ['우리', '가', '지', '었', '다', '.'],
#  ['핸드폰', '을', '가지', '고', '계시', 'ᆫ가요', '?'],
#  ['곧', '충분히', '알', '게', '되', 'ᆯ', '거', '이', '야', '.'],
#  ['우리', 'ᆫ', '이해', '하', '어', '.'],
#  ['톰', '은', '어젯밤', '에', '친구', '랑', '술집', '에', '있', '었', '어', '.'],
#  ['이렇게', '끔찍하', 'ᆯ', '수', '가', '!'],
#  ['톰', '은', '우리', '한테', '프랑스어', '를', '가르치', '었', '어', '.'],
#  ['나', 'ᆫ', '먹을거리', '를', '사', '어야', '겠', '어', '.'],
#  ['이', '농담', '은', '이미', '듣', '어', '보', '었', '어', '.'],
#  ['그만', '속삭이', '어', '.'],
#  ['미루', '는', '것', '은', '일종', '의', '예술', '이', '다', '.'],
#  ['긍정', '적', '으로', '있', '어', '.'],
#  ['톰', '이랑', '톰', '네', '형', '은', '진짜', '닮', '었', '어', '.'],
#  ['이', '사이트', '는', '유용', '하', 'ᆸ니다', '.'],
#  ['너무', '늦', '어', '.'],
#  ['병원', '으로', '가', 'ᆸ시다', '.'],
#  ['제발', '멈추', '어', '.'],
#  ['지금', '무슨', '일', '이', '벌어지', 'ᆫ', '거', '이', 'ᆫ가', '요', '?'],
#  ['뭐', '이', 'ᆫ가', '가', '일어나', '는', '중', '이', '야', '.'],
#  ['거짓말', '그만', '치', '어', '.'],
#  ['그', '는', '프랑스', '어', '를', '하', 'ᆫ다', '.'],
#  ['톰', '은', '오늘', '정장', '을', '입', '지', '않', '었', '어', '.'],
#  ['만약',
#   '신',
#   '이',
#   '존재',
#   '하',
#   '지',
#   '않',
#   '었',
#   '다면',
#   ',',
#   '만들',
#   '어',
#   '내',
#   'ᆯ',
#   '필요',
#   '가',
#   '있',
#   '겠',
#   '지',
#   '.'],
#  ['나',
#   'ᆫ',
#   '톰',
#   '과',
#   '메리',
#   '가',
#   '나',
#   '를',
#   '인질',
#   '로',
#   '잡',
#   '을',
#   '줄',
#   '알',
#   '었',
#   '지',
#   '.'],
#  ['신발', '끈', '을', '묶', '으세요', '.'],
#  ['톰', '이', '숨', '을', '들이마시', '었', '어', '.'],
#  ['나', '에게', '는', '언니', '가', '있', '다', '.'],
#  ['움직이', '지', '말', '어', '!'],
#  ['너', '는', '애견', '인', '이', '야', '아니', 'ᆷ', '애묘', '인', '이', '야', '?'],
#  ['신발', '을', '벗', '어라', '.'],
#  ['나', 'ᆫ', '더', '이상', '거미', '가', '두렵', '지', '않', '어', '.'],
#  ['우리', '는', '이달', '말', '에', '보스턴', '으로', '이사', '를', '하', 'ᆸ니다', '.'],
#  ['세상',
#   '이',
#   '변하',
#   '고',
#   '있',
#   '다는',
#   '사실',
#   '을',
#   '사람',
#   '들',
#   '은',
#   '알',
#   '어야',
#   '하',
#   'ᆫ다',
#   '.'],
#  ['공격', '하', '어', '!'],
#  ['방해', '받', '고', '싶', '지', '않', '었', '어', '.'],
#  ['그', '는', '나무', '에서', '추락', '하', '었', '다', '.'],
#  ['톰', '은', '메리', '이', '라는', '캐나다', '사람', '이랑', '결혼', '하', '었', '어', '.'],
#  ['톰', '은', '메리', '랑', '낚시', '하', '러', '가', '었었', '던', '것', '같', '어', '.'],
#  ['나', '는', '내년', '에', '호주', '에', '가', 'ᆫ다', '.'],
#  ['톰', '은', '점심', '전', '에', '여기', '있', '기', '로', '되', '어', '있', '었', '어', '.'],
#  ['이거', '는', '누구', '스키', '이', '예요', '?'],
#  ['의심', '하', '어서', '미안', '.'],
#  ['톰', '은', '메리', '가', '과다', '체중', '이', '라고', '하', '었', '다', '.'],
#  ['그거', '연필', '이', '야'],
#  ['새', '가', '날아가', '도록', '풀', '어', '주', '자', '.'],
#  ['너', '지치', '어', '보이', '어', '.'],
#  ['나', '가', '뭐', 'ᆯ', '하', '어', '주', '었', '으면', '좋', '겠', '어', '?'],
#  ['거기', '로', '가', '어', '.'],
#  ['이것', '이', '바로', '나', '가', '가장', '좋아하', '는', '표현', '이', '야', '.'],
#  ['여기', '정말', '덥', '어', '지', '었', '다', '.'],
#  ['톰', '은', '작별', '인사', '를', '하', 'ᆫ', '후', '떠나', '었', '다', '.'],
#  ['톰', '은', '메리', '한테', '남동생', '이', '있', '는지', '모르', '었', '어', '.'],
#  ['장거리', '연애', '하', '어', '보', 'ᆫ', '적', '있', '어', '?'],
#  ['생선', '좋아하', '어요', '?'],
#  ['나', '는', '우리', '아빠', '를', '닮', '었', '어', '.'],
#  ['없', '다', '.'],
#  ['톰', '과', '메리', '에게', '는', '자식', '이', '있', '어', '.'],
#  ['너', '정말', '수영', '하', 'ᆯ', '수', '있', '어', '?'],
#  ['톰', '이', '말', '하', '기', 'ᆯ', '메리', '가', '자폐증', '이', '래', '.'],
#  ['나', 'ᆫ', '나', '의', '아내', '와', '함께', '늙', '고', '싶', '어', '.'],
#  ['너', 'ᆫ', '어떻', '어', '?'],
#  ['왜', '너', '가', '프랑스어', '를', '공부', '하', '고', '있', '는지', '모르', '겠', '어', '.'],
#  ['어쩜', '이리', '멋있', '을까', '!'],
#  ['소방서', '에', '전화', '하', '어', '!'],
#  ['누구', '이', 'ᆫ가', '문', '을', '똑똑', '두드리', '었', '다', '.'],
#  ['나', '는', '나', '의', '직감', '을', '믿', '어', '보', '려', '하', '어', '.'],
#  ['바다', '가', '보이', '는', '자리', '있', '나요', '?'],
#  ['어젯밤', '에', '대하', '어', '기억나', '는', '것', '이', '뭐', '이', '야', '?'],
#  ['나', '의', '아들', '은', '또래', '에', '비하', '어', '키', '가', '작', '어', '.'],
#  ['너', 'ᆫ', '아주', '경쟁', '적', '이', '네', '.'],
#  ['거기', '가', '지', '말', '세요', '.'],
#  ['나', '의', '손', '이', '묶이', '었', '다', '.'],
#  ['톰', '은', '굶', '고', '있', '다', '.'],
#  ['나', 'ᆫ', '애묘', '인', '이', '아니', '야', '.'],
#  ['이렇', '게', '오래', '걸리', 'ᆯ', '줄', '은', '모르', '었', '어', '.'],
#  ['식물', '에', '물', '을', '주', '세요', '.'],
#  ['나', '는', '내일', '를', '찍', '을', '것', '이', '다', '.'],
#  ['톰',
#   '이',
#   '어리',
#   '었',
#   '을',
#   '때',
#   '보스턴',
#   '에',
#   '살',
#   'ᆫ',
#   '줄',
#   '도',
#   '모르',
#   '었',
#   '어',
#   '?'],
#  ['나', '는', '조금', '너', '가', '걱정', '되', '어', '.'],
#  ['프랑스어', '는', '나', '의', '취향', '이', '야', '.'],
#  ['크', 'ᆫ', '소리', '로', '책', '을', '읽', '어라', '.'],
#  ['톰', '과', '메리', '는', '가수', '이', '야', '.'],
#  ['나', '는', '잠', '이', '많', '지', '않', '어요', '.'],
#  ['톰', '은', '낯선', '이', '를', '수상', '하', '게', '바라보', '었', '다', '.'],
#  ['"', '힘들', '어', '?', '"', '"', '아니', ',', '그렇', 'ᆯ', '리', '가', '.', '"'],
#  ['나', '는', '울', '지', '않', '으려고', '하', '었', '다', '.'],
#  ['톰', '은', '파크', '스트리트', '의', '작', '은', '아파트', '에서', '살', '고', '있', '다', '.'],
#  ['그', '는', '월요일', '에', '뉴욕', '으로', '가', '었', '다', '.'],
#  ['나', '가', '너무', '늙', '었', '나', '보', '어', '.'],
#  ['그', '는', '개', '에게', '고기', '조각', '을', '던지', '었', '다', '.'],
#  ['그', '사람', '의', '꿈', '은', '실현', '되', '었', '어', '.'],
#  ['그녀', '는', '누구', '보다', '도', '아름답', '어요', '.'],
#  ...]

# %% [markdown]
# # 한국어 어휘집

# %%
from torchtext.vocab import build_vocab_from_iterator
vocab_src = build_vocab_from_iterator(src_data, specials=["<pad>", "<unk>"]) #이터러블한 객체 파라미터전달
vocab_src.set_default_index(vocab_src["<unk>"])
len(vocab_src)
# Out:
# c:\Users\hopio\anaconda3\Lib\site-packages\torchtext\vocab\__init__.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)
# c:\Users\hopio\anaconda3\Lib\site-packages\torchtext\utils.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)
# 3245

# %% [markdown]
# # 한국어 단어번호 부여

# %%
src_ko_data = [ vocab_src(tokens) for tokens in src_data]

# %%
src_ko_data
# Out:
# [[4, 2926, 32, 8, 50, 8, 3151, 4, 9, 2],
#  [1112, 4, 1254, 38, 6, 9, 2],
#  [22, 32, 4, 87, 12, 209, 6, 9, 2],
#  [10,
#   8,
#   49,
#   46,
#   84,
#   22,
#   13,
#   212,
#   41,
#   229,
#   58,
#   5,
#   48,
#   5,
#   6,
#   102,
#   371,
#   3,
#   34,
#   21,
#   28,
#   6,
#   9,
#   2],
#  [893, 13, 62, 2],
#  [166, 163, 3, 2],
#  [246, 13, 414, 134, 85, 18, 16, 12, 25, 4, 9, 2],
#  [80, 4, 2388, 4, 16, 52, 19, 277, 92, 2],
#  [80, 8, 11, 13, 218, 5, 14, 25, 12, 40, 31, 2],
#  [26, 701, 5, 525, 2],
#  [4, 127, 12, 159, 7, 25, 8, 11, 46, 247, 9, 2],
#  [79, 63, 4, 71, 13, 467, 38, 6, 9, 2],
#  [981, 12, 736, 21, 29, 3, 2],
#  [11, 13, 300, 6, 12, 117, 132, 41, 215, 5, 7, 21, 19, 96, 6, 3, 2],
#  [22, 32, 8, 137, 6, 3, 2],
#  [10, 8, 294, 516, 19, 1172, 5, 3, 2],
#  [10,
#   4,
#   84,
#   305,
#   303,
#   12,
#   5,
#   6,
#   102,
#   240,
#   5,
#   52,
#   89,
#   222,
#   168,
#   25,
#   12,
#   40,
#   31,
#   2],
#  [552, 1609, 32, 2],
#  [22, 13, 295, 12, 223, 176, 5, 6, 9, 2],
#  [1557, 2],
#  [11, 7, 10, 94, 165, 425, 5, 52, 19, 1041, 5, 20, 16, 9, 2],
#  [11, 7, 1103, 13, 187, 9, 2],
#  [338, 8, 1286, 335, 8, 497, 43, 210, 74, 20, 16, 9, 2],
#  [87, 8, 355, 4, 92, 2],
#  [63, 18, 156, 3, 97, 20, 16, 3, 15],
#  [10, 8, 1500, 4, 33, 9, 2],
#  [376, 14, 63, 4, 23, 15],
#  [10, 8, 227, 24, 330, 19, 1679, 6, 9, 2],
#  [2801, 18, 7, 1480, 13, 162, 120, 110, 15],
#  [364, 25, 12, 1225, 5, 17, 35, 7, 33, 86, 55, 10, 15],
#  [10, 8, 1915, 43, 225, 6, 9, 2],
#  [737, 19, 294, 5, 57, 110, 15],
#  [65, 4, 71, 7, 1395, 55, 65, 4, 71, 7, 1531, 1374, 4, 6, 9, 2],
#  [30, 7, 44, 8, 151, 4, 9, 2],
#  [22, 32, 12, 209, 286, 2],
#  [11, 7, 10, 12, 198, 21, 28, 6, 48, 5, 6, 3, 2],
#  [10, 8, 1164, 4, 1343, 45, 327, 57, 6, 12, 117, 177, 74, 4, 6, 3, 2],
#  [733, 7, 2583, 1626, 145, 1833, 19, 2510, 5, 3, 2],
#  [22, 39, 8, 248, 2593, 18, 1396, 8, 2570, 4, 16, 3, 2],
#  [10, 8, 666, 14, 153, 828, 1403, 12, 123, 20, 16, 3, 2],
#  [257, 45, 1448, 19, 97, 7, 25, 8, 247, 21, 28, 9, 2],
#  [674,
#   1645,
#   231,
#   167,
#   4,
#   91,
#   130,
#   37,
#   798,
#   94,
#   125,
#   5,
#   3,
#   36,
#   14,
#   47,
#   37,
#   33,
#   1659,
#   2140,
#   12,
#   483,
#   17,
#   35,
#   16,
#   6,
#   168,
#   27,
#   14,
#   706,
#   5,
#   14,
#   58,
#   4,
#   14,
#   25,
#   50,
#   3,
#   2],
#  [65, 4, 71, 911, 12, 702, 6, 3, 2],
#  [103, 5, 6, 3, 51],
#  [10, 4, 829, 5, 213, 13, 17, 27, 4, 23, 2],
#  [11, 7, 10, 4, 435, 39, 4, 14, 106, 40, 6, 9, 2],
#  [10, 8, 337, 14, 245, 18, 432, 12, 1887, 6, 9, 2],
#  [881, 5, 68, 2],
#  [2891, 446, 7, 162, 687, 5, 3, 15],
#  [11, 7, 4, 1641, 13, 499, 4, 201, 70, 31, 2],
#  [11, 7, 2527, 38, 6, 9, 2],
#  [10, 8, 237, 165, 440, 3, 2],
#  [11, 46, 7, 594, 13, 16, 9, 2],
#  [10, 8, 22, 912, 12, 1643, 6, 9, 2],
#  [128, 16, 108, 2],
#  [4, 266, 7, 310, 1590, 5, 3, 93, 31, 2],
#  [490, 109, 1556, 19, 97, 7, 25, 4, 44, 9, 2],
#  [150, 19, 1546, 131, 17, 53, 4, 9, 2],
#  [318, 5, 3, 51],
#  [26, 67, 3, 15],
#  [11,
#   7,
#   26,
#   13,
#   115,
#   41,
#   5,
#   244,
#   1874,
#   5,
#   21,
#   7,
#   28,
#   60,
#   270,
#   115,
#   41,
#   5,
#   48,
#   5,
#   17,
#   27,
#   4,
#   23],
#  [22, 19, 592, 3, 34, 3, 2],
#  [164, 11, 19, 2761, 5, 7, 27, 4, 23, 15],
#  [10, 8, 89, 349, 6, 3, 2],
#  [4, 306, 4, 101, 45, 13, 102, 371, 3, 34, 261, 15],
#  [297, 55, 2811, 72, 314, 3, 51],
#  [2230, 7, 1642, 1568, 369, 4, 23, 2],
#  [80, 29, 4, 329, 54, 2],
#  [11, 14, 650, 4, 44, 3, 2],
#  [11, 7, 1423, 19, 1238, 31, 2],
#  [11, 14, 1035, 1059, 12, 1006, 3, 2],
#  [66, 344, 20, 42, 3, 2],
#  [374, 41, 672, 17, 35, 13, 51],
#  [10, 12, 921, 5, 176, 104, 12, 659, 5, 21, 29, 3, 2],
#  [166, 568, 20, 16, 3, 36, 3, 2],
#  [10, 8, 890, 319, 13, 40, 415, 2],
#  [73, 7, 98, 136, 18, 274, 54, 2],
#  [10, 8, 69, 1280, 5, 3, 34, 52, 19, 224, 6, 9, 2],
#  [211, 4, 382, 590, 9, 2],
#  [66, 14, 908, 810, 5, 77, 53, 5, 3, 2],
#  [22, 7, 89, 297, 29, 5, 31, 2],
#  [30, 7, 188, 812, 41, 566, 6, 9, 2],
#  [26, 24, 340, 12, 2908, 5, 17, 35, 16, 86, 15],
#  [11, 24, 389, 8, 242, 74, 4, 17, 313, 4, 23, 2],
#  [144, 914, 30, 7, 364, 311, 4, 33, 9],
#  [26, 14, 320, 734, 13, 352, 68, 2],
#  [449, 46, 2687, 4, 16, 77, 53, 5, 3, 15],
#  [937, 509, 51],
#  [11, 14, 842, 89, 324, 4, 38, 6, 3, 2],
#  [413, 208, 64, 290, 70, 60, 3],
#  [11, 89, 1442, 5, 3, 2],
#  [10, 8, 1120, 12, 1140, 20, 16, 9, 2],
#  [81, 4, 11, 24, 691, 5, 14, 1340, 4, 23, 2],
#  [22, 39, 8, 3041, 47, 72, 285, 5, 3, 2],
#  [1463,
#   26,
#   24,
#   2445,
#   37,
#   103,
#   70,
#   7,
#   39,
#   4,
#   798,
#   50,
#   77,
#   29,
#   5,
#   410,
#   75,
#   14,
#   22,
#   39,
#   4,
#   26,
#   13,
#   798,
#   4,
#   83,
#   78,
#   2042,
#   41,
#   5,
#   3,
#   34,
#   7,
#   63,
#   4,
#   71,
#   19,
#   68,
#   29,
#   424,
#   43,
#   3060,
#   5,
#   3,
#   129,
#   14,
#   25,
#   4,
#   60,
#   21,
#   2,
#   869,
#   41,
#   1274,
#   5,
#   1209,
#   26,
#   14,
#   798,
#   228,
#   29,
#   5,
#   21,
#   28,
#   3,
#   2],
#  [509, 705, 3, 2],
#  [81, 8, 126, 43, 226, 6, 108, 2],
#  [10, 8, 737, 1139, 4, 23, 2],
#  [10, 8, 451, 19, 276, 31, 2],
#  [26, 13, 98, 143, 14, 47, 33, 7, 200, 237, 32, 37, 79, 16, 3, 15],
#  [468, 4, 64, 3, 2],
#  [485, 24, 39, 32, 8, 11, 13, 544, 6, 77, 53, 5, 3],
#  [22, 998, 24, 333, 38, 14, 1344, 7, 95, 256, 9, 2],
#  [116, 37, 56, 64, 6, 3, 2],
#  [26, 14, 84, 1473, 136, 18, 212, 86, 15],
#  [162, 658, 41, 15],
#  [1022, 51],
#  [116, 46, 37, 111, 3, 36, 14, 47, 4, 33, 3, 2],
#  [11, 37, 435, 39, 4, 238, 2],
#  [1690, 7, 681, 8, 1316, 519, 2],
#  [26, 128, 16, 3, 15],
#  [11, 13, 818, 90, 12, 25, 12, 131, 6, 9, 2],
#  [166, 29, 5, 20, 16, 3, 36, 3, 2],
#  [11, 7, 26, 24, 301, 4, 293, 18, 32, 21, 28, 105, 2],
#  [30, 7, 384, 703, 12, 40, 41, 38, 17, 27, 4, 23, 2],
#  [10, 8, 240, 5, 20, 16, 168, 2191, 1328, 19, 1376, 6, 9, 2],
#  [569, 109, 150, 145, 18, 204, 27, 17, 32, 57, 60, 54, 15],
#  [11, 14, 210, 118, 90, 7, 25, 12, 282, 3, 2],
#  [10,
#   8,
#   2204,
#   165,
#   555,
#   5,
#   1678,
#   2929,
#   3,
#   219,
#   6,
#   270,
#   11,
#   7,
#   95,
#   555,
#   18,
#   524,
#   4,
#   33,
#   9,
#   2],
#  [433, 45, 13, 7, 306, 88, 360, 3, 34, 17, 35, 16, 3, 15],
#  [157, 88, 276, 3, 2],
#  [26, 24, 1570, 18, 2093, 13, 11, 31, 2],
#  [22, 19, 40, 20, 383, 6, 54, 15],
#  [4, 466, 137, 14, 27, 4, 201, 441, 5, 54, 2],
#  [10, 8, 1702, 19, 2902, 3, 49, 46, 1013, 6, 9, 2],
#  [11, 59, 1776, 34, 3, 2],
#  [80, 8, 206, 12, 5, 20, 16, 186, 15],
#  [11, 7, 337, 14, 1233, 18, 773, 19, 241, 6, 9, 2],
#  [10, 8, 262, 18, 368, 3, 405, 13, 335, 21, 2],
#  [2120, 24, 979, 2793, 12, 125, 5, 3, 36, 14, 47, 16, 3, 15],
#  [3217, 5, 92, 2],
#  [10, 4, 49, 13, 63, 17, 224, 102, 1992, 5, 3, 5, 597, 2],
#  [22, 7, 3239, 14, 795, 12, 234, 20, 16, 9, 2],
#  [101, 118, 74, 17, 27, 4, 23, 15],
#  [235, 11, 3, 15],
#  [698, 119, 51],
#  [10, 239, 49, 7, 91, 117, 151, 4, 149, 21, 15],
#  [87, 12, 224, 57, 146, 15],
#  [11, 14, 10, 4, 628, 27, 17, 5, 17, 35, 16, 2767, 53, 5, 21, 28, 3, 2],
#  [460, 26, 7, 10, 46, 29, 5, 48, 5, 3, 2],
#  [838, 16, 3, 2],
#  [11, 7, 124, 7, 25, 4, 882, 9, 2],
#  [11, 13, 884, 141, 38, 289, 15],
#  [10, 4, 1489, 174, 6, 3, 2],
#  [568, 7, 25, 8, 1725, 6, 3, 2],
#  [11, 7, 3096, 19, 90, 21, 29, 14, 10, 8, 90, 21, 28, 105, 2],
#  [30, 46, 4, 220, 27, 17, 34, 14, 39, 4, 296, 80, 4, 9, 2],
#  [166, 1083, 1267, 20, 16, 3, 36, 3, 2],
#  [10, 8, 325, 3, 16, 141, 38, 3, 2, 347, 1052, 7, 362, 48, 5, 3, 2],
#  [2720, 72, 1075, 3, 2],
#  [10, 8, 49, 19, 834, 196, 18, 143, 6, 3, 2],
#  [10, 4, 3193, 280, 19, 129, 6, 3, 2],
#  [522, 1309, 4, 619, 6, 9, 2],
#  [22, 7, 538, 104, 12, 2206, 20, 16, 12, 313, 4, 9, 2],
#  [76, 7, 150, 91, 808, 12, 1706, 5, 6, 9, 2],
#  [22, 7, 310, 142, 4, 120, 77, 5, 31, 2],
#  [10, 8, 159, 12, 35, 16, 21, 15],
#  [220,
#   29,
#   32,
#   4,
#   1427,
#   5,
#   41,
#   638,
#   14,
#   27,
#   14,
#   83,
#   23,
#   2,
#   674,
#   8,
#   225,
#   52,
#   233,
#   3,
#   638,
#   6,
#   3,
#   2],
#  [11, 7, 394, 903, 8, 69, 138, 56, 5, 17, 27, 4, 23, 2],
#  [446, 19, 1710, 57, 48, 5, 54, 2],
#  [69, 297, 5, 1300, 44, 9, 2],
#  [240, 5, 3, 2],
#  [76, 7, 2137, 5, 9, 2],
#  [26, 13, 188, 10, 46, 29, 5, 6, 21, 15],
#  [10, 8, 273, 1663, 16, 3, 2],
#  [65, 11, 172, 148, 20, 42, 3, 5, 3, 2],
#  [11, 14, 121, 3029, 24, 508, 119, 5, 6, 3, 2],
#  [624, 18, 63, 5, 17, 27, 4, 23, 15],
#  [10, 8, 127, 4, 408, 365, 6, 77, 29, 5, 6, 9, 2],
#  [76, 7, 531, 18, 74, 31, 2],
#  [49, 13, 126, 18, 177, 130, 623, 13, 6, 77, 10, 4, 29, 5, 597, 2],
#  [809, 697, 51],
#  [10, 8, 262, 18, 368, 3, 405, 13, 155, 21, 28, 3, 2],
#  [81, 4, 26, 13, 5, 20, 42, 8, 29, 402, 4, 86, 15],
#  [11, 14, 114, 1428, 18, 1725, 6, 3, 2],
#  [75, 14, 11, 24, 422, 4, 23, 2],
#  [10, 8, 49, 4, 179, 1258, 94, 218, 5, 6, 3, 2],
#  [769, 3, 55, 136, 212, 60, 9, 2],
#  [22, 24, 690, 4, 306, 82, 30, 100, 13, 701, 5, 6, 9, 2],
#  [11, 14, 847, 43, 1201, 13, 16, 6, 3, 2],
#  [11, 7, 738, 12, 178, 20, 16, 9, 2],
#  [11, 14, 10, 4, 49, 59, 471, 12, 56, 5, 6, 135, 44, 60, 3, 2],
#  [11, 7, 85, 18, 16, 9, 2],
#  [11, 7, 11, 24, 227, 4, 187, 3, 2],
#  [26, 13, 114, 2624, 13, 16, 168, 27, 17, 10, 4, 11, 59, 29, 5, 6, 3, 2],
#  [22, 429, 8, 101, 18, 16, 54, 15],
#  [66, 841, 4, 23, 15],
#  [10, 8, 948, 12, 2985, 6, 3, 2],
#  [95, 215, 5, 17, 106, 70, 3, 15],
#  [116, 37, 58, 5, 20, 42, 3, 5, 21, 28, 105, 2],
#  [1571, 21, 29, 3, 2],
#  [10, 8, 11, 112, 142, 4, 120, 3, 2],
#  [10, 4, 530, 3, 2],
#  [4, 237, 7, 11, 24, 1153, 4, 9, 2],
#  [26,
#   24,
#   550,
#   13,
#   614,
#   46,
#   599,
#   61,
#   45,
#   287,
#   12,
#   5,
#   134,
#   76,
#   7,
#   61,
#   45,
#   326,
#   5,
#   86,
#   83,
#   134,
#   257,
#   45,
#   326,
#   5,
#   86,
#   15],
#  [30, 7, 22, 153, 19, 58, 1235, 56, 18, 828, 5, 6, 9, 2],
#  [68, 281, 4, 1169, 228, 1734, 3, 2],
#  [10, 4, 436, 3104, 686, 18, 549, 12, 592, 6, 3, 2],
#  [166, 434, 5, 20, 16, 3, 36, 3, 2],
#  [11, 14, 926, 44, 3, 5, 3, 2],
#  [3235, 55, 26, 7, 1000, 10, 46, 1632, 1308, 12, 123, 20, 16, 852, 2],
#  [84, 56, 38, 3, 15],
#  [10, 8, 69, 138, 178, 20, 42, 21, 28, 77, 29, 5, 6, 9, 2],
#  [81, 4, 11, 13, 36, 17, 35, 16, 7, 25, 24, 402, 4, 23, 2],
#  [30, 14, 235, 5, 20, 16, 3, 2],
#  [268, 202, 235, 4, 11, 363, 2],
#  [10, 94, 49, 7, 1005, 8, 3053, 4, 23, 2],
#  [10, 8, 21, 52, 282, 31, 2],
#  [26, 13, 75, 17, 5, 52, 182, 18, 10, 59, 543, 6, 615, 2],
#  [330, 13, 284, 54, 2],
#  [22, 7, 22, 200, 46, 805, 19, 1013, 6, 9, 2],
#  [1491, 32, 4, 925, 19, 2900, 5, 6, 9, 2],
#  [76, 7, 522, 1002, 139, 2978, 140, 1777, 12, 1030, 5, 6, 9, 2],
#  [171, 5, 260, 55, 11, 265, 3, 2],
#  [10, 4, 157, 18, 353, 3, 124, 6, 3, 2],
#  [4, 1894, 24, 2959, 8, 710, 4, 23, 2],
#  [1752, 4, 317, 1289, 13, 16, 258, 15],
#  [11, 7, 375, 316, 496, 6, 3, 2],
#  [11, 7, 639, 1285, 319, 4, 6, 3, 2],
#  [10, 8, 639, 346, 4, 149, 3, 2],
#  [89, 44, 3, 51],
#  [10, 4, 1528, 6, 3, 2],
#  [11, 14, 501, 18, 7, 85, 18, 16, 2772, 2],
#  [185, 351, 5, 3, 2],
#  [468, 4, 498, 112, 590, 9, 2],
#  [40, 3, 2],
#  [10, 8, 262, 18, 368, 3, 405, 13, 155, 3, 2],
#  [10, 8, 466, 137, 6, 9, 2],
#  [968, 8, 188, 4, 6, 9, 2],
#  [11, 7, 10, 4, 666, 77, 53, 5, 31, 2],
#  [10, 4, 157, 424, 72, 746, 3, 32, 21, 28, 6, 3, 2],
#  [157, 1794, 34, 62, 2],
#  [550, 29, 88, 111, 3, 2],
#  [26, 24, 1481, 12, 2184, 3, 2],
#  [10, 8, 88, 1125, 5, 3, 5, 20, 16, 3, 2],
#  [10, 8, 2489, 1090, 574, 18, 13, 6, 9, 2],
#  [10, 8, 220, 27, 17, 1815, 5, 20, 42, 3, 5, 3, 2],
#  [11, 7, 1774, 36, 1063, 978, 6, 9, 2],
#  [1353, 55, 81, 4, 11, 13, 29, 5, 1451, 25, 4, 6, 3, 2],
#  [10, 8, 79, 18, 140, 62, 2],
#  [113, 245, 2286, 43, 97, 17, 586, 88, 331, 3, 34, 261, 15],
#  [10, 8, 1620, 490, 19, 97, 20, 16, 3, 2],
#  [22, 517, 3223, 8, 2232, 19, 1241, 5, 14, 1806, 45, 2027, 38, 6, 9, 2],
#  [29, 318, 5, 48, 5, 31, 2],
#  [61, 125, 166, 5, 3, 2],
#  [3051, 34, 62, 2],
#  [164, 101, 13, 7, 306, 4, 62, 15],
#  [670, 7, 432, 611, 18, 580, 417, 92, 2],
#  [11, 7, 10, 46, 971, 17, 2037, 5, 14, 750, 13, 16, 9, 2],
#  [10, 8, 544, 6, 258, 15],
#  [30, 13, 21, 6, 9, 2],
#  [716, 12, 123, 20, 383, 288, 15],
#  [384, 1253, 40, 41, 38, 17, 27, 4, 23, 2],
#  [30, 14, 240, 5, 3, 2],
#  [10, 8, 688, 18, 151, 170, 2548, 18, 16, 6, 3, 2],
#  [558, 2058, 17, 35, 13, 51],
#  [10, 8, 30, 59, 61, 19, 360, 6, 3, 2],
#  [11, 14, 2262, 19, 131, 48, 60, 3, 2],
#  [4, 537, 8, 466, 111, 3, 36, 6, 3, 2],
#  [184, 2518, 3, 2],
#  [2307, 7, 25, 8, 1676, 24, 1175, 4, 9, 2],
#  [1039, 47, 72, 16, 3, 2],
#  [10, 239, 10, 68, 717, 8, 249, 1068, 6, 3, 2],
#  [4, 1536, 7, 801, 5, 92, 2],
#  [89, 212, 3, 2],
#  [605, 72, 13, 519, 2],
#  [509, 366, 3, 2],
#  [164, 147, 58, 4, 603, 14, 27, 4, 71, 173, 15],
#  [63, 4, 71, 13, 226, 7, 145, 4, 23, 2],
#  [133, 184, 174, 3, 2],
#  [22, 7, 322, 3, 19, 5, 31, 2],
#  [10, 8, 113, 2914, 12, 234, 21, 28, 6, 3, 2],
#  [599,
#   396,
#   4,
#   511,
#   5,
#   21,
#   28,
#   6,
#   236,
#   55,
#   450,
#   3,
#   129,
#   17,
#   122,
#   13,
#   16,
#   60,
#   21,
#   2],
#  [10, 8, 1349, 20, 16, 9, 2],
#  [11, 14, 1618, 1200, 4, 83, 23, 2],
#  [374, 41, 333, 175, 17, 106, 8, 70, 6, 3, 2],
#  [930, 18, 157, 12, 34, 62, 2],
#  [11, 7, 160, 19, 820, 12, 25, 4, 9, 2],
#  [10, 4, 300, 6, 12, 117, 126, 18, 74, 14, 106, 37, 70, 6, 3, 15],
#  [11, 7, 336, 26, 13, 324, 38, 3, 2],
#  [61, 7, 11, 24, 3047, 4, 23, 2],
#  [155, 14, 280, 45, 127, 12, 159, 286, 2],
#  [10, 94, 49, 7, 646, 4, 23, 2],
#  [11, 7, 468, 4, 120, 21, 28, 54, 2],
#  [10, 8, 2081, 4, 19, 1577, 5, 41, 1114, 6, 9, 2],
#  [217, 832, 3, 15, 217, 217, 83, 55, 115, 17, 889, 13, 2, 217],
#  [11, 7, 216, 21, 28, 620, 5, 6, 9, 2],
#  [10, 8, 3116, 2554, 24, 335, 8, 497, 43, 74, 20, 16, 9, 2],
#  [22, 7, 503, 18, 1399, 72, 13, 6, 9, 2],
#  [11, 13, 89, 349, 6, 11, 36, 3, 2],
#  [22, 7, 139, 46, 481, 974, 12, 2148, 6, 9, 2],
#  [22, 39, 24, 254, 8, 1151, 38, 6, 3, 2],
#  [76, 7, 65, 112, 37, 256, 54, 2],
#  ...]

# %% [markdown]
# # 영어 토큰화

# %%
from torchtext.data.utils import get_tokenizer
tokenizer = get_tokenizer("basic_english")
# Out:
# c:\Users\hopio\anaconda3\Lib\site-packages\torchtext\data\__init__.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)

# %% [markdown]
# - sos 토큰과 eos 토큰 정의

# %%
sos_token = "<sos>" # start of sentence
eos_token = "<eos>" # end of sentence

# %%
trg_data = []
for text in train["en"]:
    tokens = [sos_token] + tokenizer(text) + [eos_token]
    print(tokens)
    trg_data.append(tokens)
# Out:
# ['<sos>', 'these', 'products', 'are', 'of', 'the', 'same', 'quality', '.', '<eos>']
# ['<sos>', 'the', 'meeting', 'was', 'cancelled', '.', '<eos>']
# ['<sos>', 'they', 'found', 'this', '.', '<eos>']
# ['<sos>', 'tom', 'didn', "'", 't', 'tell', 'mary', 'why', 'he', 'had', 'to', 'work', 'late', '.', '<eos>']
# ['<sos>', 'after', 'you', '.', '<eos>']
# ['<sos>', 'keep', 'smiling', '.', '<eos>']
# ['<sos>', 'if', 'it', 'rains', ',', 'i', "'", 'll', 'stay', 'at', 'home', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'bleeding', '.', '<eos>']
# ['<sos>', 'tom', 'approved', '.', '<eos>']
# ['<sos>', 'did', 'you', 'just', 'insult', 'me', '?', '<eos>']
# ['<sos>', 'i', "'", 'm', 'having', 'a', 'hard', 'time', 'concentrating', '.', '<eos>']
# ['<sos>', 'why', 'are', 'you', 'acting', 'so', 'stupid', '?', '<eos>']
# ['<sos>', 'i', "'", 'm', 'sorry', 'for', 'interrupting', '.', '<eos>']
# ['<sos>', 'tom', 'didn', "'", 't', 'study', 'for', 'his', 'final', 'exam', '.', '<eos>']
# ['<sos>', 'what', 'would', 'you', 'do', 'if', 'that', 'happened', 'to', 'you', '?', '<eos>']
# ['<sos>', 'tom', 'wants', 'a', 'beer', '.', '<eos>']
# ['<sos>', 'that', "'", 's', 'not', 'what', 'tom', 'is', 'talking', 'about', '.', '<eos>']
# ['<sos>', 'mary', 'found', 'a', 'long', 'blonde', 'hair', 'on', 'tom', "'", 's', 'jacket', '.', '<eos>']
# ['<sos>', 'tell', 'tom', '.', '<eos>']
# ['<sos>', 'please', 'leave', '.', '<eos>']
# ['<sos>', 'can', 'i', 'have', 'this', 'cup', '?', '<eos>']
# ['<sos>', 'i', 'have', 'to', 'go', 'alone', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'abusive', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'going', 'to', 'go', 'there', 'with', 'tom', '.', '<eos>']
# ['<sos>', 'tom', 'said', 'he', 'wanted', 'to', 'go', 'swimming', '.', '<eos>']
# ['<sos>', 'she', 'carried', 'out', 'the', 'plan', '.', '<eos>']
# ['<sos>', 'come', 'inside', '.', '<eos>']
# ['<sos>', 'i', 'got', 'injured', 'doing', 'that', '.', '<eos>']
# ['<sos>', 'they', "'", 're', 'vegetarians', '.', '<eos>']
# ['<sos>', 'tom', 'can', "'", 't', 'hold', 'down', 'a', 'job', '.', 'he', "'", 's', 'always', 'getting', 'fired', '.', '<eos>']
# ['<sos>', 'did', 'you', 'get', 'a', 'chance', 'to', 'talk', 'with', 'tom', '?', '<eos>']
# ['<sos>', 'i', 'think', 'that', 'tom', "'", 's', 'french', 'has', 'improved', 'a', 'lot', '.', '<eos>']
# ['<sos>', 'tom', 'surrendered', 'to', 'the', 'police', '.', '<eos>']
# ['<sos>', 'i', 'know', 'i', 'might', 'not', 'have', 'to', 'do', 'that', 'today', '.', '<eos>']
# ['<sos>', 'tom', 'drove', '.', '<eos>']
# ['<sos>', 'the', 'data', 'was', 'completely', 'useless', '.', '<eos>']
# ['<sos>', 'i', 'don', "'", 't', 'really', 'have', 'a', 'preference', '.', '<eos>']
# ['<sos>', 'i', 'was', 'late', ',', 'so', 'i', 'missed', 'my', 'flight', '.', '<eos>']
# ['<sos>', 'eat', 'everything', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'just', 'doing', 'my', 'best', '.', '<eos>']
# ['<sos>', 'this', 'is', 'free', '.', '<eos>']
# ['<sos>', 'the', 'sand', 'on', 'the', 'beach', 'was', 'white', '.', '<eos>']
# ['<sos>', 'i', 'like', 'languages', '.', '<eos>']
# ['<sos>', 'semiconductors', 'were', 'the', 'top', 'united', 'states', 'export', 'to', 'south', 'korea', '.', '<eos>']
# ['<sos>', 'tom', 'wanted', 'a', 'bigger', 'discount', '.', '<eos>']
# ['<sos>', 'the', 'telephone', 'rang', '.', '<eos>']
# ['<sos>', 'have', 'you', 'ever', 'been', 'in', 'love', '?', '<eos>']
# ['<sos>', 'is', 'it', 'blue', '?', '<eos>']
# ['<sos>', 'tom', 'didn', "'", 't', 'do', 'the', 'dishes', '.', '<eos>']
# ['<sos>', 'was', 'the', 'bank', 'closed', '?', '<eos>']
# ['<sos>', 'there', 'are', 'seven', 'continents', 'on', 'the', 'earth', '.', '<eos>']
# ['<sos>', 'do', 'you', 'like', 'singing', '?', '<eos>']
# ['<sos>', 'tom', 'has', 'decided', 'to', 'go', 'to', 'boston', '.', '<eos>']
# ['<sos>', 'i', 'hope', 'you', 'have', 'insurance', '.', '<eos>']
# ['<sos>', 'you', 'know', 'i', "'", 'm', 'married', '.', '<eos>']
# ['<sos>', 'you', "'", 're', 'boring', '.', '<eos>']
# ['<sos>', 'this', 'book', 'is', 'easy', 'for', 'me', 'to', 'read', '.', '<eos>']
# ['<sos>', 'something', 'is', 'wrong', 'here', '.', '<eos>']
# ['<sos>', 'don', "'", 't', 'close', 'the', 'window', '.', '<eos>']
# ['<sos>', 'i', 'learned', 'how', 'to', 'swim', 'when', 'i', 'was', 'a', 'kid', '.', '<eos>']
# ['<sos>', 'they', 'left', '.', '<eos>']
# ['<sos>', 'tom', 'practices', 'piano', 'every', 'day', '.', '<eos>']
# ['<sos>', 'i', 'know', 'it', "'", 's', 'very', 'difficult', 'to', 'understand', 'why', 'tom', 'did', 'what', 'he', 'did', '.', '<eos>']
# ['<sos>', 'hello', ',', 'girls', '.', '<eos>']
# ['<sos>', 'he', 'tried', 'to', 'open', 'the', 'door', '.', '<eos>']
# ['<sos>', 'you', 'don', "'", 't', 'say', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'looking', 'forward', 'to', 'traveling', 'with', 'tom', '.', '<eos>']
# ['<sos>', 'i', 'hate', 'sand', '.', '<eos>']
# ['<sos>', 'tom', 'currently', 'lives', 'alone', 'in', 'a', 'small', 'apartment', '.', '<eos>']
# ['<sos>', 'this', 'is', 'suicide', '!', '<eos>']
# ['<sos>', 'what', 'are', 'you', 'writing', 'about', '?', '<eos>']
# ['<sos>', 'tom', 'is', 'insolent', '.', '<eos>']
# ['<sos>', 'what', "'", 's', 'that', '?', '<eos>']
# ['<sos>', 'tom', 'cut', 'his', 'own', 'hair', '.', '<eos>']
# ['<sos>', 'how', 'many', 'mosques', 'are', 'there', 'in', 'istanbul', '?', '<eos>']
# ['<sos>', 'can', "'", 't', 'you', 'suggest', 'something', 'else', ',', 'tom', '?', '<eos>']
# ['<sos>', 'tom', 'won', 'the', 'match', '.', '<eos>']
# ['<sos>', 'do', 'you', 'run', 'every', 'day', '?', '<eos>']
# ['<sos>', 'some', 'were', 'farmers', ',', 'some', 'were', 'hunters', '.', '<eos>']
# ['<sos>', 'we', 'are', 'good', 'friends', '.', '<eos>']
# ['<sos>', 'find', 'them', '.', '<eos>']
# ['<sos>', 'i', 'should', "'", 've', 'never', 'trusted', 'tom', '.', '<eos>']
# ['<sos>', 'tom', 'was', 'three', 'when', 'his', 'mother', 'was', 'killed', 'in', 'a', 'traffic', 'accident', '.', '<eos>']
# ['<sos>', 'brains', 'consume', '25', 'of', 'the', 'body', "'", 's', 'energy', '.', '<eos>']
# ['<sos>', 'he', 'has', 'a', 'deep', 'insight', 'into', 'human', 'psychology', '.', '<eos>']
# ['<sos>', 'tom', 'has', 'very', 'good', 'problemsolving', 'skills', '.', '<eos>']
# ['<sos>', 'it', 'isn', "'", 't', 'easy', 'to', 'write', 'a', 'love', 'letter', 'in', 'english', '.', '<eos>']
# ['<sos>', 'i', 'think', 'it', "'", 's', 'a', 'shame', 'that', 'some', 'foreign', 'language', 'teachers', 'were', 'able', 'to', 'graduate', 'from', 'college', 'without', 'ever', 'having', 'studied', 'with', 'a', 'native', 'speaker', '.', '<eos>']
# ['<sos>', 'someone', 'screamed', '.', '<eos>']
# ['<sos>', 'good', 'job', '!', '<eos>']
# ['<sos>', 'tom', 'is', 'going', 'to', 'check', 'it', 'out', '.', '<eos>']
# ['<sos>', 'i', 'thought', 'tom', 'was', 'canadian', '.', '<eos>']
# ['<sos>', 'both', 'tom', 'and', 'mary', 'miss', 'you', '.', '<eos>']
# ['<sos>', 'there', 'was', 'no', 'point', 'in', 'arguing', 'with', 'tom', '.', '<eos>']
# ['<sos>', 'are', 'you', 'a', 'drug', 'addict', '?', '<eos>']
# ['<sos>', 'everybody', 'left', '.', '<eos>']
# ['<sos>', 'i', 'have', 'three', 'daughters', '.', '<eos>']
# ['<sos>', 'good', 'luck', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'a', 'friend', 'of', 'mine', '.', 'do', 'you', 'know', 'him', '?', '<eos>']
# ['<sos>', 'she', 'wants', 'to', 'keep', 'a', 'cat', '.', '<eos>']
# ['<sos>', 'i', 'work', 'on', 'sunday', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'in', 'my', 'room', 'studying', 'french', '.', '<eos>']
# ['<sos>', 'let', "'", 's', 'eat', ',', 'drink', ',', 'and', 'be', 'merry', '.', '<eos>']
# ['<sos>', 'tom', 'grew', 'up', 'in', 'the', 'suburbs', '.', '<eos>']
# ['<sos>', 'i', 'assured', 'tom', 'i', 'wouldn', "'", 't', 'do', 'that', 'anymore', '.', '<eos>']
# ['<sos>', 'after', 'you', '.', '<eos>']
# ['<sos>', 'watch', 'yourself', '.', '<eos>']
# ['<sos>', 'fish', ',', 'please', '.', '<eos>']
# ['<sos>', 'colds', 'are', 'contagious', '.', '<eos>']
# ['<sos>', 'can', 'you', 'call', 'a', 'taxi', 'for', 'me', '?', '<eos>']
# ['<sos>', 'have', 'you', 'ever', 'been', 'to', 'tom', "'", 's', 'home', '?', '<eos>']
# ['<sos>', 'we', "'", 're', 'still', 'eating', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'looking', 'for', 'a', 'hat', 'to', 'match', 'a', 'brown', 'dress', '.', '<eos>']
# ['<sos>', 'shut', 'up', '!', '<eos>']
# ['<sos>', 'one', 'of', 'my', 'teeth', 'hurts', '.', '<eos>']
# ['<sos>', 'she', 'is', 'darkskinned', '.', '<eos>']
# ['<sos>', 'i', 'tried', 'to', 'apologize', 'to', 'tom', '.', '<eos>']
# ['<sos>', 'i', 'think', 'tom', 'is', 'lonely', '.', '<eos>']
# ['<sos>', 'god', 'knows', 'what', 'we', 'need', '.', '<eos>']
# ['<sos>', 'i', 'was', 'born', 'in', '2013', '.', '<eos>']
# ['<sos>', 'stop', 'whining', '.', '<eos>']
# ['<sos>', 'i', 'agreed', 'with', 'him', 'on', 'that', 'point', '.', '<eos>']
# ['<sos>', 'i', 'speak', 'french', 'a', 'lot', '.', '<eos>']
# ['<sos>', 'the', 'night', 'was', 'cold', '.', '<eos>']
# ['<sos>', 'somebody', 'was', 'talking', 'to', 'tom', '.', '<eos>']
# ['<sos>', 'i', "'", 'd', 'like', 'to', 'buy', 'this', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'as', 'thin', 'as', 'a', 'rail', '.', '<eos>']
# ['<sos>', 'this', 'technique', 'isn', "'", 't', 'easy', 'to', 'learn', '.', '<eos>']
# ['<sos>', 'don', "'", 't', 'get', 'me', 'wrong', '.', '<eos>']
# ['<sos>', 'is', 'this', 'the', 'dictionary', 'you', "'", 're', 'looking', 'for', '?', '<eos>']
# ['<sos>', 'he', "'", 's', 'addicted', 'to', 'drugs', '.', '<eos>']
# ['<sos>', 'i', 'really', 'like', 'what', 'i', 'do', '.', '<eos>']
# ['<sos>', 'i', 'sent', 'tom', 'a', 'text', '.', '<eos>']
# ['<sos>', 'do', 'you', 'really', 'think', 'you', 'can', 'convince', 'tom', 'to', 'do', 'that', '?', '<eos>']
# ['<sos>', 'tom', 'is', 'still', 'single', '.', '<eos>']
# ['<sos>', 'tom', 'sighed', '.', '<eos>']
# ['<sos>', 'have', 'you', 'ever', 'been', 'drunk', '?', '<eos>']
# ['<sos>', 'tom', 'is', 'still', 'not', 'very', 'good', 'at', 'swimming', ',', 'is', 'he', '?', '<eos>']
# ['<sos>', 'choose', 'carefully', '.', '<eos>']
# ['<sos>', 'she', 'has', 'done', 'her', 'homework', '.', '<eos>']
# ['<sos>', 'he', "'", 's', 'always', 'looking', 'at', 'you', '.', 'he', 'must', 'love', 'you', '.', '<eos>']
# ['<sos>', 'i', 'didn', "'", 't', 'know', 'tom', 'was', 'a', 'drug', 'addict', '.', '<eos>']
# ['<sos>', 'should', 'i', 'learn', 'french', '?', '<eos>']
# ['<sos>', 'she', 'forced', 'him', 'to', 'sit', 'down', '.', '<eos>']
# ['<sos>', 'let', "'", 's', 'hear', 'the', 'rest', 'of', 'the', 'story', '.', '<eos>']
# ['<sos>', 'will', 'tom', 'come', 'with', 'his', 'wife', ',', 'or', 'alone', '?', '<eos>']
# ['<sos>', 'i', 'can', 'assure', 'you', 'that', "'", 's', 'not', 'going', 'to', 'happen', '.', '<eos>']
# ['<sos>', 'i', 'never', 'should', "'", 've', 'gotten', 'divorced', '.', '<eos>']
# ['<sos>', 'two', 'beers', ',', 'please', '.', '<eos>']
# ['<sos>', 'this', 'is', 'just', 'my', 'personal', 'opinion', '.', '<eos>']
# ['<sos>', 'i', 'don', "'", 't', 'write', 'letters', 'anymore', '.', '<eos>']
# ['<sos>', 'wait', '!', '<eos>']
# ['<sos>', 'i', 'recommend', 'that', 'you', 'learn', 'french', '.', '<eos>']
# ['<sos>', 'the', 'flight', 'will', 'be', 'delayed', 'because', 'of', 'a', 'sandstorm', '.', '<eos>']
# ['<sos>', 'depression', 'is', 'common', 'among', 'young', 'adults', 'who', 'have', 'asperger', 'syndrome', '.', '<eos>']
# ['<sos>', 'it', "'", 's', 'good', '.', '<eos>']
# ['<sos>', 'tom', 'often', 'lets', 'me', 'use', 'his', 'car', '.', '<eos>']
# ['<sos>', 'i', 'often', 'play', 'tennis', 'with', 'tom', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'just', 'watching', 'television', '.', '<eos>']
# ['<sos>', 'how', 'much', 'did', 'these', 'sunglasses', 'cost', '?', '<eos>']
# ['<sos>', 'when', 'was', 'the', 'last', 'time', 'you', 'saw', 'that', 'cat', '?', '<eos>']
# ['<sos>', 'stay', 'calm', '.', '<eos>']
# ['<sos>', 'have', 'you', 'ever', 'really', 'been', 'in', 'love', '?', '<eos>']
# ['<sos>', 'where', "'", 's', 'tom', "'", 's', 'file', '?', '<eos>']
# ['<sos>', 'tom', 'said', 'he', 'wanted', 'to', 'hire', 'someone', 'with', 'experience', '.', '<eos>']
# ['<sos>', 'this', 'bread', 'looks', 'delicious', '.', '<eos>']
# ['<sos>', 'tom', 'wanted', 'to', 'learn', 'how', 'to', 'tango', '.', '<eos>']
# ['<sos>', 'painting', 'our', 'house', 'took', 'much', 'longer', 'than', 'we', 'expected', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'a', 'timid', 'kid', '.', '<eos>']
# ['<sos>', 'fantastic', '!', '<eos>']
# ['<sos>', 'ignore', 'tom', '.', '<eos>']
# ['<sos>', 'help', 'me', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'learning', 'how', 'to', 'drive', '.', '<eos>']
# ['<sos>', 'i', 'thought', 'you', 'hated', 'me', '.', '<eos>']
# ['<sos>', 'tom', 'and', 'mary', 'are', 'in', 'the', 'same', 'boat', '.', '<eos>']
# ['<sos>', 'show', 'me', '.', '<eos>']
# ['<sos>', 'he', 'did', 'not', 'want', 'her', 'to', 'leave', '.', '<eos>']
# ['<sos>', 'have', 'you', 'ever', 'been', 'on', 'a', 'helicopter', '?', '<eos>']
# ['<sos>', 'tom', 'is', 'in', 'his', 'room', 'most', 'of', 'the', 'time', '.', '<eos>']
# ['<sos>', 'it', 'looks', 'like', 'it', "'", 'll', 'rain', '.', '<eos>']
# ['<sos>', 'i', 'hear', 'that', 'there', 'are', 'people', 'in', 'japan', 'that', 'keep', 'penguins', 'as', 'pets', '.', '<eos>']
# ['<sos>', 'he', 'loves', 'trains', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'trying', 'to', 'act', 'casual', '.', '<eos>']
# ['<sos>', 'i', 'want', 'to', 'get', 'out', 'here', 'as', 'soon', 'as', 'i', 'can', '.', '<eos>']
# ['<sos>', 'champagne', ',', 'please', '.', '<eos>']
# ['<sos>', 'one', 'plus', 'one', 'equals', 'two', '.', '<eos>']
# ['<sos>', 'do', 'you', 'know', 'who', 'i', 'am', '?', '<eos>']
# ['<sos>', 'stop', 'overreacting', '.', '<eos>']
# ['<sos>', 'he', 'asked', 'us', 'to', 'help', 'him', '.', '<eos>']
# ['<sos>', 'no', 'other', 'lake', 'in', 'japan', 'is', 'as', 'large', 'as', 'lake', 'biwa', '.', '<eos>']
# ['<sos>', 'tom', 'was', 'very', 'disrespectful', '.', '<eos>']
# ['<sos>', 'you', 'know', 'that', 'that', "'", 's', 'not', 'possible', ',', 'don', "'", 't', 'you', '?', '<eos>']
# ['<sos>', 'we', 'were', 'born', 'to', 'die', '.', '<eos>']
# ['<sos>', 'will', 'you', 'lend', 'me', 'your', 'knife', '?', '<eos>']
# ['<sos>', 'he', 'seldom', 'goes', 'to', 'church', '.', '<eos>']
# ['<sos>', 'i', 'want', 'kids', ',', 'but', 'tom', 'doesn', "'", 't', '.', '<eos>']
# ['<sos>', 'an', 'accident', 'has', 'occurred', '.', '<eos>']
# ['<sos>', 'we', 'all', 'thought', 'that', 'tom', 'had', 'escaped', '.', '<eos>']
# ['<sos>', 'have', 'you', 'tested', 'it', 'yet', '?', '<eos>']
# ['<sos>', 'tom', 'is', 'bedridden', 'now', '.', '<eos>']
# ['<sos>', 'he', 'loves', 'going', 'to', 'the', 'theater', '.', '<eos>']
# ['<sos>', 'i', 'wish', 'i', "'", 'd', 'married', 'another', 'man', '.', '<eos>']
# ['<sos>', 'do', 'you', 'have', 'any', 'fresh', 'pasta', '?', '<eos>']
# ['<sos>', 'hold', 'this', '.', '<eos>']
# ['<sos>', 'have', 'you', 'ever', 'donated', 'blood', '?', '<eos>']
# ['<sos>', 'you', 'can', "'", 't', 'give', 'up', 'on', 'tom', '.', '<eos>']
# ['<sos>', 'that', 'was', 'no', 'ordinary', 'storm', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'not', 'an', 'idle', 'boy', 'any', 'longer', '.', '<eos>']
# ['<sos>', 'he', 'made', 'his', 'will', 'last', 'year', '.', '<eos>']
# ['<sos>', 'tom', "'", 's', 'attitude', 'has', 'changed', '.', '<eos>']
# ['<sos>', 'i', 'wish', 'i', 'were', 'somewhere', 'else', '.', '<eos>']
# ['<sos>', 'my', 'father', 'is', 'home', '.', '<eos>']
# ['<sos>', 'you', 'haven', "'", 't', 'told', 'tom', 'you', "'", 're', 'married', ',', 'have', 'you', '?', '<eos>']
# ['<sos>', 'he', 'can', 'speak', 'and', 'write', 'french', '.', '<eos>']
# ['<sos>', 'i', 'need', 'caffeine', '.', '<eos>']
# ['<sos>', 'is', 'there', 'a', 'woman', 'in', 'your', 'life', '?', '<eos>']
# ['<sos>', 'i', 'want', 'to', 'know', 'how', 'i', 'can', 'lose', 'weight', '.', '<eos>']
# ['<sos>', 'the', 'moon', 'has', 'set', '.', '<eos>']
# ['<sos>', 'relax', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'a', 'muslim', '.', '<eos>']
# ['<sos>', 'tom', 'clasped', 'his', 'hands', 'behind', 'his', 'head', '.', '<eos>']
# ['<sos>', 'sorry', 'for', 'being', 'late', '.', '<eos>']
# ['<sos>', 'how', 'horrible', '!', '<eos>']
# ['<sos>', 'ask', 'anyone', '.', '<eos>']
# ['<sos>', 'the', 'leaves', 'are', 'yellow', '.', '<eos>']
# ['<sos>', 'do', 'you', 'think', 'croatian', 'is', 'an', 'interesting', 'language', '?', '<eos>']
# ['<sos>', 'we', 'succeeded', '.', '<eos>']
# ['<sos>', 'don', "'", 't', 'believe', 'everything', 'people', 'tell', 'you', '.', '<eos>']
# ['<sos>', 'tom', 'knows', 'i', 'hate', 'spinach', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'wearing', 'a', 'yellow', 'shirt', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'happiest', 'when', 'i', "'", 'm', 'singing', '.', '<eos>']
# ['<sos>', 'will', 'you', 'join', 'me', 'for', 'breakfast', '?', '<eos>']
# ['<sos>', 'it', "'", 'll', 'be', 'ready', 'by', 'six', 'this', 'evening', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'the', 'best', 'drummer', 'in', 'boston', '.', '<eos>']
# ['<sos>', 'can', 'i', 'touch', 'it', '?', '<eos>']
# ['<sos>', 'he', 'is', 'a', 'rude', 'person', '.', '<eos>']
# ['<sos>', 'did', 'you', 'see', 'the', 'eclipse', 'yesterday', '?', '<eos>']
# ['<sos>', 'i', 'think', 'tom', 'would', 'be', 'thrilled', '.', '<eos>']
# ['<sos>', 'this', 'is', 'my', 'school', '.', '<eos>']
# ['<sos>', 'how', 'many', 'eggs', 'did', 'you', 'buy', '?', '<eos>']
# ['<sos>', 'that', "'", 's', 'not', 'it', '.', '<eos>']
# ['<sos>', 'i', 'can', 'go', 'tomorrow', '.', '<eos>']
# ['<sos>', 'they', 'said', 'no', '.', '<eos>']
# ['<sos>', 'under', 'a', 'microscope', ',', 'some', 'viruses', 'appear', 'quite', 'beautiful', '.', '<eos>']
# ['<sos>', 'he', 'was', 'at', 'the', 'bottom', 'of', 'the', 'class', '.', '<eos>']
# ['<sos>', 'i', 'regret', 'that', 'i', 'did', 'not', 'work', 'harder', '.', '<eos>']
# ['<sos>', 'which', 'newspaper', 'do', 'you', 'read', '?', '<eos>']
# ['<sos>', 'tom', 'is', 'breathing', 'deeply', '.', '<eos>']
# ['<sos>', 'tom', 'told', 'me', 'he', 'hasn', "'", 't', 'seen', 'mary', 'in', 'months', '.', '<eos>']
# ['<sos>', 'wait', '.', '<eos>']
# ['<sos>', 'please', 'sit', '.', '<eos>']
# ['<sos>', 'let', "'", 's', 'sing', 'and', 'dance', '.', '<eos>']
# ['<sos>', 'is', 'it', 'true', '?', '<eos>']
# ['<sos>', 'i', "'", 'd', 'like', 'to', 'check', 'out', '.', '<eos>']
# ['<sos>', 'our', 'car', 'is', 'three', 'years', 'older', 'than', 'yours', '.', '<eos>']
# ['<sos>', 'you', 'can', "'", 't', 'force', 'yourself', 'to', 'forget', 'something', '.', '<eos>']
# ['<sos>', 'tom', 'overslept', '.', '<eos>']
# ['<sos>', 'you', 'should', 'try', 'this', '.', 'it', "'", 's', 'delicious', '.', '<eos>']
# ['<sos>', 'tom', 'sent', 'us', 'christmas', 'presents', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'a', 'careful', 'man', '.', '<eos>']
# ['<sos>', 'i', 'have', 'to', 'say', 'i', 'envy', 'you', '.', '<eos>']
# ['<sos>', 'these', 'scissors', 'don', "'", 't', 'cut', 'well', '.', '<eos>']
# ['<sos>', 'how', 'many', 'children', 'were', 'injured', '?', '<eos>']
# ['<sos>', 'i', 'can', "'", 't', 'answer', 'your', 'question', '.', '<eos>']
# ['<sos>', 'i', 'hope', 'that', 'we', 'don', "'", 't', 'have', 'to', 'wait', 'for', 'too', 'long', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'a', 'great', 'french', 'teacher', '.', '<eos>']
# ['<sos>', 'i', 'can', 'teach', 'french', 'to', 'tom', '.', '<eos>']
# ['<sos>', 'tom', 'has', 'quite', 'a', 'lot', 'of', 'money', '.', '<eos>']
# ['<sos>', 'everybody', 'is', 'equal', 'before', 'the', 'law', '.', '<eos>']
# ['<sos>', 'i', 'haven', "'", 't', 'finished', 'this', 'yet', '.', '<eos>']
# ['<sos>', 'are', 'you', 'sure', 'you', 'want', 'to', 'go', 'to', 'boston', 'with', 'tom', '?', '<eos>']
# ['<sos>', 'i', 'know', 'your', 'mother', '.', '<eos>']
# ['<sos>', 'i', 'thought', 'that', 'i', 'heard', 'gunshots', '.', '<eos>']
# ['<sos>', 'i', 'think', 'what', 'tom', 'is', 'doing', 'is', 'amazing', '.', '<eos>']
# ['<sos>', 'we', 'overslept', '.', '<eos>']
# ['<sos>', 'many', 'people', 'act', 'like', 'that', '.', '<eos>']
# ['<sos>', 'help', '!', '<eos>']
# ['<sos>', 'tom', 'has', 'more', 'money', 'than', 'i', 'do', '.', '<eos>']
# ['<sos>', 'i', 'may', 'die', 'tomorrow', '.', '<eos>']
# ['<sos>', 'it', 'was', 'raining', 'outside', '.', '<eos>']
# ['<sos>', 'i', 'wasn', "'", 't', 'even', 'here', '.', '<eos>']
# ['<sos>', 'i', 'wish', 'i', 'could', 'remember', 'everything', 'tom', 'told', 'me', '.', '<eos>']
# ['<sos>', 'then', 'what', '?', '<eos>']
# ['<sos>', 'what', "'", 's', 'this', 'smell', '?', '<eos>']
# ['<sos>', 'the', 'baby', 'was', 'crying', 'in', 'bed', '.', '<eos>']
# ['<sos>', 'tom', 'blushed', '.', '<eos>']
# ['<sos>', 'the', 'answer', "'", 's', 'yes', '.', '<eos>']
# ['<sos>', 'got', 'it', '!', '<eos>']
# ['<sos>', 'tom', 'looks', 'old', 'for', 'his', 'age', '.', '<eos>']
# ['<sos>', 'let', "'", 's', 'sing', 'and', 'dance', '.', '<eos>']
# ['<sos>', 'i', 'really', 'love', 'french', '.', '<eos>']
# ['<sos>', 'i', 'know', 'tom', 'is', 'a', 'very', 'generous', 'man', '.', '<eos>']
# ['<sos>', 'thanks', 'for', 'taking', 'care', 'of', 'tom', '.', '<eos>']
# ['<sos>', 'i', 'should', "'", 've', 'bought', 'more', 'food', '.', '<eos>']
# ['<sos>', 'i', 'don', "'", 't', 'want', 'to', 'die', 'here', '.', '<eos>']
# ['<sos>', 'it', 'may', 'take', 'over', 'an', 'hour', '.', '<eos>']
# ['<sos>', 'i', 'don', "'", 't', 'know', 'anybody', 'in', 'boston', '.', '<eos>']
# ['<sos>', 'tom', 'doesn', "'", 't', 'usually', 'sing', 'in', 'french', '.', '<eos>']
# ['<sos>', 'i', 'will', 'go', 'on', 'ahead', '.', '<eos>']
# ['<sos>', 'would', 'you', 'be', 'happier', 'with', 'tom', '?', '<eos>']
# ['<sos>', 'am', 'i', 'alone', 'here', '?', '<eos>']
# ['<sos>', 'what', "'", 're', 'you', 'doing', '?', '<eos>']
# ['<sos>', 'what', 'does', 'this', 'mean', '?', '<eos>']
# ['<sos>', 'we', 'can', 'take', 'the', 'subway', 'there', '.', '<eos>']
# ['<sos>', 'get', 'some', 'rest', '.', '<eos>']
# ['<sos>', 'i', 'sincerely', 'regret', 'having', 'caused', 'you', 'such', 'an', 'inconvenience', '.', '<eos>']
# ['<sos>', 'they', 'live', 'on', 'the', '12th', 'floor', 'of', 'this', 'condo', '.', '<eos>']
# ['<sos>', 'how', 'much', 'money', 'did', 'you', 'lose', 'today', '?', '<eos>']
# ['<sos>', 'i', 'really', 'wanted', 'to', 'help', '.', '<eos>']
# ['<sos>', 'i', 'didn', "'", 't', 'know', 'you', 'loved', 'tom', 'so', 'much', '.', '<eos>']
# ['<sos>', 'selling', 'cars', 'is', 'my', 'job', '.', '<eos>']
# ['<sos>', 'how', 'curious', '!', '<eos>']
# ['<sos>', 'she', 'has', 'a', 'dog', 'and', 'six', 'cats', '.', '<eos>']
# ['<sos>', 'nobody', 'remembered', 'my', 'birthday', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'not', 'tired', '.', '<eos>']
# ['<sos>', 'tom', 'doesn', "'", 't', 'believe', 'in', 'evolution', '.', '<eos>']
# ['<sos>', 'he', "'", 's', 'studying', 'french', 'and', 'web', 'design', '.', '<eos>']
# ['<sos>', 'could', 'you', 'give', 'me', 'an', 'example', '?', '<eos>']
# ['<sos>', 'ignore', 'that', '.', '<eos>']
# ['<sos>', 'your', 'plan', 'failed', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'a', 'very', 'talkative', 'person', '.', '<eos>']
# ['<sos>', 'did', 'you', 'stop', 'at', 'the', 'red', 'light', '?', '<eos>']
# ['<sos>', 'it', "'", 's', 'beautiful', 'weather', ',', 'isn', "'", 't', 'it', '?', '<eos>']
# ['<sos>', 'this', 'is', 'so', 'relaxing', '.', '<eos>']
# ['<sos>', 'that', "'", 's', 'all', 'we', 'wanted', '.', '<eos>']
# ['<sos>', 'tom', 'said', 'he', "'", 's', 'weak', '.', '<eos>']
# ['<sos>', 'what', 'was', 'the', 'matter', 'this', 'morning', '?', '<eos>']
# ['<sos>', 'antibiotics', 'can', "'", 't', 'kill', 'viruses', '.', '<eos>']
# ['<sos>', 'you', "'", 're', 'mine', '.', '<eos>']
# ['<sos>', 'where', 'did', 'you', 'learn', 'to', 'write', '?', '<eos>']
# ['<sos>', 'tom', 'dressed', 'up', 'as', 'cowboy', 'for', 'halloween', '.', '<eos>']
# ['<sos>', 'i', 'was', 'forced', 'to', 'go', '.', '<eos>']
# ['<sos>', 'i', 'have', 'time', 'to', 'do', 'that', 'this', 'week', '.', '<eos>']
# ['<sos>', 'i', 'wonder', 'whether', 'tom', 'really', 'likes', 'boston', '.', '<eos>']
# ['<sos>', 'tom', 'said', 'he', 'was', 'very', 'lonely', '.', '<eos>']
# ['<sos>', 'i', 'think', 'this', 'is', 'ridiculous', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'as', 'thin', 'as', 'a', 'rail', '.', '<eos>']
# ['<sos>', 'promise', 'me', 'you', 'won', "'", 't', 'do', 'anything', 'stupid', '.', '<eos>']
# ['<sos>', 'i', 'know', 'that', 'i', 'might', 'not', 'have', 'to', 'do', 'that', 'today', '.', '<eos>']
# ['<sos>', 'you', ',', 'too', ',', 'can', 'learn', 'french', '.', '<eos>']
# ['<sos>', 'tom', 'and', 'mary', 'broke', 'up', 'last', 'week', '.', '<eos>']
# ['<sos>', 'this', 'sounds', 'reasonable', '.', '<eos>']
# ['<sos>', 'that', "'", 's', 'not', 'what', 'tom', 'wants', 'to', 'do', '.', '<eos>']
# ['<sos>', 'that', "'", 's', 'my', 'favorite', 'french', 'word', '.', '<eos>']
# ['<sos>', 'don', "'", 't', 'try', 'to', 'talk', '.', 'save', 'your', 'energy', '.', '<eos>']
# ['<sos>', 'please', 'let', 'us', 'know', '.', '<eos>']
# ['<sos>', 'i', 'don', "'", 't', 'want', 'to', 'waste', 'time', 'on', 'this', 'problem', '.', '<eos>']
# ['<sos>', 'i', 'spent', 'two', 'hours', 'reading', 'a', 'book', 'last', 'night', '.', '<eos>']
# ['<sos>', 'i', 'love', 'music', '.', '<eos>']
# ['<sos>', 'tom', 'wants', 'to', 'stay', 'home', 'tonight', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'still', 'optimistic', 'about', 'the', 'project', '.', '<eos>']
# ['<sos>', 'tom', 'knits', '.', '<eos>']
# ['<sos>', 'boil', 'some', 'water', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'a', 'great', 'manager', '.', '<eos>']
# ['<sos>', 'this', 'is', 'not', 'true', '.', '<eos>']
# ['<sos>', 'how', "'", 's', 'work', '?', '<eos>']
# ['<sos>', 'i', 'will', 'never', 'forgive', 'you', '.', '<eos>']
# ['<sos>', 'i', 'saw', 'him', 'crossing', 'the', 'road', '.', '<eos>']
# ['<sos>', 'my', 'watch', 'is', 'different', 'than', 'yours', '.', '<eos>']
# ['<sos>', 'tom', 'says', 'he', "'", 's', 'almost', 'ready', 'to', 'leave', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'aware', 'this', 'is', 'monday', '.', '<eos>']
# ['<sos>', 'common', 'causes', 'of', 'stress', 'are', 'work', 'and', 'human', 'relationships', '.', '<eos>']
# ['<sos>', 'that', "'", 's', 'my', 'dog', '.', '<eos>']
# ['<sos>', 'text', 'me', '.', '<eos>']
# ['<sos>', 'are', 'you', 'involved', '?', '<eos>']
# ['<sos>', 'that', 'made', 'me', 'nervous', '.', '<eos>']
# ['<sos>', 'don', "'", 't', 'lie', 'to', 'us', '.', '<eos>']
# ['<sos>', 'i', 'don', "'", 't', 'believe', 'tom', 'is', 'a', 'murderer', '.', '<eos>']
# ['<sos>', 'tom', 'apologized', '.', '<eos>']
# ['<sos>', 'don', "'", 't', 'wake', 'him', 'up', '.', '<eos>']
# ['<sos>', 'do', 'you', 'like', 'fish', '?', '<eos>']
# ['<sos>', 'let', 'me', 'pay', '.', '<eos>']
# ['<sos>', 'i', 'think', 'that', 'tom', 'is', 'great', '.', '<eos>']
# ['<sos>', 'how', 'much', 'time', 'will', 'it', 'take', 'to', 'do', 'this', '?', '<eos>']
# ['<sos>', 'no', 'one', 'was', 'at', 'home', '.', '<eos>']
# ['<sos>', 'everyone', 'stood', '.', '<eos>']
# ['<sos>', 'someone', 'has', 'died', '.', '<eos>']
# ['<sos>', 'what', 'are', 'you', 'two', 'arguing', 'about', '?', '<eos>']
# ['<sos>', 'i', 'forgot', 'that', 'tom', 'spoke', 'french', '.', '<eos>']
# ['<sos>', 'who', "'", 's', 'your', 'favorite', 'tennis', 'player', '?', '<eos>']
# ['<sos>', 'i', 'like', 'beer', '.', '<eos>']
# ['<sos>', 'wait', 'here', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'thinking', 'about', 'going', 'back', 'into', 'teaching', '.', '<eos>']
# ['<sos>', 'tom', 'was', 'a', 'troubled', 'child', '.', '<eos>']
# ['<sos>', 'i', 'arrived', 'last', 'night', '.', '<eos>']
# ['<sos>', 'he', 'took', 'a', 'short', 'cut', '.', '<eos>']
# ['<sos>', 'there', "'", 's', 'a', 'storm', 'coming', '.', '<eos>']
# ['<sos>', 'tom', 'moaned', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'having', 'a', 'hard', 'time', 'focusing', '.', '<eos>']
# ['<sos>', 'we', 'went', 'to', 'boston', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'a', 'human', 'being', '.', '<eos>']
# ['<sos>', 'it', 'snowed', 'a', 'lot', 'last', 'year', '.', '<eos>']
# ['<sos>', 'lawyers', 'are', 'all', 'liars', '.', '<eos>']
# ['<sos>', 'we', 'used', 'the', 'computer', 'in', 'order', 'to', 'save', 'time', '.', '<eos>']
# ['<sos>', 'look', '!', 'there', "'", 's', 'a', 'cat', 'in', 'the', 'kitchen', '.', '<eos>']
# ['<sos>', 'it', "'", 's', 'one', 'thing', 'to', 'make', 'plans', ',', 'but', 'quite', 'another', 'to', 'carry', 'them', 'out', '.', '<eos>']
# ['<sos>', 'a', 'dog', 'was', 'following', 'tom', '.', '<eos>']
# ['<sos>', 'certain', 'religions', 'are', 'against', 'organ', 'donation', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'not', 'young', 'anymore', '.', '<eos>']
# ['<sos>', 'i', "'", 'll', 'come', 'back', 'later', '.', '<eos>']
# ['<sos>', 'this', 'game', 'is', 'a', 'lot', 'of', 'fun', '.', '<eos>']
# ['<sos>', 'there', "'", 's', 'nothing', 'worse', 'than', 'loneliness', '.', '<eos>']
# ['<sos>', 'mary', 'and', 'i', 'are', 'engaged', '.', '<eos>']
# ['<sos>', 'yes', ',', 'i', 'kissed', 'him', '.', '<eos>']
# ['<sos>', 'i', "'", 'd', 'accept', '.', '<eos>']
# ['<sos>', 'i', 'didn', "'", 't', 'think', 'that', 'we', 'had', 'any', 'chance', 'of', 'winning', '.', '<eos>']
# ['<sos>', 'all', 'of', 'a', 'sudden', ',', 'she', 'began', 'to', 'laugh', '.', '<eos>']
# ['<sos>', 'i', 'don', "'", 't', 'feel', 'anything', 'at', 'all', '.', '<eos>']
# ['<sos>', 'sputnik', 'was', 'launched', 'on', 'october', '4', ',', '1957', '.', '<eos>']
# ['<sos>', 'almost', 'everyone', 'arrived', 'on', 'time', '.', '<eos>']
# ['<sos>', 'there', 'are', 'children', 'here', '.', '<eos>']
# ['<sos>', 'we', 'agree', '.', '<eos>']
# ['<sos>', 'tom', 'prevented', 'mary', 'from', 'doing', 'that', '.', '<eos>']
# ['<sos>', 'my', 'french', 'would', 'likely', 'be', 'much', 'better', 'today', 'if', 'i', "'", 'd', 'studied', 'with', 'a', 'native', 'speaker', '.', '<eos>']
# ['<sos>', 'he', 'laughed', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'too', 'weak', 'to', 'walk', 'that', 'far', '.', '<eos>']
# ['<sos>', 'we', 'need', 'your', 'advice', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'a', 'good', 'friend', 'of', 'yours', ',', 'isn', "'", 't', 'he', '?', '<eos>']
# ['<sos>', 'how', 'tragic', '!', '<eos>']
# ['<sos>', 'some', 'children', 'don', "'", 't', 'like', 'vegetables', '.', '<eos>']
# ['<sos>', 'have', 'you', 'ever', 'been', 'to', 'this', 'beach', 'before', '?', '<eos>']
# ['<sos>', 'tom', 'turned', 'off', 'his', 'computer', '.', '<eos>']
# ['<sos>', 'where', 'does', 'that', 'bus', 'go', '?', '<eos>']
# ['<sos>', 'nothing', 'happened', '.', '<eos>']
# ['<sos>', 'i', 'have', 'attempted', 'suicide', 'two', 'times', '.', '<eos>']
# ['<sos>', 'they', "'", 're', 'watching', 'you', '.', '<eos>']
# ['<sos>', 'i', 'don', "'", 't', 'have', 'money', ',', 'but', 'i', 'have', 'dreams', '.', '<eos>']
# ['<sos>', 'tom', 'has', 'braided', 'his', 'beard', '.', '<eos>']
# ['<sos>', 'tom', 'will', 'have', 'a', 'hard', 'time', '.', '<eos>']
# ['<sos>', 'something', 'is', 'happening', '.', '<eos>']
# ['<sos>', 'a', 'person', 'who', 'steals', 'deserves', 'punishment', '.', '<eos>']
# ['<sos>', 'that', "'", 's', 'nonsense', '.', '<eos>']
# ['<sos>', 'do', 'you', 'want', 'to', 'help', '?', '<eos>']
# ['<sos>', 'i', 'think', 'we', 'should', 'do', 'something', 'stupid', '.', '<eos>']
# ['<sos>', 'tom', 'wakes', 'up', 'at', 'sixthirty', 'every', 'morning', '.', '<eos>']
# ['<sos>', 'you', "'", 'll', 'regret', 'it', '.', '<eos>']
# ['<sos>', 'tom', 'kept', 'looking', 'at', 'mary', '.', '<eos>']
# ['<sos>', 'they', "'", 're', 'green', '.', '<eos>']
# ['<sos>', 'may', 'god', 'bless', 'you', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'an', 'electrical', 'engineer', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'living', 'alone', 'in', 'a', 'hut', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'sorry', ',', 'but', 'i', 'don', "'", 't', 'understand', '.', '<eos>']
# ['<sos>', 'in', '1950', ',', 'north', 'korea', 'invaded', 'south', 'korea', '.', '<eos>']
# ['<sos>', 'muscles', 'are', 'made', 'of', 'hundreds', 'of', 'thin', 'fibers', '.', '<eos>']
# ['<sos>', 'i', 'used', 'to', 'dream', 'about', 'becoming', 'a', 'model', '.', '<eos>']
# ['<sos>', 'i', "'", 'll', 'see', 'you', 'at', 'the', 'restaurant', '.', '<eos>']
# ['<sos>', 'i', 'read', 'a', 'book', 'in', 'french', '.', '<eos>']
# ['<sos>', 'nobody', 'died', '.', '<eos>']
# ['<sos>', 'grab', 'a', 'spoon', '.', '<eos>']
# ['<sos>', 'greece', 'has', 'many', 'islands', '.', '<eos>']
# ['<sos>', 'where', "'", 's', 'my', 'apple', 'juice', '?', '<eos>']
# ['<sos>', 'excuse', 'me', ',', 'where', 'is', 'the', 'exit', '?', '<eos>']
# ['<sos>', 'you', 'called', '?', '<eos>']
# ['<sos>', 'his', 'sudden', 'appearance', 'surprised', 'us', 'all', '.', '<eos>']
# ['<sos>', 'unfortunately', ',', 'nobody', 'told', 'us', '.', '<eos>']
# ['<sos>', 'he', 'runs', 'very', 'fast', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'nervous', '.', '<eos>']
# ['<sos>', 'i', 'don', "'", 't', 'like', 'being', 'cheated', '.', '<eos>']
# ['<sos>', 'i', 'took', 'this', 'picture', 'a', 'week', 'ago', '.', '<eos>']
# ['<sos>', 'i', 'misunderstood', '.', '<eos>']
# ['<sos>', 'i', 'haven', "'", 't', 'been', 'honest', 'with', 'you', '.', '<eos>']
# ['<sos>', 'why', 'should', 'i', 'learn', 'french', '?', '<eos>']
# ['<sos>', 'where', 'is', 'the', 'screwdriver', '?', '<eos>']
# ['<sos>', 'they', 'all', 'were', 'wrong', '.', '<eos>']
# ['<sos>', 'she', 'has', 'small', 'feet', '.', '<eos>']
# ['<sos>', 'tom', 'cut', 'his', 'own', 'hair', '.', '<eos>']
# ['<sos>', 'do', 'you', 'remember', 'my', 'name', '?', '<eos>']
# ['<sos>', 'let', "'", 's', 'go', '!', '<eos>']
# ['<sos>', 'grab', 'tom', '.', '<eos>']
# ['<sos>', 'i', 'don', "'", 't', 'want', 'to', 'be', 'alone', 'again', '.', '<eos>']
# ['<sos>', 'i', "'", 'd', 'advise', 'doing', 'that', '.', '<eos>']
# ['<sos>', 'it', "'", 's', 'lunch', 'time', '.', '<eos>']
# ['<sos>', 'look', 'at', 'the', 'clock', '.', '<eos>']
# ['<sos>', 'everybody', 'lies', '.', '<eos>']
# ['<sos>', 'thanks', '.', '<eos>']
# ['<sos>', 'tom', 'graduated', '.', '<eos>']
# ['<sos>', 'i', 'wish', 'i', 'were', 'younger', '.', '<eos>']
# ['<sos>', 'tom', 'left', 'mary', '.', '<eos>']
# ['<sos>', 'tom', ',', 'mary', ',', 'john', 'and', 'alice', 'can', 'all', 'swim', '.', '<eos>']
# ['<sos>', 'fire', 'burns', '.', '<eos>']
# ['<sos>', 'tom', 'died', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'optimistic', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'taking', 'a', 'french', 'class', '.', '<eos>']
# ['<sos>', 'it', "'", 's', 'about', 'time', 'you', 'went', 'to', 'bed', '.', '<eos>']
# ['<sos>', 'gas', 'prices', 'are', 'up', '.', '<eos>']
# ['<sos>', 'keep', 'singing', '.', '<eos>']
# ['<sos>', 'start', 'over', '.', '<eos>']
# ['<sos>', 'tom', 'could', "'", 've', 'been', 'seriously', 'injured', '.', '<eos>']
# ['<sos>', 'how', 'many', 'years', 'did', 'you', 'live', 'in', 'boston', '?', '<eos>']
# ['<sos>', 'where', "'", 's', 'tom', 'hiding', '?', '<eos>']
# ['<sos>', 'i', 'thought', 'i', 'heard', 'gunshots', '.', '<eos>']
# ['<sos>', 'tom', 'thinks', 'that', 'i', "'", 'm', 'romantic', '.', '<eos>']
# ['<sos>', 'i', 'remember', 'seeing', 'you', 'before', '.', '<eos>']
# ['<sos>', 'he', 'kept', 'me', 'waiting', '.', '<eos>']
# ['<sos>', 'they', 'made', 'fun', 'of', 'mary', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'sorry', 'i', 'left', 'without', 'you', '.', '<eos>']
# ['<sos>', 'you', 'should', 'do', 'that', 'by', 'yourself', '.', '<eos>']
# ['<sos>', 'this', 'room', 'is', 'too', 'big', '.', '<eos>']
# ['<sos>', 'tom', 'ran', 'for', 'it', '.', '<eos>']
# ['<sos>', 'do', 'you', 'really', 'think', 'we', 'can', 'help', '?', '<eos>']
# ['<sos>', 'tom', 'has', 'talent', '.', '<eos>']
# ['<sos>', 'i', 'am', 'an', 'honest', 'person', '.', '<eos>']
# ['<sos>', 'there', 'was', 'an', 'accident', '.', '<eos>']
# ['<sos>', 'i', "'", 've', 'never', 'loved', 'you', '.', '<eos>']
# ['<sos>', 'hurry', 'up', ',', 'or', 'you', "'", 'll', 'miss', 'your', 'plane', '.', '<eos>']
# ['<sos>', 'stop', '!', 'thief', '!', '<eos>']
# ['<sos>', 'i', "'", 'll', 'be', 'back', 'soon', '.', '<eos>']
# ['<sos>', 'everyone', "'", 's', 'going', 'to', 'be', 'there', '.', '<eos>']
# ['<sos>', 'neither', 'tom', 'nor', 'mary', 'was', 'injured', '.', '<eos>']
# ['<sos>', 'what', "'", 's', 'your', 'plan', '?', '<eos>']
# ['<sos>', 'you', "'", 're', 'not', 'mad', 'at', 'me', 'anymore', ',', 'are', 'you', '?', '<eos>']
# ['<sos>', 'i', 'think', 'i', "'", 'll', 'buy', 'a', 'new', 'car', '.', '<eos>']
# ['<sos>', 'is', 'it', 'true', 'that', 'you', "'", 're', 'a', 'high', 'school', 'teacher', '?', '<eos>']
# ['<sos>', 'it', "'", 's', 'really', 'hot', 'here', '.', '<eos>']
# ['<sos>', 'have', 'you', 'ever', 'thought', 'about', 'quitting', 'your', 'job', '?', '<eos>']
# ['<sos>', 'wood', 'burns', '.', '<eos>']
# ['<sos>', 'thanks', 'for', 'your', 'help', ',', 'tom', '.', '<eos>']
# ['<sos>', 'my', 'parents', 'came', 'to', 'see', 'me', 'off', 'at', 'the', 'airport', '.', '<eos>']
# ['<sos>', 'tom', 'didn', "'", 't', 'have', 'dinner', 'last', 'night', '.', '<eos>']
# ['<sos>', 'it', 'works', '.', '<eos>']
# ['<sos>', 'how', 'safe', 'are', 'ecigarettes', '?', '<eos>']
# ['<sos>', 'i', 'don', "'", 't', 'know', 'how', 'much', 'this', 'motorcycle', 'is', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'in', 'jail', '.', '<eos>']
# ['<sos>', 'tom', 'acts', 'like', 'a', 'child', '.', '<eos>']
# ['<sos>', 'i', 'have', 'an', 'older', 'sister', '.', '<eos>']
# ['<sos>', 'tom', 'climbed', 'the', 'mountain', '.', '<eos>']
# ['<sos>', 'there', 'you', 'are', '.', '<eos>']
# ['<sos>', 'these', 'apples', 'look', 'very', 'fresh', '.', '<eos>']
# ['<sos>', 'you', 'should', 'wear', 'a', 'hat', 'and', 'sunglasses', '.', '<eos>']
# ['<sos>', 'i', 'think', 'i', "'", 'll', 'buy', 'a', 'new', 'car', '.', '<eos>']
# ['<sos>', 'watch', 'out', '!', '<eos>']
# ['<sos>', 'do', 'you', 'like', 'it', '?', '<eos>']
# ['<sos>', 'i', 'won', "'", 't', 'force', 'you', 'to', 'do', 'that', ',', 'but', 'i', 'think', 'you', 'should', '.', '<eos>']
# ['<sos>', 'release', 'him', '.', '<eos>']
# ['<sos>', 'are', 'you', 'trying', 'to', 'hit', 'on', 'me', '?', '<eos>']
# ['<sos>', 'tom', 'was', 'too', 'old', '.', '<eos>']
# ['<sos>', 'can', 'you', 'tell', 'where', 'this', 'road', 'goes', '?', '<eos>']
# ['<sos>', 'quick', ',', 'hide', 'over', 'here', '!', '<eos>']
# ['<sos>', 'linux', 'is', 'open', 'source', 'software', '.', '<eos>']
# ['<sos>', 'you', "'", 're', 'quite', 'right', '.', '<eos>']
# ['<sos>', 'i', 'like', 'winter', '.', '<eos>']
# ['<sos>', 'i', 'enjoy', 'reading', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'extremely', 'shy', '.', '<eos>']
# ['<sos>', 'i', 'want', 'this', '.', '<eos>']
# ['<sos>', 'how', 'wonderful', '!', '<eos>']
# ['<sos>', 'don', "'", 't', 'waste', 'your', 'time', 'trying', 'to', 'convince', 'tom', '.', '<eos>']
# ['<sos>', 'keep', 'dancing', '.', '<eos>']
# ['<sos>', 'tom', 'isn', "'", 't', 'a', 'drug', 'addict', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'still', 'in', 'school', '.', '<eos>']
# ['<sos>', 'tom', 'wanted', 'a', 'bigger', 'discount', '.', '<eos>']
# ['<sos>', 'i', 'feel', 'much', 'better', '.', '<eos>']
# ['<sos>', 'i', 'think', 'that', 'that', "'", 's', 'inaccurate', '.', '<eos>']
# ['<sos>', 'he', 'talks', 'too', 'fast', '.', '<eos>']
# ['<sos>', 'we', 'had', 'a', 'good', 'time', 'yesterday', '.', '<eos>']
# ['<sos>', 'can', 'you', 'justify', 'your', 'action', '?', '<eos>']
# ['<sos>', 'my', 'daughter', 'is', 'only', 'three', 'years', 'old', '.', '<eos>']
# ['<sos>', 'actually', ',', 'we', 'don', "'", 't', 'have', 'a', 'choice', '.', '<eos>']
# ['<sos>', 'you', "'", 're', 'very', 'astute', '.', '<eos>']
# ['<sos>', 'do', 'you', 'think', 'animals', 'have', 'souls', '?', '<eos>']
# ['<sos>', 'oh', 'please', '!', '<eos>']
# ['<sos>', 'i', 'suddenly', 'got', 'very', 'worried', '.', '<eos>']
# ['<sos>', 'i', 'don', "'", 't', 'know', 'when', 'he', "'", 's', 'coming', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'too', 'fat', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'building', 'a', 'wall', '.', '<eos>']
# ['<sos>', 'that', "'", 's', 'my', 'only', 'focus', '.', '<eos>']
# ['<sos>', 'he', 'says', 'things', 'on', 'the', 'spur', 'of', 'the', 'moment', '.', '<eos>']
# ['<sos>', 'if', 'someone', 'who', 'doesn', "'", 't', 'know', 'your', 'background', 'says', 'that', 'you', 'sound', 'like', 'a', 'native', 'speaker', ',', 'it', 'means', 'they', 'probably', 'noticed', 'something', 'about', 'your', 'speaking', 'that', 'made', 'them', 'realize', 'you', 'weren', "'", 't', 'a', 'native', 'speaker', '.', 'in', 'other', 'words', ',', 'you', 'don', "'", 't', 'really', 'sound', 'like', 'a', 'native', 'speaker', '.', '<eos>']
# ['<sos>', 'please', 'relax', '.', '<eos>']
# ['<sos>', 'it', 'happened', 'in', 'boston', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'a', 'runner', '.', '<eos>']
# ['<sos>', 'tom', 'drinks', 'beer', '.', '<eos>']
# ['<sos>', 'are', 'there', 'any', 'girls', 'here', 'you', 'haven', "'", 't', 'yet', 'met', '?', '<eos>']
# ['<sos>', 'i', 'can', "'", 't', 'sleep', '.', '<eos>']
# ['<sos>', 'most', 'people', 'think', 'that', 'i', "'", 'm', 'crazy', '.', '<eos>']
# ['<sos>', 'the', 'old', 'church', 'by', 'the', 'lake', 'is', 'very', 'beautiful', '.', '<eos>']
# ['<sos>', 'nobody', 'came', '.', '<eos>']
# ['<sos>', 'why', 'are', 'you', 'always', 'late', 'for', 'school', '?', '<eos>']
# ['<sos>', 'how', 'deep', '?', '<eos>']
# ['<sos>', 'attack', '!', '<eos>']
# ['<sos>', 'i', 'haven', "'", 't', 'heard', 'from', 'anyone', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'canadian', ',', 'too', '.', '<eos>']
# ['<sos>', 'skip', 'the', 'boring', 'chapters', '.', '<eos>']
# ['<sos>', 'are', 'you', 'in', 'there', '?', '<eos>']
# ['<sos>', 'i', 'bought', 'myself', 'something', 'to', 'eat', '.', '<eos>']
# ['<sos>', 'keep', 'talking', '.', '<eos>']
# ['<sos>', 'i', 'don', "'", 't', 'like', 'your', 'name', '.', '<eos>']
# ['<sos>', 'we', "'", 'll', 'learn', 'the', 'truth', 'soon', '.', '<eos>']
# ['<sos>', 'tom', 'nodded', 'understandingly', '.', '<eos>']
# ['<sos>', 'would', 'you', 'like', 'coffee', 'or', 'tea', '?', '<eos>']
# ['<sos>', 'i', 'hate', 'eating', 'alone', '.', '<eos>']
# ['<sos>', 'tom', 'occasionally', 'prods', 'me', 'to', 'work', 'out', 'with', 'him', ',', 'but', 'i', "'", 'm', 'really', 'not', 'interested', '.', '<eos>']
# ['<sos>', 'can', 'you', 'give', 'me', 'directions', 'to', 'the', 'subway', 'station', '?', '<eos>']
# ['<sos>', 'drink', 'some', 'water', '.', '<eos>']
# ['<sos>', 'i', "'", 've', 'had', 'enough', 'of', 'your', 'shenanigans', '.', '<eos>']
# ['<sos>', 'did', 'you', 'know', 'him', '?', '<eos>']
# ['<sos>', 'i', 'wonder', 'if', 'tom', 'has', 'already', 'left', '.', '<eos>']
# ['<sos>', 'tom', 'folded', 'the', 'paper', 'before', 'handing', 'it', 'to', 'mary', '.', '<eos>']
# ['<sos>', 'give', 'me', 'the', 'file', '.', '<eos>']
# ['<sos>', 'what', "'", 're', 'you', 'doing', '?', '<eos>']
# ['<sos>', 'i', 'was', 'skiing', 'last', 'weekend', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'short', 'for', 'his', 'age', ',', 'isn', "'", 't', 'he', '?', '<eos>']
# ['<sos>', 'have', 'you', 'studied', 'darwin', "'", 's', 'theory', 'of', 'evolution', '?', '<eos>']
# ['<sos>', 'welcome', '.', '<eos>']
# ['<sos>', 'tom', 'wondered', 'what', 'mary', 'wanted', 'to', 'do', '.', '<eos>']
# ['<sos>', 'she', 'is', 'dressed', 'in', 'white', '.', '<eos>']
# ['<sos>', 'where', 'will', 'you', 'live', '?', '<eos>']
# ['<sos>', 'do', 'you', 'remember', '?', '<eos>']
# ['<sos>', 'hold', 'it', '!', '<eos>']
# ['<sos>', 'tom', 'and', 'mary', 'used', 'to', 'be', 'friends', ',', 'right', '?', '<eos>']
# ['<sos>', 'do', 'you', 'want', 'this', '?', '<eos>']
# ['<sos>', 'i', 'don', "'", 't', 'think', 'tom', 'is', 'able', 'to', 'do', 'that', '.', '<eos>']
# ['<sos>', 'perhaps', 'you', 'should', 'tell', 'tom', '.', '<eos>']
# ['<sos>', 'hold', 'still', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'afraid', 'of', 'dying', '.', '<eos>']
# ['<sos>', 'might', 'i', 'come', 'in', '?', '<eos>']
# ['<sos>', 'tom', 'clapped', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'tired', 'of', 'dancing', '.', '<eos>']
# ['<sos>', 'i', 'eat', 'tomatoes', ',', 'but', 'tom', 'doesn', "'", 't', '.', '<eos>']
# ['<sos>', 'you', "'", 're', 'the', 'one', 'who', 'gave', 'us', 'all', 'this', '.', '<eos>']
# ['<sos>', 'keep', 'digging', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'allowed', 'to', 'stay', '.', 'the', 'rest', 'of', 'you', 'have', 'to', 'leave', '.', '<eos>']
# ['<sos>', 'turn', 'left', '.', '<eos>']
# ['<sos>', 'tom', 'met', 'mary', 'in', '2013', '.', '<eos>']
# ['<sos>', 'tom', 'gasped', '.', '<eos>']
# ['<sos>', 'the', 'price', 'of', 'eggs', 'is', 'going', 'up', '.', '<eos>']
# ['<sos>', 'he', 'is', 'just', 'killing', 'time', '.', '<eos>']
# ['<sos>', 'she', 'ordered', 'a', 'cup', 'of', 'tea', '.', '<eos>']
# ['<sos>', 'it', 'is', 'said', 'that', 'he', 'was', 'very', 'rich', '.', '<eos>']
# ['<sos>', 'tom', 'can', 'read', ',', 'can', "'", 't', 'he', '?', '<eos>']
# ['<sos>', 'not', 'all', 'horses', 'were', 'born', 'equal', '.', 'a', 'few', 'were', 'born', 'to', 'win', '.', '<eos>']
# ['<sos>', 'i', 'don', "'", 't', 'translate', 'novels', 'anymore', '.', '<eos>']
# ['<sos>', 'you', 'should', 'smoke', 'less', '.', '<eos>']
# ['<sos>', 'the', 'sooner', ',', 'the', 'better', '.', '<eos>']
# ['<sos>', 'i', 'understand', '.', '<eos>']
# ['<sos>', 'she', 'is', 'easygoing', '.', '<eos>']
# ['<sos>', 'you', 'talked', 'to', 'tom', 'yesterday', ',', 'didn', "'", 't', 'you', '?', '<eos>']
# ['<sos>', 'tom', 'is', 'quite', 'motivated', '.', '<eos>']
# ['<sos>', 'everybody', 'wants', 'to', 'be', 'loved', '.', '<eos>']
# ['<sos>', 'i', 'only', 'did', 'the', 'bare', 'minimum', '.', '<eos>']
# ['<sos>', 'what', 'do', 'you', 'do', 'on', 'sundays', '?', '<eos>']
# ['<sos>', 'tom', 'said', 'that', 'book', 'was', 'interesting', '.', '<eos>']
# ['<sos>', 'she', 'lives', 'nearby', '.', '<eos>']
# ['<sos>', 'tom', 'said', 'mary', 'has', 'been', 'to', 'boston', 'three', 'times', '.', '<eos>']
# ['<sos>', 'what', 'fun', '!', '<eos>']
# ['<sos>', 'tom', 'isn', "'", 't', 'tall', 'for', 'his', 'age', '.', '<eos>']
# ['<sos>', 'is', 'that', 'all', 'you', 'want', 'to', 'say', '?', '<eos>']
# ['<sos>', 'i', "'", 'm', 'sick', 'of', 'cat', 'videos', '.', '<eos>']
# ['<sos>', 'that', "'", 's', 'my', 'dictionary', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'married', 'to', 'a', 'canadian', 'named', 'mary', '.', '<eos>']
# ['<sos>', 'hurry', 'up', ',', 'or', 'you', "'", 'll', 'be', 'late', 'for', 'school', '.', '<eos>']
# ['<sos>', 'his', 'long', 'speech', 'bored', 'us', 'all', '.', '<eos>']
# ['<sos>', 'we', 'know', 'what', 'tom', 'is', 'going', 'through', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'sorry', 'i', 'opened', 'my', 'mouth', '.', '<eos>']
# ['<sos>', 'i', 'like', 'your', 'cat', ',', 'but', 'she', 'doesn', "'", 't', 'like', 'me', '.', '<eos>']
# ['<sos>', 'get', 'into', 'the', 'car', '.', '<eos>']
# ['<sos>', 'i', 'thought', 'that', 'you', 'didn', "'", 't', 'want', 'anything', 'to', 'eat', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'quite', 'shy', ',', 'isn', "'", 't', 'he', '?', '<eos>']
# ['<sos>', 'what', 'causes', 'loneliness', '?', '<eos>']
# ['<sos>', 'how', 'did', 'you', 'know', 'tom', 'would', 'help', '?', '<eos>']
# ['<sos>', 'this', 'is', 'a', 'battle', 'worth', 'fighting', '.', '<eos>']
# ['<sos>', 'that', "'", 's', 'my', 'responsibility', '.', '<eos>']
# ['<sos>', 'i', 'have', 'to', 'leave', 'now', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'not', 'a', 'teacher', '.', '<eos>']
# ['<sos>', 'turn', 'around', '.', '<eos>']
# ['<sos>', 'i', 'was', 'at', 'home', 'yesterday', '.', '<eos>']
# ['<sos>', 'tom', 'drowned', '.', '<eos>']
# ['<sos>', 'pelicans', 'have', 'large', 'beaks', '.', '<eos>']
# ['<sos>', 'tom', 'attempted', 'suicide', '.', '<eos>']
# ['<sos>', 'tom', 'has', 'decided', 'to', 'get', 'his', 'house', 'repainted', '.', '<eos>']
# ['<sos>', 'what', 'we', 'need', 'is', 'a', 'break', '.', '<eos>']
# ['<sos>', 'my', 'grandfather', 'died', 'five', 'years', 'ago', '.', '<eos>']
# ['<sos>', 'we', 'waited', '.', '<eos>']
# ['<sos>', 'i', 'laughed', '.', '<eos>']
# ['<sos>', 'i', 'hate', 'myself', 'as', 'well', '.', '<eos>']
# ['<sos>', 'we', "'", 're', 'both', 'from', 'boston', '.', '<eos>']
# ['<sos>', 'the', 'fact', 'tom', 'did', 'that', 'can', "'", 't', 'be', 'denied', '.', '<eos>']
# ['<sos>', 'take', 'this', '.', '<eos>']
# ['<sos>', 'please', 'tell', 'him', 'to', 'wait', '.', '<eos>']
# ['<sos>', 'think', 'about', 'this', '.', '<eos>']
# ['<sos>', 'it', 'doesn', "'", 't', 'hurt', '.', '<eos>']
# ['<sos>', 'tom', 'wants', 'to', 'quit', '.', '<eos>']
# ['<sos>', 'i', 'shouldn', "'", 't', "'", 've', 'eaten', 'that', '.', '<eos>']
# ['<sos>', 'are', 'you', 'crying', '?', '<eos>']
# ['<sos>', 'tom', 'has', 'some', 'experience', 'in', 'teaching', 'french', '.', '<eos>']
# ['<sos>', 'tom', 'has', 'a', 'dog', 'and', 'three', 'cats', '.', '<eos>']
# ['<sos>', 'you', 'have', 'one', 'hour', '.', '<eos>']
# ['<sos>', 'we', 'have', 'no', 'evidence', 'that', 'such', 'a', 'virus', 'exists', '.', '<eos>']
# ['<sos>', 'physics', 'is', 'more', 'difficult', 'than', 'mathematics', '.', '<eos>']
# ['<sos>', 'the', 'girls', 'won', "'", 't', 'play', 'tennis', 'tomorrow', '.', '<eos>']
# ['<sos>', 'i', "'", 'll', 'buy', 'that', '.', '<eos>']
# ['<sos>', 'hold', 'still', '.', '<eos>']
# ['<sos>', 'suicide', 'isn', "'", 't', 'painful', '.', '<eos>']
# ['<sos>', 'i', 'don', "'", 't', 'know', '.', '<eos>']
# ...
# ['<sos>', 'i', 'used', 'to', 'do', 'that', 'every', 'day', '.', '<eos>']
# ['<sos>', 'stop', 'smoking', '.', '<eos>']
# ['<sos>', 'you', 'can', "'", 't', 'keep', 'this', 'a', 'secret', '.', '<eos>']
# ['<sos>', 'that', 'wasn', "'", 't', 'the', 'case', '.', '<eos>']
# ['<sos>', 'it', "'", 's', '745', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'lonely', 'and', 'unhappy', '.', '<eos>']
# ['<sos>', 'tom', 'also', 'learns', 'french', '.', '<eos>']
# ['<sos>', 'tom', 'will', 'find', 'out', 'sooner', 'or', 'later', '.', '<eos>']
# ['<sos>', 'tom', 'sat', 'alone', '.', '<eos>']
# ['<sos>', 'the', 'ice', 'is', 'thick', 'enough', 'to', 'walk', 'on', '.', '<eos>']
# ['<sos>', 'tom', 'has', 'been', 'trying', 'to', 'help', 'mary', '.', '<eos>']
# ['<sos>', 'i', 'really', 'feel', 'sorry', 'for', 'tom', '.', '<eos>']
# ['<sos>', 'leave', 'now', '.', '<eos>']
# ['<sos>', 'tell', 'me', 'what', 'you', 'said', 'to', 'tom', '.', '<eos>']
# ['<sos>', 'the', 'plane', 'took', 'off', 'from', 'boston', 'at', '230', '.', '<eos>']
# ['<sos>', 'tom', 'came', 'too', 'early', 'because', 'of', 'a', 'misunderstanding', '.', '<eos>']
# ['<sos>', 'that', "'", 's', 'a', 'good', 'start', '.', '<eos>']
# ['<sos>', 'do', 'you', 'have', 'your', 'passport', '?', '<eos>']
# ['<sos>', 'is', 'that', 'our', 'problem', '?', '<eos>']
# ['<sos>', 'how', 'often', 'did', 'you', 'go', 'swimming', 'last', 'summer', '?', '<eos>']
# ['<sos>', 'is', 'there', 'anything', 'that', 'you', 'want', 'to', 'tell', 'me', '?', '<eos>']
# ['<sos>', 'i', 'tried', 'to', 'act', 'appropriately', '.', '<eos>']
# ['<sos>', 'no', 'one', 'laughed', '.', '<eos>']
# ['<sos>', 'tom', 'was', 'probably', 'pondering', 'something', '.', '<eos>']
# ['<sos>', 'you', 'should', "'", 've', 'done', 'that', 'with', 'us', '.', '<eos>']
# ['<sos>', 'this', 'is', 'a', 'catastrophe', '.', '<eos>']
# ['<sos>', 'i', 'played', 'golf', '.', '<eos>']
# ['<sos>', 'tom', 'talks', 'to', 'his', 'mother', 'more', 'often', 'than', 'he', 'talks', 'to', 'his', 'father', '.', '<eos>']
# ['<sos>', 'do', 'i', 'look', 'desperate', 'to', 'you', '?', '<eos>']
# ['<sos>', 'the', 'food', 'isn', "'", 't', 'very', 'good', 'here', '.', '<eos>']
# ['<sos>', 'dreams', 'do', 'come', 'true', '.', '<eos>']
# ['<sos>', 'i', 'heard', 'it', 'on', 'the', 'news', 'today', '.', '<eos>']
# ['<sos>', 'would', 'you', 'like', 'to', 'go', 'with', 'me', '?', '<eos>']
# ['<sos>', 'i', 'have', 'no', 'regrets', '.', '<eos>']
# ['<sos>', 'why', 'do', 'you', 'walk', 'when', 'you', 'have', 'a', 'car', '?', '<eos>']
# ['<sos>', 'i', 'met', 'tom', 'after', 'work', '.', '<eos>']
# ['<sos>', 'i', 'could', 'write', 'tom', 'a', 'note', 'if', 'you', 'want', 'me', 'to', '.', '<eos>']
# ['<sos>', 'women', 'like', 'men', 'with', 'mustaches', '.', '<eos>']
# ['<sos>', 'many', 'people', 'think', 'i', "'", 'm', 'crazy', '.', '<eos>']
# ['<sos>', 'living', 'abroad', 'is', 'the', 'best', 'way', 'to', 'learn', 'a', 'foreign', 'language', '.', '<eos>']
# ['<sos>', 'tom', 'was', 'sitting', 'in', 'the', 'garden', '.', '<eos>']
# ['<sos>', 'i', 'don', "'", 't', 'think', 'this', 'is', 'a', 'fake', '.', '<eos>']
# ['<sos>', 'we', 'ran', 'after', 'the', 'cat', '.', '<eos>']
# ['<sos>', 'you', 'are', 'late', '.', '<eos>']
# ['<sos>', 'i', 'couldn', "'", 't', 'come', 'to', 'the', 'birthday', 'party', '.', '<eos>']
# ['<sos>', 'english', 'has', 'become', 'an', 'international', 'language', '.', '<eos>']
# ['<sos>', 'unfortunately', ',', 'no', 'one', 'told', 'us', '.', '<eos>']
# ['<sos>', 'a', 'thousand', 'meters', 'is', 'one', 'kilometer', '.', '<eos>']
# ['<sos>', 'what', 'are', 'your', 'plans', 'for', 'next', 'weekend', '?', '<eos>']
# ['<sos>', 'the', 'fact', 'that', 'tom', 'didn', "'", 't', 'do', 'that', 'can', "'", 't', 'be', 'denied', '.', '<eos>']
# ['<sos>', 'my', 'grandfather', 'cannot', 'walk', 'without', 'a', 'walking', 'stick', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'beautiful', '.', '<eos>']
# ['<sos>', 'i', 'can', "'", 't', 'walk', 'fast', '.', '<eos>']
# ['<sos>', 'twenty', 'police', 'have', 'arrived', 'on', 'the', 'scene', '.', '<eos>']
# ['<sos>', 'she', 'fell', 'down', 'the', 'ladder', '.', '<eos>']
# ['<sos>', 'software', 'is', 'constantly', 'evolving', '.', '<eos>']
# ['<sos>', 'i', 'texted', 'tom', 'back', '.', '<eos>']
# ['<sos>', 'i', "'", 'd', 'like', 'a', 'wakeup', 'call', 'at', 'six', 'tomorrow', 'morning', '.', '<eos>']
# ['<sos>', 'the', 'venom', 'of', 'most', 'spiders', 'is', 'harmless', 'to', 'humans', '.', '<eos>']
# ['<sos>', 'here', 'comes', 'our', 'teacher', '.', '<eos>']
# ['<sos>', 'let', 'us', 'know', 'what', 'you', 'decide', '.', '<eos>']
# ['<sos>', 'i', 'want', 'to', 'be', 'able', 'to', 'play', 'the', 'violin', 'as', 'well', 'as', 'tom', '.', '<eos>']
# ['<sos>', 'do', 'you', 'know', 'this', 'song', '?', '<eos>']
# ['<sos>', 'it', "'", 's', 'very', 'hot', 'here', '.', '<eos>']
# ['<sos>', 'i', 'don', "'", 't', 'sleep', 'a', 'lot', '.', '<eos>']
# ['<sos>', 'who', "'", 's', 'the', 'person', 'who', 'was', 'just', 'speaking', 'to', 'you', '?', '<eos>']
# ['<sos>', 'strictly', 'speaking', ',', 'chinese', 'consists', 'of', 'hundreds', 'of', 'dialects', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'sorry', 'for', 'calling', 'so', 'late', '.', 'i', 'just', 'wanted', 'to', 'hear', 'your', 'voice', '.', '<eos>']
# ['<sos>', 'i', 'don', "'", 't', 'care', 'what', 'you', 'thought', '.', '<eos>']
# ['<sos>', 'tom', 'wants', 'to', 'learn', 'how', 'to', 'play', 'the', 'piano', '.', '<eos>']
# ['<sos>', 'i', 'don', "'", 't', 'know', 'how', 'to', 'pronounce', 'his', 'name', '.', '<eos>']
# ['<sos>', 'they', 'are', 'eating', 'just', 'now', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'a', 'little', 'oldfashioned', '.', '<eos>']
# ['<sos>', 'we', "'", 've', 'been', 'worried', '.', '<eos>']
# ['<sos>', 'tom', 'used', 'mary', "'", 's', 'computer', '.', '<eos>']
# ['<sos>', 'i', 'know', 'tom', 'is', 'a', 'lazy', 'kid', '.', '<eos>']
# ['<sos>', 'tom', 'suffers', 'from', 'headaches', '.', '<eos>']
# ['<sos>', 'people', 'are', 'afraid', 'of', 'change', '.', '<eos>']
# ['<sos>', 'please', 'drive', 'slowly', '.', '<eos>']
# ['<sos>', 'we', 'need', 'to', 'learn', 'to', 'live', 'with', 'what', 'we', 'have', '.', '<eos>']
# ['<sos>', 'watch', 'carefully', '.', '<eos>']
# ['<sos>', 'tom', 'doesn', "'", 't', 'want', 'to', 'be', 'disappointed', '.', '<eos>']
# ['<sos>', 'i', 'found', 'this', 'under', 'your', 'bed', '.', '<eos>']
# ['<sos>', 'i', 'need', 'to', 'finish', 'it', '.', '<eos>']
# ['<sos>', 'tom', 'knows', 'my', 'number', '.', '<eos>']
# ['<sos>', 'the', 'water', 'flows', 'under', 'the', 'bridge', '.', '<eos>']
# ['<sos>', 'i', 'sometimes', 'use', 'scissors', 'as', 'a', 'can', 'opener', '.', '<eos>']
# ['<sos>', 'is', 'that', 'okay', '?', '<eos>']
# ['<sos>', 'he', 'plays', 'beach', 'volleyball', '.', '<eos>']
# ['<sos>', 'smoking', 'stinks', '.', '<eos>']
# ['<sos>', 'i', 'knew', 'i', 'would', 'win', '.', '<eos>']
# ['<sos>', 'the', 'question', 'is', 'who', 'is', 'going', 'to', 'tell', 'him', '.', '<eos>']
# ['<sos>', 'of', 'course', '!', '<eos>']
# ['<sos>', 'nothing', 'seems', 'to', 'grow', 'in', 'this', 'soil', '.', '<eos>']
# ['<sos>', 'the', 'cat', 'meowed', '.', '<eos>']
# ['<sos>', 'she', 'went', 'to', 'the', 'hospital', 'yesterday', '.', '<eos>']
# ['<sos>', 'who', 'drew', 'it', '?', '<eos>']
# ['<sos>', 'the', 'bag', 'is', 'full', '.', '<eos>']
# ['<sos>', 'it', 'wasn', "'", 't', 'tom', 'who', 'talked', 'to', 'me', '.', '<eos>']
# ['<sos>', 'the', 'water', 'is', 'really', 'cold', '.', '<eos>']
# ['<sos>', 'tom', 'says', 'he', 'doesn', "'", 't', 'feel', 'like', 'playing', 'tennis', 'today', '.', '<eos>']
# ['<sos>', 'tom', 'has', 'a', 'guitar', 'that', 'was', 'made', 'in', 'korea', '.', '<eos>']
# ['<sos>', 'times', 'have', 'changed', '.', '<eos>']
# ['<sos>', 'culture', 'destroys', 'language', '.', '<eos>']
# ['<sos>', 'tom', 'wants', 'to', 'play', 'a', 'game', '.', '<eos>']
# ['<sos>', 'do', 'you', 'hear', 'me', '?', '<eos>']
# ['<sos>', 'i', 'saw', 'him', 'crossing', 'the', 'street', '.', '<eos>']
# ['<sos>', 'i', 'wish', 'i', 'had', 'more', 'money', '.', '<eos>']
# ['<sos>', 'if', 'i', 'tell', 'the', 'truth', ',', 'i', "'", 'll', 'be', 'killed', '.', '<eos>']
# ['<sos>', 'tell', 'me', 'where', 'you', "'", 're', 'going', '.', '<eos>']
# ['<sos>', 'everybody', 'here', 'except', 'me', 'has', 'done', 'that', '.', '<eos>']
# ['<sos>', 'keep', 'away', '.', '<eos>']
# ['<sos>', 'she', 'has', 'no', 'sense', 'of', 'beauty', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'sorry', 'that', 'i', 'cried', '.', '<eos>']
# ['<sos>', 'tom', 'works', 'for', 'a', 'tech', 'company', '.', '<eos>']
# ['<sos>', 'it', "'", 's', 'a', 'ridiculous', 'question', ',', 'really', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'a', 'pretty', 'good', 'tennis', 'player', '.', '<eos>']
# ['<sos>', 'come', 'aboard', '.', '<eos>']
# ['<sos>', 'if', 'walls', 'could', 'talk', ',', 'what', 'stories', 'would', 'they', 'tell', 'us', '?', '<eos>']
# ['<sos>', 'this', 'grocery', 'store', 'only', 'sells', 'organic', 'food', '.', '<eos>']
# ['<sos>', 'i', 'often', 'read', 'books', '.', '<eos>']
# ['<sos>', 'think', 'about', 'what', 'you', 'did', '.', '<eos>']
# ['<sos>', 'am', 'i', 'talking', 'too', 'much', '?', '<eos>']
# ['<sos>', 'if', 'you', "'", 're', 'going', 'to', 'smoke', ',', 'smoke', 'over', 'there', '.', '<eos>']
# ['<sos>', 'i', 'heard', 'that', 'both', 'tom', 'and', 'mary', 'have', 'been', 'fired', '.', '<eos>']
# ['<sos>', 'you', 'should', 'study', 'french', '.', '<eos>']
# ['<sos>', 'help', 'me', '!', '<eos>']
# ['<sos>', 'tom', 'is', 'a', 'pioneer', 'in', 'this', 'field', '.', '<eos>']
# ['<sos>', 'he', 'was', 'born', 'in', 'africa', '.', '<eos>']
# ['<sos>', 'tom', 'thinks', 'that', 'mary', 'won', "'", 't', 'need', 'to', 'do', 'that', '.', '<eos>']
# ['<sos>', 'walk', 'slowly', '.', '<eos>']
# ['<sos>', 'turn', 'right', '.', '<eos>']
# ['<sos>', 'we', "'", 'll', 'never', 'get', 'to', 'boston', 'before', 'dark', '.', '<eos>']
# ['<sos>', 'i', 'wanted', 'tom', 'to', 'be', 'more', 'careful', '.', '<eos>']
# ['<sos>', 'hurry', 'up', ',', 'or', 'you', "'", 'll', 'be', 'late', 'for', 'school', '.', '<eos>']
# ['<sos>', 'are', 'you', 'involved', '?', '<eos>']
# ['<sos>', 'tom', 'complained', '.', '<eos>']
# ['<sos>', 'love', 'hurts', '.', '<eos>']
# ['<sos>', 'she', "'", 's', 'a', 'trainee', '.', '<eos>']
# ['<sos>', 'her', 'nails', 'are', 'red', '.', '<eos>']
# ['<sos>', 'i', 'can', "'", 't', 'stand', 'mary', "'", 's', 'boyfriend', '.', '<eos>']
# ['<sos>', 'you', "'", 're', 'not', 'really', 'worried', ',', 'are', 'you', '?', '<eos>']
# ['<sos>', 'tom', 'and', 'i', 'meet', 'every', 'monday', '.', '<eos>']
# ['<sos>', 'i', "'", 'd', 'like', 'to', 'see', 'him', 'tomorrow', 'afternoon', '.', '<eos>']
# ['<sos>', 'it', "'", 's', 'lunch', 'time', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'taking', 'a', 'rest', '.', '<eos>']
# ['<sos>', 'i', 'have', 'no', 'idea', 'what', 'tom', "'", 's', 'plan', 'is', '.', '<eos>']
# ['<sos>', 'calm', 'down', '.', '<eos>']
# ['<sos>', 'if', 'it', 'were', 'not', 'for', 'water', ',', 'human', 'life', 'would', 'be', 'impossible', '.', '<eos>']
# ['<sos>', 'i', 'want', 'tom', 'to', 'show', 'you', 'how', 'to', 'do', 'that', '.', '<eos>']
# ['<sos>', 'i', 'want', 'to', 'be', 'happy', '.', '<eos>']
# ['<sos>', 'let', "'", 's', 'sing', 'the', 'song', 'in', 'english', '.', '<eos>']
# ['<sos>', 'by', 'the', 'way', ',', 'have', 'you', 'ever', 'been', 'to', 'hokkaido', '?', '<eos>']
# ['<sos>', 'i', 'don', "'", 't', 'watch', 'television', '.', '<eos>']
# ['<sos>', 'i', 'know', 'what', 'you', 'are', 'thinking', '.', '<eos>']
# ['<sos>', 'that', 'was', 'stupid', '.', '<eos>']
# ['<sos>', 'is', 'there', 'a', 'pharmacy', 'nearby', '?', '<eos>']
# ['<sos>', 'five', 'times', 'seven', 'is', 'thirtyfive', '.', '<eos>']
# ['<sos>', 'tom', 'reassured', 'mary', '.', '<eos>']
# ['<sos>', 'this', 'is', 'how', 'i', 'did', 'it', '.', '<eos>']
# ['<sos>', 'tom', 'pondered', 'his', 'next', 'move', '.', '<eos>']
# ['<sos>', 'got', 'it', '?', '<eos>']
# ['<sos>', 'it', "'", 's', 'tom', "'", 's', 'favorite', 'french', 'word', '.', '<eos>']
# ['<sos>', 'we', 'can', 'buy', 'it', '.', '<eos>']
# ['<sos>', 'why', 'is', 'he', 'staring', 'at', 'me', '?', '<eos>']
# ['<sos>', 'i', 'feel', 'very', 'guilty', '.', '<eos>']
# ['<sos>', 'you', 'can', "'", 't', 'imagine', 'how', 'difficult', 'it', 'was', 'for', 'tom', '.', '<eos>']
# ['<sos>', 'she', 'isn', "'", 't', 'married', '.', '<eos>']
# ['<sos>', 'i', 'don', "'", 't', 'want', 'to', 'die', 'here', '.', '<eos>']
# ['<sos>', 'i', 'had', 'no', 'choice', 'but', 'to', 'go', '.', '<eos>']
# ['<sos>', 'do', 'you', 'need', 'the', 'phone', '?', '<eos>']
# ['<sos>', 'tom', 'knows', '.', '<eos>']
# ['<sos>', 'he', 'was', 'about', 'to', 'speak', '.', '<eos>']
# ['<sos>', 'we', 'own', 'a', 'dog', 'and', 'a', 'cat', '.', '<eos>']
# ['<sos>', 'please', 'smile', '.', '<eos>']
# ['<sos>', 'i', 'rarely', 'make', 'a', 'mistake', '.', '<eos>']
# ['<sos>', 'tom', 'survived', 'being', 'buried', 'under', 'an', 'avalanche', '.', '<eos>']
# ['<sos>', 'my', 'children', 'are', 'in', 'school', '.', '<eos>']
# ['<sos>', 'tom', "'", 's', 'famous', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'married', 'to', 'a', 'rich', 'woman', '.', '<eos>']
# ['<sos>', 'tom', 'tried', 'to', 'think', 'logically', '.', '<eos>']
# ['<sos>', 'can', 'the', 'price', 'be', 'discounted', '?', '<eos>']
# ['<sos>', 'it', "'", 's', 'fun', 'to', 'travel', '.', '<eos>']
# ['<sos>', 'he', 'had', 'a', 'headache', '.', '<eos>']
# ['<sos>', 'no', 'decision', 'was', 'made', '.', '<eos>']
# ['<sos>', 'why', 'do', 'i', 'always', 'get', 'up', 'at', 'this', 'time', '?', '<eos>']
# ['<sos>', 'dreams', 'sometimes', 'come', 'true', '.', '<eos>']
# ['<sos>', 'tom', 'wouldn', "'", 't', 'let', 'them', 'in', '.', '<eos>']
# ['<sos>', 'i', "'", 'm', 'sorry', '.', '<eos>']
# ['<sos>', 'cats', 'have', 'nine', 'lives', '.', '<eos>']
# ['<sos>', 'i', 'love', 'this', 'job', '.', '<eos>']
# ['<sos>', 'where', 'can', 'i', 'learn', 'french', '?', '<eos>']
# ['<sos>', 'don', "'", 't', 'go', 'near', 'the', 'dog', '.', '<eos>']
# ['<sos>', 'why', 'is', 'the', 'store', 'closed', '?', '<eos>']
# ['<sos>', 'can', 'rabbits', 'swim', '?', '<eos>']
# ['<sos>', 'tom', 'escaped', '.', '<eos>']
# ['<sos>', 'sugar', 'is', 'soluble', 'in', 'water', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'probably', 'not', 'going', 'to', 'be', 'there', '.', '<eos>']
# ['<sos>', 'i', 'don', "'", 't', 'know', 'what', 'you', 'want', 'to', 'do', '.', '<eos>']
# ['<sos>', 'why', 'are', 'you', 'still', 'at', 'school', '?', '<eos>']
# ['<sos>', 'call', 'us', 'tollfree', 'at', '18004462581', '.', '<eos>']
# ['<sos>', 'the', 'book', "'", 's', 'white', '.', '<eos>']
# ['<sos>', 'three', 'children', 'were', 'playing', 'in', 'the', 'park', '.', '<eos>']
# ['<sos>', 'is', 'there', 'something', 'that', 'you', 'want', 'to', 'tell', 'me', '?', '<eos>']
# ['<sos>', 'i', 'looked', 'out', 'the', 'window', '.', '<eos>']
# ['<sos>', 'he', 'breathed', 'deeply', 'before', 'entering', 'his', 'boss', "'", 's', 'office', '.', '<eos>']
# ['<sos>', 'are', 'there', 'any', 'questions', '?', '<eos>']
# ['<sos>', 'tom', 'was', 'upset', '.', '<eos>']
# ['<sos>', 'i', 'was', 'almost', 'killed', '.', '<eos>']
# ['<sos>', 'stand', 'up', '!', '<eos>']
# ['<sos>', 'this', 'is', 'just', 'like', 'a', 'dream', '.', '<eos>']
# ['<sos>', 'we', "'", 're', 'coming', 'back', 'tomorrow', '.', '<eos>']
# ['<sos>', 'i', 'don', "'", 't', 'think', 'i', "'", 'll', 'be', 'lonely', '.', '<eos>']
# ['<sos>', 'to', 'be', 'honest', 'with', 'you', ',', 'i', 'don', "'", 't', 'think', 'i', 'can', 'do', 'that', '.', '<eos>']
# ['<sos>', 'his', 'behavior', 'aroused', 'my', 'suspicions', '.', '<eos>']
# ['<sos>', 'tom', 'is', 'so', 'irresponsible', '.', 'i', 'can', "'", 't', 'believe', 'it', '.', '<eos>']
# ['<sos>', 'tom', 'cheated', '.', '<eos>']
# ['<sos>', 'company', 'regulations', 'mandate', 'that', 'workers', 'use', 'protective', 'eyewear', '.', '<eos>']
# ['<sos>', 'our', 'school', 'is', '80', 'years', 'old', '.', '<eos>']
# ['<sos>', 'are', 'you', 'ready', 'to', 'start', 'working', '?', '<eos>']
# ['<sos>', 'sorry', 'to', 'trouble', 'you', ',', 'but', 'can', 'you', 'help', 'me', '?', '<eos>']
# ['<sos>', 'could', 'you', 'please', 'repeat', 'what', 'you', 'just', 'said', '?', '<eos>']
# ['<sos>', 'tom', 'is', 'studying', 'to', 'become', 'a', 'marine', 'biologist', '.', '<eos>']
# ['<sos>', 'science', 'is', 'fun', '.', '<eos>']

# %% [markdown]
# # 영어 어휘집

# %%
vocab_trg = build_vocab_from_iterator(trg_data, specials=["<pad>", "<unk>", sos_token, eos_token])
vocab_trg.set_default_index(vocab_trg["<unk>"])

# %%
len(vocab_trg)
# Out:
# 3129

# %% [markdown]
# # 영어 단어번호 부여

# %%
trg_eng_data = [ vocab_trg(tokens) for tokens in trg_data ]

# %%
trg_eng_data
# Out:
# [[2, 210, 2696, 29, 27, 11, 291, 1584, 4, 3],
#  [2, 11, 574, 23, 1314, 4, 3],
#  [2, 68, 477, 21, 4, 3],
#  [2, 7, 56, 6, 14, 93, 43, 62, 22, 84, 9, 111, 165, 4, 3],
#  [2, 242, 8, 4, 3],
#  [2, 117, 586, 4, 3],
#  [2, 79, 17, 1589, 20, 5, 6, 61, 188, 51, 97, 4, 3],
#  [2, 5, 6, 25, 1909, 4, 3],
#  [2, 7, 1818, 4, 3],
#  [2, 57, 8, 120, 2384, 30, 10, 3],
#  [2, 5, 6, 25, 258, 13, 124, 74, 713, 4, 3],
#  [2, 62, 29, 8, 461, 101, 455, 10, 3],
#  [2, 5, 6, 25, 112, 37, 1480, 4, 3],
#  [2, 7, 56, 6, 14, 209, 37, 44, 876, 728, 4, 3],
#  [2, 34, 85, 8, 18, 79, 15, 301, 9, 8, 10, 3],
#  [2, 7, 184, 13, 464, 4, 3],
#  [2, 15, 6, 16, 42, 34, 7, 12, 425, 80, 4, 3],
#  [2, 43, 477, 13, 172, 1298, 480, 58, 7, 6, 16, 1119, 4, 3],
#  [2, 93, 7, 4, 3],
#  [2, 71, 217, 4, 3],
#  [2, 32, 5, 24, 21, 849, 10, 3],
#  [2, 5, 24, 9, 54, 185, 4, 3],
#  [2, 7, 12, 1766, 4, 3],
#  [2, 5, 6, 25, 64, 9, 54, 41, 55, 7, 4, 3],
#  [2, 7, 88, 22, 167, 9, 54, 424, 4, 3],
#  [2, 50, 1022, 118, 11, 448, 4, 3],
#  [2, 99, 527, 4, 3],
#  [2, 5, 150, 746, 122, 15, 4, 3],
#  [2, 68, 6, 52, 1719, 4, 3],
#  [2, 7, 32, 6, 14, 406, 232, 13, 204, 4, 22, 6, 16, 215, 300, 634, 4, 3],
#  [2, 57, 8, 110, 13, 392, 9, 240, 55, 7, 10, 3],
#  [2, 5, 38, 15, 7, 6, 16, 48, 53, 2351, 13, 166, 4, 3],
#  [2, 7, 1684, 9, 11, 308, 4, 3],
#  [2, 5, 40, 5, 306, 42, 24, 9, 18, 15, 138, 4, 3],
#  [2, 7, 2145, 4, 3],
#  [2, 11, 2080, 23, 846, 3046, 4, 3],
#  [2, 5, 28, 6, 14, 70, 24, 13, 2680, 4, 3],
#  [2, 5, 23, 165, 20, 101, 5, 651, 26, 1081, 4, 3],
#  [2, 170, 256, 4, 3],
#  [2, 5, 6, 25, 120, 122, 26, 313, 4, 3],
#  [2, 21, 12, 478, 4, 3],
#  [2, 11, 1193, 58, 11, 607, 23, 457, 4, 3],
#  [2, 5, 36, 408, 4, 3],
#  [2, 2823, 91, 11, 3008, 807, 957, 2199, 9, 955, 444, 4, 3],
#  [2, 7, 167, 13, 702, 857, 4, 3],
#  [2, 11, 1220, 1591, 4, 3],
#  [2, 24, 8, 103, 63, 19, 126, 10, 3],
#  [2, 12, 17, 436, 10, 3],
#  [2, 7, 56, 6, 14, 18, 11, 1047, 4, 3],
#  [2, 23, 11, 387, 618, 10, 3],
#  [2, 41, 29, 781, 2041, 58, 11, 626, 4, 3],
#  [2, 18, 8, 36, 497, 10, 3],
#  [2, 7, 53, 471, 9, 54, 9, 114, 4, 3],
#  [2, 5, 302, 8, 24, 2385, 4, 3],
#  [2, 8, 40, 5, 6, 25, 235, 4, 3],
#  [2, 8, 6, 52, 832, 4, 3],
#  [2, 21, 157, 12, 222, 37, 30, 9, 187, 4, 3],
#  [2, 89, 12, 241, 60, 4, 3],
#  [2, 28, 6, 14, 617, 11, 988, 4, 3],
#  [2, 5, 285, 45, 9, 376, 87, 5, 23, 13, 643, 4, 3],
#  [2, 68, 171, 4, 3],
#  [2, 7, 2677, 491, 186, 136, 4, 3],
#  [2, 5, 40, 17, 6, 16, 49, 298, 9, 201, 62, 7, 57, 34, 22, 57, 4, 3],
#  [2, 524, 20, 522, 4, 3],
#  [2, 22, 309, 9, 416, 11, 318, 4, 3],
#  [2, 8, 28, 6, 14, 135, 4, 3],
#  [2, 5, 6, 25, 286, 1084, 9, 1705, 55, 7, 4, 3],
#  [2, 5, 182, 1193, 4, 3],
#  [2, 7, 2070, 321, 185, 19, 13, 345, 462, 4, 3],
#  [2, 21, 12, 347, 46, 3],
#  [2, 34, 29, 8, 816, 80, 10, 3],
#  [2, 7, 12, 2375, 4, 3],
#  [2, 34, 6, 16, 15, 10, 3],
#  [2, 7, 516, 44, 658, 480, 4, 3],
#  [2, 45, 128, 2522, 29, 41, 19, 2401, 10, 3],
#  [2, 32, 6, 14, 8, 2936, 89, 627, 20, 7, 10, 3],
#  [2, 7, 147, 11, 1512, 4, 3],
#  [2, 18, 8, 665, 186, 136, 10, 3],
#  [2, 109, 91, 1412, 20, 109, 91, 1470, 4, 3],
#  [2, 33, 29, 82, 199, 4, 3],
#  [2, 281, 252, 4, 3],
#  [2, 5, 73, 6, 59, 107, 1707, 7, 4, 3],
#  [2, 7, 23, 113, 87, 44, 340, 23, 365, 19, 13, 1701, 460, 4, 3],
#  [2, 1924, 2036, 1752, 27, 11, 704, 6, 16, 1393, 4, 3],
#  [2, 22, 53, 13, 853, 2373, 223, 259, 2705, 4, 3],
#  [2, 7, 53, 49, 82, 2691, 950, 4, 3],
#  [2, 17, 77, 6, 14, 222, 9, 382, 13, 126, 567, 19, 233, 4, 3],
#  [2,
#   5,
#   38,
#   17,
#   6,
#   16,
#   13,
#   2831,
#   15,
#   109,
#   1082,
#   194,
#   801,
#   91,
#   383,
#   9,
#   1090,
#   90,
#   1033,
#   311,
#   103,
#   258,
#   676,
#   55,
#   13,
#   652,
#   673,
#   4,
#   3],
#  [2, 264, 1195, 4, 3],
#  [2, 82, 204, 46, 3],
#  [2, 7, 12, 64, 9, 615, 17, 118, 4, 3],
#  [2, 5, 123, 7, 23, 391, 4, 3],
#  [2, 280, 7, 47, 43, 755, 8, 4, 3],
#  [2, 41, 23, 67, 492, 19, 998, 55, 7, 4, 3],
#  [2, 29, 8, 13, 1057, 506, 10, 3],
#  [2, 203, 171, 4, 3],
#  [2, 5, 24, 113, 1358, 4, 3],
#  [2, 82, 1506, 4, 3],
#  [2, 7, 12, 13, 442, 27, 413, 4, 18, 8, 40, 78, 10, 3],
#  [2, 50, 184, 9, 117, 13, 140, 4, 3],
#  [2, 5, 111, 58, 677, 4, 3],
#  [2, 5, 6, 25, 19, 26, 161, 275, 48, 4, 3],
#  [2, 105, 6, 16, 170, 20, 319, 20, 47, 31, 1516, 4, 3],
#  [2, 7, 1092, 94, 19, 11, 2934, 4, 3],
#  [2, 5, 1274, 7, 5, 381, 6, 14, 18, 15, 220, 4, 3],
#  [2, 242, 8, 4, 3],
#  [2, 310, 294, 4, 3],
#  [2, 335, 20, 71, 4, 3],
#  [2, 2013, 29, 2037, 4, 3],
#  [2, 32, 8, 331, 13, 964, 37, 30, 10, 3],
#  [2, 24, 8, 103, 63, 9, 7, 6, 16, 97, 10, 3],
#  [2, 33, 6, 52, 98, 399, 4, 3],
#  [2, 5, 6, 25, 286, 37, 13, 560, 9, 1512, 13, 1016, 858, 4, 3],
#  [2, 1201, 94, 46, 3],
#  [2, 81, 27, 26, 965, 641, 4, 3],
#  [2, 50, 12, 2078, 4, 3],
#  [2, 5, 309, 9, 824, 9, 7, 4, 3],
#  [2, 5, 38, 7, 12, 160, 4, 3],
#  [2, 284, 174, 34, 33, 96, 4, 3],
#  [2, 5, 23, 547, 19, 818, 4, 3],
#  [2, 121, 3100, 4, 3],
#  [2, 5, 994, 55, 78, 58, 15, 492, 4, 3],
#  [2, 5, 146, 48, 13, 166, 4, 3],
#  [2, 11, 225, 23, 246, 4, 3],
#  [2, 787, 23, 425, 9, 7, 4, 3],
#  [2, 5, 6, 119, 36, 9, 173, 21, 4, 3],
#  [2, 7, 12, 66, 1226, 66, 13, 1588, 4, 3],
#  [2, 21, 2973, 77, 6, 14, 222, 9, 141, 4, 3],
#  [2, 28, 6, 14, 110, 30, 241, 4, 3],
#  [2, 12, 21, 11, 397, 8, 6, 52, 286, 37, 10, 3],
#  [2, 22, 6, 16, 507, 9, 2146, 4, 3],
#  [2, 5, 70, 36, 34, 5, 18, 4, 3],
#  [2, 5, 944, 7, 13, 1223, 4, 3],
#  [2, 18, 8, 70, 38, 8, 32, 1037, 7, 9, 18, 15, 10, 3],
#  [2, 7, 12, 98, 668, 4, 3],
#  [2, 7, 2849, 4, 3],
#  [2, 24, 8, 103, 63, 861, 10, 3],
#  [2, 7, 12, 98, 42, 49, 82, 51, 424, 20, 12, 22, 10, 3],
#  [2, 1027, 612, 4, 3],
#  [2, 50, 53, 231, 144, 638, 4, 3],
#  [2, 22, 6, 16, 215, 286, 51, 8, 4, 22, 287, 126, 8, 4, 3],
#  [2, 5, 56, 6, 14, 40, 7, 23, 13, 1057, 506, 4, 3],
#  [2, 73, 5, 141, 48, 10, 3],
#  [2, 50, 1423, 78, 9, 344, 232, 4, 3],
#  [2, 105, 6, 16, 363, 11, 342, 27, 11, 500, 4, 3],
#  [2, 456, 1155, 18, 8, 187, 10, 3],
#  [2, 7, 12, 1304, 1042, 4, 3],
#  [2, 7, 180, 30, 22, 523, 6, 14, 324, 43, 19, 911, 4, 3],
#  [2, 276, 4, 3],
#  [2, 71, 344, 4, 3],
#  [2, 105, 6, 16, 292, 47, 622, 4, 3],
#  [2, 12, 17, 211, 10, 3],
#  [2, 5, 6, 119, 36, 9, 615, 118, 4, 3],
#  [2, 148, 168, 12, 113, 197, 657, 102, 459, 4, 3],
#  [2, 8, 32, 6, 14, 1422, 294, 9, 403, 89, 4, 3],
#  [2, 7, 921, 4, 3],
#  [2, 8, 73, 253, 21, 4, 17, 6, 16, 624, 4, 3],
#  [2, 7, 944, 92, 394, 1571, 4, 3],
#  [2, 5, 6, 25, 13, 437, 195, 4, 3],
#  [2, 5, 24, 9, 135, 5, 868, 8, 4, 3],
#  [2, 210, 939, 28, 6, 14, 516, 162, 4, 3],
#  [2, 45, 128, 245, 91, 746, 10, 3],
#  [2, 5, 32, 6, 14, 266, 35, 341, 4, 3],
#  [2, 5, 302, 15, 33, 28, 6, 14, 24, 9, 276, 37, 86, 172, 4, 3],
#  [2, 7, 12, 13, 361, 48, 251, 4, 3],
#  [2, 5, 32, 800, 48, 9, 7, 4, 3],
#  [2, 7, 53, 219, 13, 166, 27, 133, 4, 3],
#  [2, 203, 12, 628, 198, 11, 1127, 4, 3],
#  [2, 5, 362, 6, 14, 556, 21, 214, 4, 3],
#  [2, 29, 8, 239, 8, 39, 9, 54, 9, 114, 55, 7, 10, 3],
#  [2, 5, 40, 35, 340, 4, 3],
#  [2, 5, 123, 15, 5, 247, 1447, 4, 3],
#  [2, 5, 38, 34, 7, 12, 122, 12, 1797, 4, 3],
#  [2, 33, 921, 4, 3],
#  [2, 128, 127, 432, 36, 15, 4, 3],
#  [2, 69, 46, 3],
#  [2, 7, 53, 106, 133, 102, 5, 18, 4, 3],
#  [2, 5, 236, 357, 142, 4, 3],
#  [2, 17, 23, 1181, 759, 4, 3],
#  [2, 5, 213, 6, 14, 727, 60, 4, 3],
#  [2, 5, 227, 5, 139, 263, 256, 7, 180, 30, 4, 3],
#  [2, 971, 34, 10, 3],
#  [2, 34, 6, 16, 21, 1205, 10, 3],
#  [2, 11, 700, 23, 356, 19, 221, 4, 3],
#  [2, 7, 1914, 4, 3],
#  [2, 11, 266, 6, 16, 817, 4, 3],
#  [2, 150, 17, 46, 3],
#  [2, 7, 206, 129, 37, 44, 296, 4, 3],
#  [2, 105, 6, 16, 292, 47, 622, 4, 3],
#  [2, 5, 70, 126, 48, 4, 3],
#  [2, 5, 40, 7, 12, 13, 49, 1436, 195, 4, 3],
#  [2, 681, 37, 535, 467, 27, 7, 4, 3],
#  [2, 5, 73, 6, 59, 229, 106, 282, 4, 3],
#  [2, 5, 28, 6, 14, 39, 9, 357, 60, 4, 3],
#  [2, 17, 236, 116, 289, 95, 745, 4, 3],
#  [2, 5, 28, 6, 14, 40, 354, 19, 114, 4, 3],
#  [2, 7, 83, 6, 14, 594, 292, 19, 48, 4, 3],
#  [2, 5, 675, 189, 303, 373, 13, 157, 125, 225, 4, 3],
#  [2, 5, 126, 415, 4, 3],
#  [2, 7, 184, 9, 188, 97, 349, 4, 3],
#  [2, 5, 6, 25, 98, 1159, 80, 11, 1575, 4, 3],
#  [2, 7, 2423, 4, 3],
#  [2, 1299, 109, 153, 4, 3],
#  [2, 7, 12, 13, 361, 648, 4, 3],
#  [2, 21, 12, 42, 211, 4, 3],
#  [2, 45, 6, 16, 111, 10, 3],
#  [2, 5, 76, 107, 518, 8, 4, 3],
#  [2, 5, 226, 78, 1353, 11, 938, 4, 3],
#  [2, 26, 310, 12, 856, 102, 459, 4, 3],
#  [2, 7, 343, 22, 6, 16, 329, 417, 9, 217, 4, 3],
#  [2, 5, 6, 25, 1850, 21, 12, 487, 4, 3],
#  [2, 845, 1023, 27, 2925, 29, 111, 47, 259, 1598, 4, 3],
#  [2, 15, 6, 16, 26, 169, 4, 3],
#  [2, 1223, 30, 4, 3],
#  [2, 29, 8, 1482, 10, 3],
#  [2, 15, 175, 30, 654, 4, 3],
#  [2, 28, 6, 14, 234, 9, 92, 4, 3],
#  [2, 5, 28, 6, 14, 192, 7, 12, 13, 2532, 4, 3],
#  [2, 7, 1266, 4, 3],
#  [2, 28, 6, 14, 1240, 78, 94, 4, 3],
#  [2, 18, 8, 36, 335, 10, 3],
#  [2, 105, 30, 447, 4, 3],
#  [2, 5, 38, 15, 7, 12, 361, 4, 3],
#  [2, 45, 134, 74, 76, 17, 116, 9, 18, 21, 10, 3],
#  [2, 67, 81, 23, 51, 97, 4, 3],
#  [2, 132, 1210, 4, 3],
#  [2, 264, 53, 230, 4, 3],
#  [2, 34, 29, 8, 189, 998, 80, 10, 3],
#  [2, 5, 734, 15, 7, 1208, 48, 4, 3],
#  [2, 72, 6, 16, 35, 143, 426, 765, 10, 3],
#  [2, 5, 36, 464, 4, 3],
#  [2, 276, 60, 4, 3],
#  [2, 5, 6, 25, 803, 80, 64, 156, 223, 1688, 4, 3],
#  [2, 7, 23, 13, 3028, 393, 4, 3],
#  [2, 5, 605, 125, 225, 4, 3],
#  [2, 22, 265, 13, 783, 516, 4, 3],
#  [2, 41, 6, 16, 13, 1669, 514, 4, 3],
#  [2, 7, 2516, 4, 3],
#  [2, 7, 12, 258, 13, 124, 74, 1421, 4, 3],
#  [2, 33, 190, 9, 114, 4, 3],
#  [2, 5, 6, 25, 13, 259, 279, 4, 3],
#  [2, 17, 1648, 13, 166, 125, 191, 4, 3],
#  [2, 1128, 29, 65, 905, 4, 3],
#  [2, 33, 131, 11, 395, 19, 919, 9, 777, 74, 4, 3],
#  [2, 183, 46, 41, 6, 16, 13, 140, 19, 11, 1124, 4, 3],
#  [2,
#   17,
#   6,
#   16,
#   81,
#   427,
#   9,
#   207,
#   1563,
#   20,
#   104,
#   219,
#   698,
#   9,
#   613,
#   252,
#   118,
#   4,
#   3],
#  [2, 13, 169, 23, 733, 7, 4, 3],
#  [2, 1319, 2742, 29, 1258, 1547, 2134, 4, 3],
#  [2, 5, 6, 25, 42, 293, 220, 4, 3],
#  [2, 5, 6, 61, 99, 156, 409, 4, 3],
#  [2, 21, 635, 12, 13, 166, 27, 283, 4, 3],
#  [2, 41, 6, 16, 262, 1734, 102, 1502, 4, 3],
#  [2, 43, 47, 5, 29, 1062, 4, 3],
#  [2, 817, 20, 5, 443, 78, 4, 3],
#  [2, 5, 6, 119, 819, 4, 3],
#  [2, 5, 56, 6, 14, 38, 15, 33, 84, 130, 392, 27, 815, 4, 3],
#  [2, 65, 27, 13, 1212, 20, 50, 545, 9, 749, 4, 3],
#  [2, 5, 28, 6, 14, 158, 155, 51, 65, 4, 3],
#  [2, 2908, 23, 2436, 58, 656, 1754, 20, 1750, 4, 3],
#  [2, 329, 132, 605, 58, 74, 4, 3],
#  [2, 41, 29, 245, 60, 4, 3],
#  [2, 33, 993, 4, 3],
#  [2, 7, 2687, 43, 90, 122, 15, 4, 3],
#  [2,
#   26,
#   48,
#   85,
#   1135,
#   31,
#   134,
#   216,
#   138,
#   79,
#   5,
#   6,
#   119,
#   676,
#   55,
#   13,
#   652,
#   673,
#   4,
#   3],
#  [2, 22, 410, 4, 3],
#  [2, 7, 12, 86, 1242, 9, 378, 15, 555, 4, 3],
#  [2, 33, 96, 35, 433, 4, 3],
#  [2, 7, 12, 13, 82, 442, 27, 459, 20, 77, 6, 14, 22, 10, 3],
#  [2, 45, 1702, 46, 3],
#  [2, 109, 245, 28, 6, 14, 36, 1236, 4, 3],
#  [2, 24, 8, 103, 63, 9, 21, 607, 198, 10, 3],
#  [2, 7, 540, 307, 44, 395, 4, 3],
#  [2, 75, 164, 15, 315, 54, 10, 3],
#  [2, 262, 301, 4, 3],
#  [2, 5, 24, 699, 347, 189, 348, 4, 3],
#  [2, 68, 6, 52, 505, 8, 4, 3],
#  [2, 5, 28, 6, 14, 24, 133, 20, 104, 5, 24, 723, 4, 3],
#  [2, 7, 53, 1923, 44, 1882, 4, 3],
#  [2, 7, 76, 24, 13, 124, 74, 4, 3],
#  [2, 89, 12, 637, 4, 3],
#  [2, 13, 152, 72, 2919, 1365, 1582, 4, 3],
#  [2, 15, 6, 16, 655, 4, 3],
#  [2, 18, 8, 39, 9, 69, 10, 3],
#  [2, 5, 38, 33, 73, 18, 89, 455, 4, 3],
#  [2, 7, 3075, 94, 51, 2863, 186, 322, 4, 3],
#  [2, 8, 6, 61, 774, 17, 4, 3],
#  [2, 7, 902, 286, 51, 43, 4, 3],
#  [2, 68, 6, 52, 636, 4, 3],
#  [2, 236, 284, 1297, 8, 4, 3],
#  [2, 7, 12, 95, 2165, 866, 4, 3],
#  [2, 7, 12, 571, 185, 19, 13, 1112, 4, 3],
#  [2, 5, 6, 25, 112, 20, 104, 5, 28, 6, 14, 201, 4, 3],
#  [2, 19, 1749, 20, 1537, 444, 1481, 955, 444, 4, 3],
#  [2, 2533, 29, 175, 27, 1468, 27, 1226, 2217, 4, 3],
#  [2, 5, 131, 9, 358, 80, 1884, 13, 2518, 4, 3],
#  [2, 32, 8, 2413, 35, 1775, 10, 3],
#  [2, 26, 438, 12, 178, 113, 197, 129, 4, 3],
#  [2, 603, 20, 33, 28, 6, 14, 24, 13, 616, 4, 3],
#  [2, 8, 6, 52, 49, 1838, 4, 3],
#  [2, 18, 8, 38, 543, 24, 2893, 10, 3],
#  [2, 1156, 71, 46, 3],
#  [2, 5, 2935, 150, 49, 602, 4, 3],
#  [2, 5, 28, 6, 14, 40, 87, 22, 6, 16, 514, 4, 3],
#  [2, 5, 6, 25, 86, 1074, 4, 3],
#  [2, 7, 12, 835, 13, 3078, 4, 3],
#  [2, 15, 6, 16, 26, 178, 1419, 4, 3],
#  [2, 22, 343, 501, 58, 11, 2907, 27, 11, 2519, 4, 3],
#  [2,
#   79,
#   264,
#   72,
#   83,
#   6,
#   14,
#   40,
#   35,
#   1853,
#   343,
#   15,
#   8,
#   672,
#   36,
#   13,
#   652,
#   673,
#   20,
#   17,
#   753,
#   68,
#   494,
#   915,
#   89,
#   80,
#   35,
#   790,
#   15,
#   175,
#   252,
#   2722,
#   8,
#   986,
#   6,
#   14,
#   13,
#   652,
#   673,
#   4,
#   19,
#   237,
#   689,
#   20,
#   8,
#   28,
#   6,
#   14,
#   70,
#   672,
#   36,
#   13,
#   652,
#   673,
#   4,
#   3],
#  [2, 71, 936, 4, 3],
#  [2, 17, 301, 19, 114, 4, 3],
#  [2, 7, 12, 13, 2789, 4, 3],
#  [2, 7, 724, 464, 4, 3],
#  [2, 29, 41, 130, 522, 60, 8, 362, 6, 14, 214, 261, 10, 3],
#  [2, 5, 32, 6, 14, 273, 4, 3],
#  [2, 218, 127, 38, 15, 5, 6, 25, 552, 4, 3],
#  [2, 11, 129, 1328, 115, 11, 903, 12, 49, 244, 4, 3],
#  [2, 177, 193, 4, 3],
#  [2, 62, 29, 8, 215, 165, 37, 100, 10, 3],
#  [2, 45, 853, 10, 3],
#  [2, 1276, 46, 3],
#  [2, 5, 362, 6, 14, 247, 90, 355, 4, 3],
#  [2, 5, 6, 25, 391, 20, 86, 4, 3],
#  [2, 1644, 11, 832, 1972, 4, 3],
#  [2, 29, 8, 19, 41, 10, 3],
#  [2, 5, 229, 489, 89, 9, 170, 4, 3],
#  [2, 117, 425, 4, 3],
#  [2, 5, 28, 6, 14, 36, 35, 288, 4, 3],
#  [2, 33, 6, 61, 141, 11, 539, 274, 4, 3],
#  [2, 7, 1534, 3038, 4, 3],
#  [2, 85, 8, 36, 513, 179, 799, 10, 3],
#  [2, 5, 182, 399, 185, 4, 3],
#  [2,
#   7,
#   2572,
#   2694,
#   30,
#   9,
#   111,
#   118,
#   55,
#   78,
#   20,
#   104,
#   5,
#   6,
#   25,
#   70,
#   42,
#   563,
#   4,
#   3],
#  [2, 32, 8, 181, 30, 1370, 9, 11, 423, 454, 10, 3],
#  [2, 319, 109, 153, 4, 3],
#  [2, 5, 6, 59, 84, 359, 27, 35, 2833, 4, 3],
#  [2, 57, 8, 40, 78, 10, 3],
#  [2, 5, 380, 79, 7, 53, 384, 171, 4, 3],
#  [2, 7, 2236, 11, 923, 198, 2300, 17, 9, 43, 4, 3],
#  [2, 181, 30, 11, 1414, 4, 3],
#  [2, 34, 6, 52, 8, 122, 10, 3],
#  [2, 5, 23, 1203, 125, 984, 4, 3],
#  [2, 7, 12, 783, 37, 44, 296, 20, 77, 6, 14, 22, 10, 3],
#  [2, 24, 8, 676, 2079, 6, 16, 2982, 27, 1063, 10, 3],
#  [2, 812, 4, 3],
#  [2, 7, 1733, 34, 43, 167, 9, 18, 4, 3],
#  [2, 50, 12, 1380, 19, 457, 4, 3],
#  [2, 75, 76, 8, 151, 10, 3],
#  [2, 18, 8, 263, 10, 3],
#  [2, 406, 17, 46, 3],
#  [2, 7, 47, 43, 131, 9, 31, 199, 20, 137, 10, 3],
#  [2, 18, 8, 39, 21, 10, 3],
#  [2, 5, 28, 6, 14, 38, 7, 12, 383, 9, 18, 15, 4, 3],
#  [2, 1556, 8, 73, 93, 7, 4, 3],
#  [2, 406, 98, 4, 3],
#  [2, 5, 6, 25, 295, 27, 1059, 4, 3],
#  [2, 306, 5, 99, 19, 10, 3],
#  [2, 7, 1329, 4, 3],
#  [2, 5, 6, 25, 327, 27, 623, 4, 3],
#  [2, 5, 170, 3006, 20, 104, 7, 83, 6, 14, 4, 3],
#  [2, 8, 6, 52, 11, 81, 72, 360, 92, 65, 21, 4, 3],
#  [2, 117, 1369, 4, 3],
#  [2, 7, 12, 696, 9, 188, 4, 11, 342, 27, 8, 24, 9, 217, 4, 3],
#  [2, 592, 171, 4, 3],
#  [2, 7, 261, 43, 19, 818, 4, 3],
#  [2, 7, 2269, 4, 3],
#  [2, 11, 530, 27, 439, 12, 64, 94, 4, 3],
#  [2, 22, 12, 120, 1491, 74, 4, 3],
#  [2, 50, 1161, 13, 849, 27, 799, 4, 3],
#  [2, 17, 12, 88, 15, 22, 23, 49, 451, 4, 3],
#  [2, 7, 32, 187, 20, 32, 6, 14, 22, 10, 3],
#  [2, 42, 65, 893, 91, 547, 628, 4, 13, 334, 91, 547, 9, 379, 4, 3],
#  [2, 5, 28, 6, 14, 1229, 1539, 220, 4, 3],
#  [2, 8, 73, 669, 645, 4, 3],
#  [2, 11, 788, 20, 11, 216, 4, 3],
#  [2, 5, 201, 4, 3],
#  [2, 50, 12, 2156, 4, 3],
#  [2, 8, 679, 9, 7, 154, 20, 56, 6, 14, 8, 10, 3],
#  [2, 7, 12, 219, 1150, 4, 3],
#  [2, 203, 184, 9, 31, 752, 4, 3],
#  [2, 5, 178, 57, 11, 1869, 2509, 4, 3],
#  [2, 34, 18, 8, 18, 58, 2942, 10, 3],
#  [2, 7, 88, 15, 157, 23, 364, 4, 3],
#  [2, 50, 321, 1152, 4, 3],
#  [2, 7, 88, 43, 53, 63, 9, 114, 113, 348, 4, 3],
#  [2, 34, 283, 46, 3],
#  [2, 7, 77, 6, 14, 536, 37, 44, 296, 4, 3],
#  [2, 12, 15, 65, 8, 39, 9, 135, 10, 3],
#  [2, 5, 6, 25, 496, 27, 140, 3061, 4, 3],
#  [2, 15, 6, 16, 26, 397, 4, 3],
#  [2, 7, 12, 235, 9, 13, 391, 756, 43, 4, 3],
#  [2, 526, 94, 20, 179, 8, 6, 61, 31, 165, 37, 100, 4, 3],
#  [2, 44, 172, 674, 1012, 92, 65, 4, 3],
#  [2, 33, 40, 34, 7, 12, 64, 804, 4, 3],
#  [2, 5, 6, 25, 112, 5, 918, 26, 1151, 4, 3],
#  [2, 5, 36, 35, 140, 20, 104, 50, 83, 6, 14, 36, 30, 4, 3],
#  [2, 110, 223, 11, 168, 4, 3],
#  [2, 5, 123, 15, 8, 56, 6, 14, 39, 155, 9, 170, 4, 3],
#  [2, 7, 12, 219, 948, 20, 77, 6, 14, 22, 10, 3],
#  [2, 34, 1023, 1502, 10, 3],
#  [2, 45, 57, 8, 40, 7, 85, 69, 10, 3],
#  [2, 21, 12, 13, 1287, 458, 875, 4, 3],
#  [2, 15, 6, 16, 26, 663, 4, 3],
#  [2, 5, 24, 9, 217, 108, 4, 3],
#  [2, 5, 6, 25, 42, 13, 251, 4, 3],
#  [2, 592, 435, 4, 3],
#  [2, 5, 23, 51, 97, 154, 4, 3],
#  [2, 7, 860, 4, 3],
#  [2, 2629, 24, 566, 1879, 4, 3],
#  [2, 7, 699, 347, 4, 3],
#  [2, 7, 53, 471, 9, 110, 44, 159, 2748, 4, 3],
#  [2, 34, 33, 96, 12, 13, 1927, 4, 3],
#  [2, 26, 404, 230, 402, 197, 353, 4, 3],
#  [2, 33, 596, 4, 3],
#  [2, 5, 410, 4, 3],
#  [2, 5, 182, 489, 66, 162, 4, 3],
#  [2, 33, 6, 52, 280, 90, 114, 4, 3],
#  [2, 11, 440, 7, 57, 15, 32, 6, 14, 31, 718, 4, 3],
#  [2, 116, 21, 4, 3],
#  [2, 71, 93, 78, 9, 276, 4, 3],
#  [2, 38, 80, 21, 4, 3],
#  [2, 17, 83, 6, 14, 562, 4, 3],
#  [2, 7, 184, 9, 450, 4, 3],
#  [2, 5, 784, 6, 14, 6, 59, 863, 15, 4, 3],
#  [2, 29, 8, 356, 10, 3],
#  [2, 7, 53, 109, 873, 19, 1688, 48, 4, 3],
#  [2, 7, 53, 13, 169, 47, 113, 268, 4, 3],
#  [2, 8, 24, 81, 745, 4, 3],
#  [2, 33, 24, 67, 2186, 15, 591, 13, 1238, 871, 4, 3],
#  [2, 1168, 12, 106, 298, 102, 2487, 4, 3],
#  [2, 11, 522, 147, 6, 14, 208, 426, 142, 4, 3],
#  [2, 5, 6, 61, 173, 15, 4, 3],
#  [2, 406, 98, 4, 3],
#  [2, 347, 77, 6, 14, 2609, 4, 3],
#  [2, 5, 28, 6, 14, 40, 4, 3],
#  [2, 603, 20, 33, 28, 6, 14, 24, 13, 616, 4, 3],
#  [2, 7, 53, 13, 169, 756, 2046, 4, 3],
#  [2, 7, 175, 43, 908, 4, 3],
#  [2, 5, 24, 13, 2871, 743, 138, 4, 3],
#  [2, 68, 6, 52, 2181, 4, 3],
#  [2, 5, 158, 70, 580, 4, 3],
#  [2, 7, 77, 6, 14, 1135, 9, 760, 11, 859, 968, 4, 3],
#  [2, 7, 180, 30, 8, 91, 1791, 9, 268, 4, 3],
#  [2, 75, 12, 11, 387, 10, 3],
#  [2, 12, 21, 874, 10, 3],
#  [2, 7, 2262, 4, 3],
#  [2, 32, 8, 70, 42, 376, 10, 3],
#  [2, 177, 184, 9, 111, 4, 3],
#  [2, 405, 307, 4, 3],
#  [2, 7, 53, 106, 133, 102, 30, 4, 3],
#  [2, 7, 450, 4, 3],
#  [2, 21, 12, 26, 700, 4, 3],
#  [2,
#   79,
#   35,
#   269,
#   1835,
#   35,
#   340,
#   13,
#   341,
#   19,
#   48,
#   20,
#   164,
#   50,
#   266,
#   19,
#   48,
#   179,
#   19,
#   233,
#   10,
#   3],
#  [2, 33, 2888, 15, 200, 19, 13, 277, 4, 3],
#  [2, 35, 740, 12, 66, 246, 66, 895, 4, 3],
#  [2, 7, 372, 11, 1571, 428, 11, 394, 976, 4, 3],
#  [2, 188, 1420, 4, 3],
#  [2, 5, 36, 983, 4, 3],
#  [2, 162, 20, 8, 1542, 24, 664, 1078, 37, 7, 4, 3],
#  [2, 62, 42, 10, 3],
#  [2, 7, 343, 15, 22, 147, 6, 14, 276, 130, 366, 4, 3],
#  [2, 15, 6, 16, 65, 5, 32, 145, 4, 3],
#  [2, 33, 263, 4, 3],
#  [2, 17, 6, 16, 514, 156, 9, 30, 108, 4, 3],
#  [2, 7, 47, 43, 29, 617, 2739, 4, 3],
#  [2, 7, 83, 6, 14, 36, 9, 572, 4, 3],
#  [2, 8, 73, 6, 59, 243, 7, 198, 8, 57, 15, 4, 3],
#  [2, 26, 742, 641, 4, 3],
#  [2, 22, 88, 524, 9, 11, 352, 4, 3],
#  [2, 11, 1594, 265, 1036, 27, 11, 710, 4, 3],
#  [2, 50, 229, 189, 1051, 439, 4, 3],
#  [2, 112, 20, 104, 5, 6, 25, 255, 4, 3],
#  [2, 7, 860, 4, 3],
#  [2, 21, 835, 53, 13, 636, 2778, 4, 3],
#  [2, 164, 1256, 70, 111, 10, 3],
#  [2, 5, 401, 580, 37, 67, 773, 4, 3],
#  [2, 5, 131, 9, 31, 13, 1105, 506, 4, 3],
#  [2, 7, 131, 9, 31, 13, 2660, 4, 3],
#  [2, 45, 249, 46, 3],
#  [2, 7, 726, 4, 3],
#  [2, 5, 6, 25, 64, 9, 31, 51, 97, 21, 508, 4, 3],
#  [2, 215, 1993, 35, 2895, 4, 3],
#  [2, 68, 192, 30, 4, 3],
#  [2, 85, 17, 31, 369, 79, 5, 509, 11, 125, 1646, 27, 764, 10, 3],
#  [2, 5, 6, 25, 13, 48, 1211, 4, 3],
#  [2, 5, 28, 6, 14, 40, 75, 7, 76, 151, 176, 191, 4, 3],
#  [2, 809, 35, 405, 270, 4, 3],
#  [2, 65, 924, 27, 11, 929, 29, 1426, 4, 3],
#  [2, 62, 29, 8, 461, 101, 1984, 10, 3],
#  [2, 99, 185, 4, 3],
#  [2, 2878, 29, 2012, 1351, 4, 3],
#  [2, 183, 41, 4, 3],
#  [2, 7, 77, 6, 14, 13, 750, 4, 3],
#  [2, 21, 301, 1173, 9, 2725, 35, 567, 4, 3],
#  [2, 5, 32, 6, 14, 192, 7, 12, 13, 404, 4, 3],
#  [2, 13, 1557, 204, 12, 216, 102, 13, 1690, 81, 4, 3],
#  [2, 5, 250, 465, 314, 90, 11, 751, 4, 3],
#  [2, 11, 481, 793, 47, 935, 9, 414, 4, 3],
#  [2, 5, 28, 6, 14, 187, 48, 1539, 4, 3],
#  [2, 7, 483, 9, 92, 4, 3],
#  [2, 5, 329, 230, 154, 4, 3],
#  [2, 5, 993, 4, 3],
#  [2, 62, 29, 8, 733, 92, 10, 3],
#  [2, 24, 8, 103, 324, 7, 749, 10, 3],
#  [2, 18, 8, 40, 15, 195, 10, 3],
#  [2, 34, 194, 23, 15, 10, 3],
#  [2, 18, 8, 40, 354, 72, 375, 48, 10, 3],
#  [2, 15, 213, 6, 14, 211, 4, 3],
#  [2, 50, 53, 13, 260, 610, 4, 3],
#  [2, 57, 8, 40, 7, 23, 160, 10, 3],
#  [2, 5, 147, 6, 14, 173, 21, 946, 4, 3],
#  [2, 116, 21, 4, 3],
#  [2, 5, 38, 5, 6, 25, 945, 507, 4, 3],
#  [2, 17, 6, 16, 42, 66, 124, 66, 8, 38, 4, 3],
#  [2, 7, 213, 6, 14, 19, 87, 5, 1056, 115, 4, 3],
#  [2, 5, 463, 8, 7, 76, 31, 846, 666, 4, 3],
#  [2, 45, 128, 2299, 57, 8, 173, 10, 3],
#  [2, 8, 73, 6, 59, 479, 9, 7, 6, 16, 323, 4, 3],
#  [2, 71, 1405, 17, 106, 1641, 4, 3],
#  [2, 18, 8, 554, 7, 9, 31, 165, 10, 3],
#  [2, 5, 6, 59, 150, 13, 341, 4, 3],
#  [2, 524, 46, 3],
#  [2, 62, 30, 10, 3],
#  [2, 7, 12, 13, 49, 82, 714, 4, 3],
#  [2, 5, 38, 15, 7, 77, 6, 14, 19, 149, 108, 4, 3],
#  [2, 15, 85, 31, 36, 1619, 307, 11, 1013, 8, 6, 52, 532, 58, 4, 3],
#  [2, 71, 292, 4, 3],
#  [2, 273, 12, 216, 102, 338, 4, 3],
#  [2, 5, 40, 4, 3],
#  [2, 7, 12, 536, 37, 44, 296, 4, 3],
#  [2, 7, 384, 171, 4, 3],
#  [2, 11, 879, 23, 154, 4, 3],
#  [2, 5, 38, 7, 12, 1374, 4, 3],
#  [2, 7, 56, 6, 14, 901, 223, 11, 153, 4, 3],
#  [2, 5, 6, 119, 36, 13, 1087, 27, 153, 20, 71, 4, 3],
#  [2, 484, 9, 35, 269, 4, 3],
#  [2, 420, 294, 4, 3],
#  [2, 7, 12, 13, 510, 654, 4, 3],
#  [2, 7, 190, 9, 444, 66, 13, 1990, 2512, 4, 3],
#  [2, 7, 184, 9, 1000, 256, 4, 3],
#  [2, 5, 6, 25, 327, 27, 505, 538, 4, 3],
#  [2, 817, 20, 15, 6, 16, 34, 5, 445, 4, 3],
#  [2, 117, 7, 41, 4, 3],
#  [2, 85, 8, 1132, 30, 35, 559, 9, 212, 349, 58, 2911, 10, 3],
#  [2, 7, 12, 328, 13, 1286, 1955, 4, 3],
#  [2, 11, 515, 2683, 23, 2359, 37, 2628, 2417, 4, 3],
#  [2, 8, 73, 31, 437, 34, 8, 135, 4, 3],
#  [2, 117, 275, 48, 4, 3],
#  [2, 1326, 20, 71, 4, 3],
#  [2, 29, 33, 64, 671, 108, 10, 3],
#  [2, 680, 8, 37, 11, 624, 472, 4, 3],
#  [2, 5, 24, 95, 1717, 650, 37, 7, 4, 3],
#  [2, 53, 7, 544, 552, 10, 3],
#  [2, 33, 271, 4, 3],
#  [2, 18, 8, 24, 13, 1318, 10, 3],
#  [2, 8, 76, 40, 274, 359, 4, 3],
#  [2, 33, 201, 4, 3],
#  [2, 7, 23, 51, 11, 2706, 55, 44, 199, 125, 225, 4, 3],
#  [2, 45, 1003, 46, 3],
#  [2, 7, 537, 48, 9, 92, 4, 3],
#  [2, 5, 96, 9, 173, 89, 9, 170, 4, 3],
#  [2, 5, 6, 59, 247, 21, 900, 384, 4, 3],
#  [2, 121, 3102, 4, 3],
#  [2, 2693, 12, 95, 999, 4, 3],
#  [2, 188, 2670, 4, 3],
#  [2, 7, 47, 44, 254, 183, 219, 2855, 4, 3],
#  [2, 21, 2859, 12, 808, 4, 3],
#  [2, 86, 165, 4, 3],
#  [2, 105, 6, 16, 54, 9, 11, 561, 4, 3],
#  [2, 71, 121, 4, 3],
#  [2, 34, 1099, 108, 10, 3],
#  [2, 89, 6, 16, 637, 4, 3],
#  [2, 121, 647, 4, 3],
#  [2, 22, 375, 48, 4, 3],
#  [2, 7, 56, 6, 14, 811, 13, 961, 138, 4, 3],
#  [2, 79, 284, 57, 42, 870, 20, 17, 85, 31, 1154, 9, 2398, 78, 4, 3],
#  [2, 5, 123, 7, 47, 43, 91, 64, 9, 212, 30, 66, 13, 2335, 4, 3],
#  [2, 1694, 35, 2839, 4, 3],
#  [2, 7, 2369, 4, 3],
#  [2, 5, 24, 13, 325, 4, 3],
#  [2, 121, 914, 46, 3],
#  [2, 29, 8, 13, 169, 152, 179, 13, 140, 152, 10, 3],
#  [2, 116, 307, 35, 947, 4, 3],
#  [2, 5, 6, 25, 67, 366, 295, 27, 499, 4, 3],
#  [2, 33, 6, 52, 914, 9, 114, 51, 11, 1392, 27, 21, 488, 4, 3],
#  [2, 127, 73, 201, 15, 11, 202, 12, 1322, 4, 3],
#  [2, 1276, 46, 3],
#  [2, 5, 56, 6, 14, 39, 9, 31, 2392, 4, 3],
#  [2, 22, 475, 90, 11, 976, 4, 3],
#  [2, 7, 12, 235, 9, 13, 391, 756, 43, 4, 3],
#  [2, 5, 38, 7, 190, 2225, 55, 43, 4, 3],
#  [2, 5, 6, 25, 64, 9, 149, 176, 191, 4, 3],
#  [2, 7, 23, 962, 9, 31, 60, 198, 573, 4, 3],
#  [2, 987, 2866, 29, 210, 10, 3],
#  [2, 5, 6, 25, 112, 5, 1050, 8, 4, 3],
#  [2, 7, 88, 43, 23, 1550, 4, 3],
#  ...]

# %% [markdown]
# # 데이터셋 클래스

# %%
class TranslateDataset(torch.utils.data.Dataset):
    def __init__(self, src, trg):
        self.src = src
        self.trg = trg
    def __len__(self):
        return len(self.src)
    def __getitem__(self, idx):
        item = {}
        item["src"] = torch.tensor( self.src[idx] )
        item["trg"] = torch.tensor( self.trg[idx] )
        return item

# %%
def collate_fn(lst):
    from torch.nn.utils.rnn import pad_sequence

    src = [ item["src"] for item in lst]
    src = pad_sequence(src, batch_first=True)

    trg = [ item["trg"] for item in lst]
    trg = pad_sequence(trg, batch_first=True)

    return {"src": src, "trg": trg}

# %%
dt = TranslateDataset(src_ko_data, trg_eng_data)
dl = torch.utils.data.DataLoader(dt, 2 , shuffle=False, collate_fn= collate_fn)
batch = next(iter(dl))
batch
# Out:
# {'src': tensor([[   4, 2926,   32,    8,   50,    8, 3151,    4,    9,    2],
#          [1112,    4, 1254,   38,    6,    9,    2,    0,    0,    0]]),
#  'trg': tensor([[   2,  210, 2696,   29,   27,   11,  291, 1584,    4,    3],
#          [   2,   11,  574,   23, 1314,    4,    3,    0,    0,    0]])}

# %% [markdown]
# # Encoder layer

# %%
class Encoder(torch.nn.Module):
    def __init__(self, num_embeddings, embedding_dim):
        super().__init__()
        self.emb_layer = torch.nn.Embedding(num_embeddings, embedding_dim)
        self.rnn_layer = torch.nn.LSTM(embedding_dim, embedding_dim*2, batch_first=True, bidirectional=True)

    def forward(self, src):
        src = self.emb_layer(src) # batch,seq -> batch, seq, feature

        # output: batch, seq, feature
        # hn: nlayer, batch, features
        # cn: nlayer, batch, features
        outputs, (hn, cn) = self.rnn_layer(src)

        return hn, cn

# %%
encoder = Encoder(len(vocab_src), 64)
hn, cn = encoder(batch["src"])
hn.shape, cn.shape
# Out:
# (torch.Size([2, 2, 128]), torch.Size([2, 2, 128]))

# %%
# nlayer, batch, features -> batch, nlayer,  features -> batch, nlayer x features
tmp = hn.permute(1,0,2).flatten(1)
tmp.shape
# Out:
# torch.Size([2, 256])

# %%
tmp.unsqueeze(0).shape # batch, nlayer x features -> 1, batch, nlayer x features
# Out:
# torch.Size([1, 2, 256])

# %% [markdown]
# # Decoder layer

# %%
class Decoder(torch.nn.Module):
    def __init__(self, num_embeddings, embedding_dim):
        super().__init__()
        self.emb_layer = torch.nn.Embedding(num_embeddings, embedding_dim)
        self.rnn_layer = torch.nn.LSTM(embedding_dim, embedding_dim*4, batch_first=True)
        self.fc_layer = torch.nn.Linear(embedding_dim*4, num_embeddings) # 예측하는

    def forward(self,trg, hn, cn): # trg는 하나의 시점의 텐서
        trg = self.emb_layer(trg) # batch, 1 -> batch, 1, features

# nlayer, batch, features -> 
# batch, nlayer, features -> 
# batch, nlayer x features ->
# 1, batch, nlayer x features
        hn = hn.permute(1,0,2).flatten(1).unsqueeze(0)
        cn = cn.permute(1,0,2).flatten(1).unsqueeze(0)
        _, (hn, cn)= self.rnn_layer(trg, (hn, cn) )

        # hn: nlayer, batch, features
        pred = self.fc_layer(hn[-1]) # 인덱싱해서 다음과 같은 텐서가 입력으로 전달: batch, features
        return pred, hn, cn

# %%
batch["trg"][:,0].view(-1,1)
# Out:
# tensor([[2],
#         [2]])

# %%
batch["trg"][:,1].view(-1,1)
# Out:
# tensor([[210],
#         [ 11]])

# %%
hn.shape
# Out:
# torch.Size([2, 2, 128])

# %%
decoder = Decoder(len(vocab_trg), 64)
pred, hn, cn = decoder(batch["trg"][:,0].view(-1,1), hn, cn)

# %%
pred.shape
# Out:
# torch.Size([2, 3129])

# %% [markdown]
# # Seq2Seq 모델

# %%
class Net(torch.nn.Module):
    def __init__(self, vocab_size_src, vocab_size_trg, embedding_dim=64, device="cpu"):
        super().__init__()
        self.encoder = Encoder(vocab_size_src, embedding_dim)
        self.decoder = Decoder(vocab_size_trg, embedding_dim)
        self.device = device
        self.vocab_size_trg = vocab_size_trg # 타겟의 단어사전갯수 == 정답 클래스 개수
    def forward(self,src, trg, hn=None, cn=None):

        # trg: batch, seq
        batch_size = trg.shape[0]
        trg_len = trg.shape[1] 
        # prediction: batch, seq, n_class
        prediction = torch.zeros(batch_size, trg_len, self.vocab_size_trg).to(self.device)

        if hn is None:
            hn, cn = self.encoder(src)

        # 디코더에 전달 되는 첫번째 토큰데이터 == sos 토큰
        dec_input = trg[:, 0].view(-1,1)  # batch -> batch,seq

        # if len(trg_len[0][0])==1:
        #    print("디코더의 첫 인풋값이 잘못되었습니다.")

        for t in range(1, trg_len): # 맞춰야하는 문장 길이만큼 예측 시작
            
            # pred : batch, n_class
            pred, hn, cn = self.decoder(dec_input, hn, cn)

            prediction[:,t] = pred # t 시퀀스의 예측 단어를 t시점에 넣어줌

            dec_input = pred.argmax(1).view(-1,1) # batch -> batch, seq

            if random.random() < 0.5: # 교사강요
                dec_input = trg[:,t].view(-1,1) # batch -> batch,seq
        
        #-----> 추론 부분에선 하나하나 예측을 하는것이다.
    
        return prediction, hn, cn

# %%
model = Net(len(vocab_src), len(vocab_trg))
pred, _ , _  = model(batch["src"], batch["trg"])
pred.shape
# Out:
# torch.Size([2, 10, 3129])

# %%
len(vocab_trg)
# Out:
# 3129

# %% [markdown]
# # 학습 loop 함수

# %%
def train_loop(dataloader, model, loss_fn, optimizer, device):
    epoch_loss = 0
    model.train()
    
    for batch in tqdm(dataloader):
        src = batch["src"].to(device)
        trg = batch["trg"].to(device)
        pred, _, _ = model(src,trg)

        # pred: batch, seq, n_class -> batch x seq, n_class
        n_class = pred.shape[-1] # 정답 클래스의 개수
        pred = pred.view(-1, n_class)

        # trg: batch, seq -> batch x seq
        trg = trg.flatten()

        # pad, unk, sos 토큰 제외하고 손실 계산하기 위해 마스킹
        mask = trg > 2
        trg = trg[mask]
        pred = pred[mask]
        loss = loss_fn(pred, trg)

        optimizer.zero_grad() # 경사값 0으로 초기화
        loss.backward() # 역전파
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1) # 기울기 폭주 현상을 개선
        optimizer.step() # 가중치 업데이트

        epoch_loss += loss.item()

    epoch_loss /= len(dataloader)

    return epoch_loss

# %%
loss_fn = torch.nn.CrossEntropyLoss()

# %% [markdown]
# # 학습

# %%
reset_seeds(SEED)
model = Net(len(vocab_src), len(vocab_trg), device=device).to(device)
optimizer = torch.optim.Adam( model.parameters() )

dt = TranslateDataset(src_ko_data, trg_eng_data)
dl = torch.utils.data.DataLoader(dt, batch_size=64, shuffle=True, collate_fn=collate_fn)

for epoch in range(50):
    epoch_loss = train_loop(dl, model, loss_fn, optimizer, device)
    print(epoch, epoch_loss)
# Out:
#   0%|          | 0/91 [00:00<?, ?it/s]
# 0 5.354704207116431
#   0%|          | 0/91 [00:00<?, ?it/s]
# 1 4.476916842408233
#   0%|          | 0/91 [00:00<?, ?it/s]
# 2 4.1709932154351534
#   0%|          | 0/91 [00:00<?, ?it/s]
# 3 3.939714355783148
#   0%|          | 0/91 [00:00<?, ?it/s]
# 4 3.7526487151345056
#   0%|          | 0/91 [00:00<?, ?it/s]
# 5 3.580222711458311
#   0%|          | 0/91 [00:00<?, ?it/s]
# 6 3.4178805691855296
#   0%|          | 0/91 [00:00<?, ?it/s]
# 7 3.298372902712979
#   0%|          | 0/91 [00:00<?, ?it/s]
# 8 3.1309490020458517
#   0%|          | 0/91 [00:00<?, ?it/s]
# 9 3.0428453120556505
#   0%|          | 0/91 [00:00<?, ?it/s]
# 10 2.8908222167046516
#   0%|          | 0/91 [00:00<?, ?it/s]
# 11 2.743723209087665
#   0%|          | 0/91 [00:00<?, ?it/s]
# 12 2.6241496185680013
#   0%|          | 0/91 [00:00<?, ?it/s]
# 13 2.464437246322632
#   0%|          | 0/91 [00:00<?, ?it/s]
# 14 2.3551629965121927
#   0%|          | 0/91 [00:00<?, ?it/s]
# 15 2.251247546175024
#   0%|          | 0/91 [00:00<?, ?it/s]
# 16 2.122707166514554
#   0%|          | 0/91 [00:00<?, ?it/s]
# 17 2.010160560136313
#   0%|          | 0/91 [00:00<?, ?it/s]
# 18 1.9308898619243078
#   0%|          | 0/91 [00:00<?, ?it/s]
# 19 1.8105901636920132
#   0%|          | 0/91 [00:00<?, ?it/s]
# 20 1.6964080386109404
#   0%|          | 0/91 [00:00<?, ?it/s]
# 21 1.605543816482628
#   0%|          | 0/91 [00:00<?, ?it/s]
# 22 1.5042456755271325
#   0%|          | 0/91 [00:00<?, ?it/s]
# 23 1.4181377586427626
#   0%|          | 0/91 [00:00<?, ?it/s]
# 24 1.3216810881436527
#   0%|          | 0/91 [00:00<?, ?it/s]
# 25 1.25226407457184
#   0%|          | 0/91 [00:00<?, ?it/s]
# 26 1.1631875057796857
#   0%|          | 0/91 [00:00<?, ?it/s]
# 27 1.0925386168144562
#   0%|          | 0/91 [00:00<?, ?it/s]
# 28 1.0201210432000212
#   0%|          | 0/91 [00:00<?, ?it/s]
# 29 0.9742286997837025
#   0%|          | 0/91 [00:00<?, ?it/s]
# 30 0.9051505569573287
#   0%|          | 0/91 [00:00<?, ?it/s]
# 31 0.8519175065742745
#   0%|          | 0/91 [00:00<?, ?it/s]
# 32 0.787810742855072
#   0%|          | 0/91 [00:00<?, ?it/s]
# 33 0.7337854645409427
#   0%|          | 0/91 [00:00<?, ?it/s]
# 34 0.681058250940763
#   0%|          | 0/91 [00:00<?, ?it/s]
# 35 0.6428400864312936
#   0%|          | 0/91 [00:00<?, ?it/s]
# 36 0.5710018535891732
#   0%|          | 0/91 [00:00<?, ?it/s]
# 37 0.5372262096012032
#   0%|          | 0/91 [00:00<?, ?it/s]
# 38 0.4842506234462445
#   0%|          | 0/91 [00:00<?, ?it/s]
# 39 0.44606787817818777
#   0%|          | 0/91 [00:00<?, ?it/s]
# 40 0.4108594616690835
#   0%|          | 0/91 [00:00<?, ?it/s]
# 41 0.38612881286458656
#   0%|          | 0/91 [00:00<?, ?it/s]
# 42 0.3528519089405353
#   0%|          | 0/91 [00:00<?, ?it/s]
# 43 0.31998199437345776
#   0%|          | 0/91 [00:00<?, ?it/s]
# 44 0.28293841766132105
#   0%|          | 0/91 [00:00<?, ?it/s]
# 45 0.26721300381225543
#   0%|          | 0/91 [00:00<?, ?it/s]
# 46 0.24586070238888919
#   0%|          | 0/91 [00:00<?, ?it/s]
# 47 0.22588277567218948
#   0%|          | 0/91 [00:00<?, ?it/s]
# 48 0.21495757080041444
#   0%|          | 0/91 [00:00<?, ?it/s]
# 49 0.1879483413892788

# %% [markdown]
# # 한국어 -> 영어 출력하는 함수

# %%
@torch.no_grad()
def translate(text,tokenizer , model, vocab_src, vocab_trg, max_len, device):
    model.eval()

    src = vocab_src([ t.form for t in tokenizer.tokenize(text)])
    src = torch.tensor(src).view(1,-1).to(device) # seq -> 1, seq

    # trg = [2]
    # 디코더의 인풋값이 시퀀스 길이가 1일때 forward함수의 반복예측이 의미가 없어져서 나온 결과가온다.
    # 하지만 다음 디코더의 인풋이 시퀀스가 1이상이면 예측을 함
    # trg = [2,0,0,0,0] 이것도 예측을 한다.
    # trg = [2] 이런 의미 없는 시퀀스가 아니면 됨.

    trg = [2,0]

    trg = torch.tensor(trg).view(1,-1).to(device) # seq -> 1, seq

    hn = None
    cn = None

    for _ in range(max_len):
        pred, hn, cn = model(src,trg, hn, cn)
        # pred: batch, seq, n_class
        word_no = pred[0,-1].argmax().item() # n_class -> 예측 클래스 번호
        if word_no == 3:  # eos 토큰일 경우 반복 중지
            break

        print(vocab_trg.lookup_token(word_no), end=" ")

        trg = [word_no,0]
        # trg = [word_no]
        # 디코더의 인풋값이 시퀀스 길이가 1일때 forward함수의 반복예측이 의미가 없어져서 의미없는 결과가 나온다.
        trg = torch.tensor(trg).view(1,-1).to(device) # seq -> 1, seq

# %%
max_len = max( len(lst) for lst in trg_data)
max_len
# Out:
# 112

# %%
n = 20
text = train["ko"][n]
text, train["en"][n]
# Out:
# ('이 컵 가져도 돼요?', 'can i have this cup?')

# %%
# 다음 예시는 디코더의 인풋값이 시퀀스 길이가 1일때 forward함수의 반복예측이 의미가 없어져서 나온 결과
translate(text,kiwi , model, vocab_src, vocab_trg, max_len, device)
# Out:
# can i have this cup ?

# %%
vocab_trg["<sos>"]
# Out:
# 2

# %%
vocab_trg.lookup_token(2),vocab_trg.lookup_token(0)
# Out:
# ('<sos>', '<pad>')

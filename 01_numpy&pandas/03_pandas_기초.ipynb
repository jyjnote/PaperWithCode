# %% [markdown]
# # Pandas
# - 파이썬 에서 데이터를 다룰수 있게 만들어진 라이브러리
# - 2차원 배열 데이터에 대한 집계, 전처리를 굉장히 쉽게 할 수 있게 해준다.
# - 정형 데이터를 다루는 라이브러리
# - numpy 라이브러리를 내부적으로 그대로 활용한다.
# - 대량의 데이터를 읽어드려 분석하는데 최적화
# - 데이터 분석에 특화된 다양한 기능들을 제공
# - 다른 시스템과 다른 라이브러리와 쉽게 연결(데이터베이스, 머신러닝 라이브러리)

# %% [markdown]
# # Pandas의 데이터 구조
# - DataFrame: 2차원 구조로 되어있는 형식(행렬)
# - Series: 1차원 구조로 되어있는 한 종류의 데이터(열 방향 벡터)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# - DataFrame 만들기

# %%
data = [
    ["A군", 43, 170],
    ["B군", 25, 180]
]

pd.DataFrame(data)
# Out:
#     0   1    2
# 0  A군  43  170
# 1  B군  25  180

# %%
data = [
    ["A군", 43, 170],
    ["B군", 25, 180]
]

df = pd.DataFrame(data, columns=["이름","나 이","키"])
df
# Out:
#    이름  나 이    키
# 0  A군   43  170
# 1  B군   25  180

# %%
data = [
    ["c군", 43, 170],
    ["d군", 25, 180]
]

# %%
np.array(data)

pd.DataFrame(data).iloc[:,]
# Out:
#     0   1    2
# 0  c군  43  170
# 1  d군  25  180

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# - Series

# %%
df["이름"]
# Out:
# 0    A군
# 1    B군
# Name: 이름, dtype: object

# %%
type(df["이름"])
# Out:
# pandas.core.series.Series

# %%
df["나 이"]
# Out:
# 0    43
# 1    25
# Name: 나 이, dtype: int64

# %%
data = {
    "이름" : ["A군","B군"],
    "나이" : [35,43]
}
pd.DataFrame(data)
# Out:
#    이름  나이
# 0  A군  35
# 1  B군  43

# %% [markdown]
# # CSV 파일 불러오기

# %%
#from google.colab import drive
#drive.mount("/content/drive")

# %%
DATA_PATH = "C:\\study\\01_numpy&pandas\\data"

# %% [markdown]
# ```
# passengerid	: 승객ID
# survived: 생존여부(0: 사망, 1: 생존)
# pclass: 객실 등급(1~3)
# name: 이름
# gender: 성별
# age: 나이
# sibsp: 형제 자매수
# parch: 부모 자식수
# ticket: 티켓번호
# fare: 운임료
# cabin: 객실번호
# embarked: 탑승항구(C, S, Q)
# ```

# %% [markdown]
# - read_csv 함수
#     - csv 파일을 읽어서 dataframe 객체로 반환

# %%
df = pd.read_csv(f"{DATA_PATH}\\titanic_train.csv")
df
# Out:
#      passengerid  survived  pclass                          name  gender  \
# 0            494         0       1       Artagaveytia, Mr. Ramon    male
# 1            462         0       3           Morley, Mr. William    male
# 2           1286         0       3      Kink-Heilmann, Mr. Anton    male
# 3           1130         1       2         Hiltunen, Miss. Marta  female
# 4            461         1       1           Anderson, Mr. Harry    male
# ..           ...       ...     ...                           ...     ...
# 911          738         1       1        Lesurer, Mr. Gustave J    male
# 912          518         0       3             Ryan, Mr. Patrick    male
# 913          664         0       3              Coleff, Mr. Peju    male
# 914          109         0       3               Rekic, Mr. Tido    male
# 915          146         0       2  Nicholls, Mr. Joseph Charles    male
#
#       age  sibsp  parch      ticket      fare cabin embarked
# 0    71.0      0      0    PC 17609   49.5042   NaN        C
# 1    34.0      0      0      364506    8.0500   NaN        S
# 2    29.0      3      1      315153   22.0250   NaN        S
# 3    18.0      1      1      250650   13.0000   NaN        S
# 4    48.0      0      0       19952   26.5500   E12        S
# ..    ...    ...    ...         ...       ...   ...      ...
# 911  35.0      0      0    PC 17755  512.3292  B101        C
# 912   NaN      0      0      371110   24.1500   NaN        Q
# 913  36.0      0      0      349210    7.4958   NaN        S
# 914  38.0      0      0      349249    7.8958   NaN        S
# 915  19.0      1      1  C.A. 33112   36.7500   NaN        S
#
# [916 rows x 12 columns]

# %% [markdown]
# - to_csv 메서드
#     - dataframe 객체를 csv 파일로 저장

# %%
df.to_csv("data.csv",index=False)

# %% [markdown]
# # 데이터 프레임 기초 정보 확인하기

# %% [markdown]
# - 컬럼명 확인

# %%
df.columns
# Out:
# Index(['passengerid', 'survived', 'pclass', 'name', 'gender', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['passengerid',
#  'survived',
#  'pclass',
#  'name',
#  'gender',
#  'age',
#  'sibsp',
#  'parch',
#  'ticket',
#  'fare',
#  'cabin',
#  'embarked']

# %%
df["pclass"].tolist()
# Out:
# [1,
#  3,
#  3,
#  2,
#  1,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  2,
#  2,
#  2,
#  1,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  1,
#  3,
#  1,
#  3,
#  3,
#  1,
#  2,
#  1,
#  3,
#  3,
#  3,
#  3,
#  1,
#  1,
#  3,
#  3,
#  2,
#  1,
#  2,
#  3,
#  3,
#  1,
#  2,
#  3,
#  3,
#  2,
#  1,
#  2,
#  2,
#  1,
#  3,
#  2,
#  3,
#  1,
#  3,
#  3,
#  1,
#  3,
#  2,
#  3,
#  1,
#  3,
#  1,
#  1,
#  3,
#  2,
#  3,
#  2,
#  1,
#  3,
#  3,
#  2,
#  3,
#  2,
#  1,
#  3,
#  2,
#  2,
#  2,
#  2,
#  3,
#  1,
#  2,
#  3,
#  3,
#  3,
#  1,
#  3,
#  2,
#  2,
#  3,
#  1,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  1,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  2,
#  2,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  2,
#  1,
#  3,
#  2,
#  1,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  2,
#  1,
#  3,
#  3,
#  3,
#  2,
#  2,
#  3,
#  3,
#  1,
#  3,
#  3,
#  1,
#  1,
#  1,
#  2,
#  2,
#  1,
#  2,
#  1,
#  3,
#  3,
#  3,
#  2,
#  1,
#  3,
#  1,
#  2,
#  2,
#  3,
#  3,
#  3,
#  1,
#  1,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  1,
#  3,
#  2,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  1,
#  3,
#  1,
#  1,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  1,
#  1,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  1,
#  3,
#  1,
#  1,
#  2,
#  2,
#  3,
#  2,
#  3,
#  1,
#  3,
#  3,
#  1,
#  3,
#  2,
#  3,
#  3,
#  3,
#  2,
#  1,
#  1,
#  1,
#  1,
#  2,
#  1,
#  3,
#  1,
#  1,
#  3,
#  3,
#  1,
#  1,
#  2,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  2,
#  1,
#  2,
#  3,
#  3,
#  3,
#  3,
#  2,
#  1,
#  3,
#  2,
#  2,
#  1,
#  3,
#  3,
#  3,
#  1,
#  2,
#  1,
#  3,
#  1,
#  2,
#  2,
#  2,
#  1,
#  3,
#  3,
#  2,
#  1,
#  3,
#  3,
#  1,
#  1,
#  3,
#  3,
#  3,
#  1,
#  3,
#  1,
#  3,
#  3,
#  3,
#  1,
#  1,
#  2,
#  3,
#  3,
#  3,
#  2,
#  3,
#  1,
#  1,
#  3,
#  1,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  1,
#  2,
#  1,
#  2,
#  1,
#  1,
#  2,
#  1,
#  3,
#  1,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  2,
#  3,
#  3,
#  1,
#  1,
#  3,
#  2,
#  3,
#  3,
#  1,
#  2,
#  3,
#  3,
#  1,
#  3,
#  1,
#  2,
#  3,
#  3,
#  3,
#  2,
#  2,
#  1,
#  3,
#  2,
#  1,
#  2,
#  2,
#  3,
#  2,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  1,
#  2,
#  3,
#  2,
#  1,
#  1,
#  3,
#  3,
#  2,
#  1,
#  3,
#  3,
#  1,
#  3,
#  2,
#  1,
#  2,
#  1,
#  2,
#  1,
#  3,
#  2,
#  1,
#  2,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  1,
#  3,
#  1,
#  2,
#  2,
#  3,
#  3,
#  2,
#  3,
#  2,
#  3,
#  2,
#  3,
#  3,
#  3,
#  2,
#  3,
#  1,
#  1,
#  2,
#  3,
#  2,
#  3,
#  3,
#  1,
#  2,
#  3,
#  3,
#  2,
#  3,
#  3,
#  2,
#  3,
#  2,
#  1,
#  3,
#  2,
#  3,
#  1,
#  3,
#  1,
#  3,
#  1,
#  3,
#  3,
#  2,
#  1,
#  2,
#  3,
#  2,
#  3,
#  3,
#  1,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  2,
#  3,
#  1,
#  3,
#  2,
#  1,
#  1,
#  3,
#  1,
#  1,
#  1,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  2,
#  2,
#  2,
#  1,
#  3,
#  1,
#  2,
#  3,
#  1,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  2,
#  2,
#  2,
#  3,
#  1,
#  3,
#  2,
#  3,
#  1,
#  3,
#  2,
#  3,
#  3,
#  1,
#  3,
#  3,
#  1,
#  3,
#  1,
#  1,
#  3,
#  3,
#  2,
#  2,
#  2,
#  2,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  2,
#  1,
#  3,
#  1,
#  3,
#  1,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  1,
#  3,
#  1,
#  1,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  1,
#  3,
#  1,
#  1,
#  2,
#  1,
#  3,
#  3,
#  1,
#  2,
#  1,
#  3,
#  1,
#  3,
#  1,
#  3,
#  1,
#  3,
#  2,
#  1,
#  3,
#  1,
#  3,
#  2,
#  2,
#  1,
#  1,
#  1,
#  3,
#  1,
#  3,
#  3,
#  1,
#  1,
#  1,
#  2,
#  2,
#  3,
#  3,
#  1,
#  3,
#  3,
#  1,
#  3,
#  1,
#  3,
#  2,
#  3,
#  2,
#  3,
#  2,
#  3,
#  3,
#  1,
#  3,
#  2,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  1,
#  1,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  1,
#  1,
#  1,
#  2,
#  3,
#  3,
#  2,
#  1,
#  2,
#  2,
#  2,
#  3,
#  1,
#  3,
#  1,
#  3,
#  1,
#  2,
#  2,
#  2,
#  3,
#  3,
#  3,
#  2,
#  3,
#  2,
#  3,
#  1,
#  3,
#  3,
#  3,
#  2,
#  2,
#  3,
#  3,
#  2,
#  1,
#  3,
#  2,
#  3,
#  2,
#  2,
#  3,
#  1,
#  3,
#  2,
#  3,
#  2,
#  2,
#  3,
#  1,
#  3,
#  1,
#  3,
#  2,
#  1,
#  3,
#  2,
#  3,
#  2,
#  3,
#  2,
#  3,
#  1,
#  3,
#  1,
#  1,
#  3,
#  2,
#  1,
#  1,
#  3,
#  3,
#  3,
#  1,
#  2,
#  1,
#  1,
#  3,
#  3,
#  3,
#  3,
#  1,
#  1,
#  1,
#  1,
#  1,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  2,
#  3,
#  1,
#  3,
#  3,
#  3,
#  2,
#  1,
#  3,
#  2,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  2,
#  1,
#  2,
#  2,
#  3,
#  1,
#  3,
#  1,
#  1,
#  1,
#  3,
#  2,
#  3,
#  1,
#  2,
#  1,
#  3,
#  3,
#  1,
#  2,
#  1,
#  3,
#  1,
#  1,
#  1,
#  1,
#  3,
#  1,
#  3,
#  1,
#  2,
#  1,
#  2,
#  3,
#  3,
#  2,
#  3,
#  2,
#  3,
#  3,
#  1,
#  2,
#  1,
#  2,
#  2,
#  2,
#  3,
#  2,
#  3,
#  3,
#  1,
#  3,
#  2,
#  3,
#  1,
#  3,
#  3,
#  3,
#  2]

# %%
np.array(df["pclass"].tolist())
# Out:
# array([1, 3, 3, 2, 1, 3, 3, 3, 3, 1, 3, 2, 2, 2, 1, 1, 3, 3, 3, 3, 3, 3,
#        1, 3, 3, 3, 1, 3, 3, 3, 3, 3, 2, 1, 3, 1, 3, 3, 1, 2, 1, 3, 3, 3,
#        3, 1, 1, 3, 3, 2, 1, 2, 3, 3, 1, 2, 3, 3, 2, 1, 2, 2, 1, 3, 2, 3,
#        1, 3, 3, 1, 3, 2, 3, 1, 3, 1, 1, 3, 2, 3, 2, 1, 3, 3, 2, 3, 2, 1,
#        3, 2, 2, 2, 2, 3, 1, 2, 3, 3, 3, 1, 3, 2, 2, 3, 1, 2, 3, 3, 3, 3,
#        3, 1, 3, 3, 3, 1, 2, 3, 3, 3, 3, 3, 2, 3, 2, 2, 1, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 1, 2, 1, 3, 2, 1, 3, 3, 3, 1, 3, 3, 3, 3, 3, 1, 3,
#        3, 1, 3, 3, 3, 2, 1, 3, 3, 3, 2, 2, 3, 3, 1, 3, 3, 1, 1, 1, 2, 2,
#        1, 2, 1, 3, 3, 3, 2, 1, 3, 1, 2, 2, 3, 3, 3, 1, 1, 3, 3, 3, 3, 1,
#        3, 1, 3, 2, 3, 3, 3, 1, 3, 3, 3, 1, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3,
#        3, 2, 3, 1, 3, 1, 1, 2, 3, 3, 3, 3, 3, 2, 3, 3, 1, 3, 3, 3, 3, 1,
#        3, 3, 2, 3, 3, 3, 3, 3, 2, 1, 1, 1, 3, 3, 3, 3, 3, 2, 1, 3, 1, 1,
#        2, 2, 3, 2, 3, 1, 3, 3, 1, 3, 2, 3, 3, 3, 2, 1, 1, 1, 1, 2, 1, 3,
#        1, 1, 3, 3, 1, 1, 2, 3, 1, 3, 3, 3, 3, 3, 3, 2, 3, 3, 2, 1, 2, 3,
#        3, 3, 3, 2, 1, 3, 2, 2, 1, 3, 3, 3, 1, 2, 1, 3, 1, 2, 2, 2, 1, 3,
#        3, 2, 1, 3, 3, 1, 1, 3, 3, 3, 1, 3, 1, 3, 3, 3, 1, 1, 2, 3, 3, 3,
#        2, 3, 1, 1, 3, 1, 3, 3, 3, 1, 3, 3, 1, 2, 1, 2, 1, 1, 2, 1, 3, 1,
#        3, 3, 1, 3, 3, 3, 3, 3, 3, 3, 1, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 2,
#        3, 3, 1, 1, 3, 2, 3, 3, 1, 2, 3, 3, 1, 3, 1, 2, 3, 3, 3, 2, 2, 1,
#        3, 2, 1, 2, 2, 3, 2, 3, 2, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 2, 3,
#        3, 3, 3, 3, 1, 3, 3, 2, 3, 3, 3, 3, 2, 3, 3, 3, 3, 1, 2, 3, 2, 1,
#        1, 3, 3, 2, 1, 3, 3, 1, 3, 2, 1, 2, 1, 2, 1, 3, 2, 1, 2, 3, 3, 3,
#        3, 1, 3, 1, 3, 1, 2, 2, 3, 3, 2, 3, 2, 3, 2, 3, 3, 3, 2, 3, 1, 1,
#        2, 3, 2, 3, 3, 1, 2, 3, 3, 2, 3, 3, 2, 3, 2, 1, 3, 2, 3, 1, 3, 1,
#        3, 1, 3, 3, 2, 1, 2, 3, 2, 3, 3, 1, 1, 3, 3, 3, 3, 3, 2, 3, 3, 2,
#        3, 1, 3, 2, 1, 1, 3, 1, 1, 1, 3, 3, 3, 3, 2, 3, 3, 3, 2, 2, 2, 1,
#        3, 1, 2, 3, 1, 3, 1, 3, 3, 3, 3, 3, 1, 2, 2, 2, 3, 1, 3, 2, 3, 1,
#        3, 2, 3, 3, 1, 3, 3, 1, 3, 1, 1, 3, 3, 2, 2, 2, 2, 3, 3, 3, 3, 2,
#        3, 3, 2, 3, 3, 3, 3, 2, 3, 3, 2, 1, 3, 1, 3, 1, 3, 1, 3, 3, 3, 3,
#        3, 3, 2, 3, 3, 3, 1, 3, 1, 1, 3, 3, 3, 1, 3, 3, 3, 1, 3, 1, 1, 2,
#        1, 3, 3, 1, 2, 1, 3, 1, 3, 1, 3, 1, 3, 2, 1, 3, 1, 3, 2, 2, 1, 1,
#        1, 3, 1, 3, 3, 1, 1, 1, 2, 2, 3, 3, 1, 3, 3, 1, 3, 1, 3, 2, 3, 2,
#        3, 2, 3, 3, 1, 3, 2, 3, 3, 1, 3, 3, 3, 1, 1, 2, 3, 3, 3, 3, 3, 3,
#        3, 3, 1, 1, 1, 1, 2, 3, 3, 2, 1, 2, 2, 2, 3, 1, 3, 1, 3, 1, 2, 2,
#        2, 3, 3, 3, 2, 3, 2, 3, 1, 3, 3, 3, 2, 2, 3, 3, 2, 1, 3, 2, 3, 2,
#        2, 3, 1, 3, 2, 3, 2, 2, 3, 1, 3, 1, 3, 2, 1, 3, 2, 3, 2, 3, 2, 3,
#        1, 3, 1, 1, 3, 2, 1, 1, 3, 3, 3, 1, 2, 1, 1, 3, 3, 3, 3, 1, 1, 1,
#        1, 1, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 2, 3, 1, 3, 3, 3,
#        2, 1, 3, 2, 3, 1, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 2,
#        1, 2, 2, 3, 1, 3, 1, 1, 1, 3, 2, 3, 1, 2, 1, 3, 3, 1, 2, 1, 3, 1,
#        1, 1, 1, 3, 1, 3, 1, 2, 1, 2, 3, 3, 2, 3, 2, 3, 3, 1, 2, 1, 2, 2,
#        2, 3, 2, 3, 3, 1, 3, 2, 3, 1, 3, 3, 3, 2])

# %%
np.array(df["pclass"])
# Out:
# array([1, 3, 3, 2, 1, 3, 3, 3, 3, 1, 3, 2, 2, 2, 1, 1, 3, 3, 3, 3, 3, 3,
#        1, 3, 3, 3, 1, 3, 3, 3, 3, 3, 2, 1, 3, 1, 3, 3, 1, 2, 1, 3, 3, 3,
#        3, 1, 1, 3, 3, 2, 1, 2, 3, 3, 1, 2, 3, 3, 2, 1, 2, 2, 1, 3, 2, 3,
#        1, 3, 3, 1, 3, 2, 3, 1, 3, 1, 1, 3, 2, 3, 2, 1, 3, 3, 2, 3, 2, 1,
#        3, 2, 2, 2, 2, 3, 1, 2, 3, 3, 3, 1, 3, 2, 2, 3, 1, 2, 3, 3, 3, 3,
#        3, 1, 3, 3, 3, 1, 2, 3, 3, 3, 3, 3, 2, 3, 2, 2, 1, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 1, 2, 1, 3, 2, 1, 3, 3, 3, 1, 3, 3, 3, 3, 3, 1, 3,
#        3, 1, 3, 3, 3, 2, 1, 3, 3, 3, 2, 2, 3, 3, 1, 3, 3, 1, 1, 1, 2, 2,
#        1, 2, 1, 3, 3, 3, 2, 1, 3, 1, 2, 2, 3, 3, 3, 1, 1, 3, 3, 3, 3, 1,
#        3, 1, 3, 2, 3, 3, 3, 1, 3, 3, 3, 1, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3,
#        3, 2, 3, 1, 3, 1, 1, 2, 3, 3, 3, 3, 3, 2, 3, 3, 1, 3, 3, 3, 3, 1,
#        3, 3, 2, 3, 3, 3, 3, 3, 2, 1, 1, 1, 3, 3, 3, 3, 3, 2, 1, 3, 1, 1,
#        2, 2, 3, 2, 3, 1, 3, 3, 1, 3, 2, 3, 3, 3, 2, 1, 1, 1, 1, 2, 1, 3,
#        1, 1, 3, 3, 1, 1, 2, 3, 1, 3, 3, 3, 3, 3, 3, 2, 3, 3, 2, 1, 2, 3,
#        3, 3, 3, 2, 1, 3, 2, 2, 1, 3, 3, 3, 1, 2, 1, 3, 1, 2, 2, 2, 1, 3,
#        3, 2, 1, 3, 3, 1, 1, 3, 3, 3, 1, 3, 1, 3, 3, 3, 1, 1, 2, 3, 3, 3,
#        2, 3, 1, 1, 3, 1, 3, 3, 3, 1, 3, 3, 1, 2, 1, 2, 1, 1, 2, 1, 3, 1,
#        3, 3, 1, 3, 3, 3, 3, 3, 3, 3, 1, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 2,
#        3, 3, 1, 1, 3, 2, 3, 3, 1, 2, 3, 3, 1, 3, 1, 2, 3, 3, 3, 2, 2, 1,
#        3, 2, 1, 2, 2, 3, 2, 3, 2, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 2, 3,
#        3, 3, 3, 3, 1, 3, 3, 2, 3, 3, 3, 3, 2, 3, 3, 3, 3, 1, 2, 3, 2, 1,
#        1, 3, 3, 2, 1, 3, 3, 1, 3, 2, 1, 2, 1, 2, 1, 3, 2, 1, 2, 3, 3, 3,
#        3, 1, 3, 1, 3, 1, 2, 2, 3, 3, 2, 3, 2, 3, 2, 3, 3, 3, 2, 3, 1, 1,
#        2, 3, 2, 3, 3, 1, 2, 3, 3, 2, 3, 3, 2, 3, 2, 1, 3, 2, 3, 1, 3, 1,
#        3, 1, 3, 3, 2, 1, 2, 3, 2, 3, 3, 1, 1, 3, 3, 3, 3, 3, 2, 3, 3, 2,
#        3, 1, 3, 2, 1, 1, 3, 1, 1, 1, 3, 3, 3, 3, 2, 3, 3, 3, 2, 2, 2, 1,
#        3, 1, 2, 3, 1, 3, 1, 3, 3, 3, 3, 3, 1, 2, 2, 2, 3, 1, 3, 2, 3, 1,
#        3, 2, 3, 3, 1, 3, 3, 1, 3, 1, 1, 3, 3, 2, 2, 2, 2, 3, 3, 3, 3, 2,
#        3, 3, 2, 3, 3, 3, 3, 2, 3, 3, 2, 1, 3, 1, 3, 1, 3, 1, 3, 3, 3, 3,
#        3, 3, 2, 3, 3, 3, 1, 3, 1, 1, 3, 3, 3, 1, 3, 3, 3, 1, 3, 1, 1, 2,
#        1, 3, 3, 1, 2, 1, 3, 1, 3, 1, 3, 1, 3, 2, 1, 3, 1, 3, 2, 2, 1, 1,
#        1, 3, 1, 3, 3, 1, 1, 1, 2, 2, 3, 3, 1, 3, 3, 1, 3, 1, 3, 2, 3, 2,
#        3, 2, 3, 3, 1, 3, 2, 3, 3, 1, 3, 3, 3, 1, 1, 2, 3, 3, 3, 3, 3, 3,
#        3, 3, 1, 1, 1, 1, 2, 3, 3, 2, 1, 2, 2, 2, 3, 1, 3, 1, 3, 1, 2, 2,
#        2, 3, 3, 3, 2, 3, 2, 3, 1, 3, 3, 3, 2, 2, 3, 3, 2, 1, 3, 2, 3, 2,
#        2, 3, 1, 3, 2, 3, 2, 2, 3, 1, 3, 1, 3, 2, 1, 3, 2, 3, 2, 3, 2, 3,
#        1, 3, 1, 1, 3, 2, 1, 1, 3, 3, 3, 1, 2, 1, 1, 3, 3, 3, 3, 1, 1, 1,
#        1, 1, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 2, 3, 1, 3, 3, 3,
#        2, 1, 3, 2, 3, 1, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 2,
#        1, 2, 2, 3, 1, 3, 1, 1, 1, 3, 2, 3, 1, 2, 1, 3, 3, 1, 2, 1, 3, 1,
#        1, 1, 1, 3, 1, 3, 1, 2, 1, 2, 3, 3, 2, 3, 2, 3, 3, 1, 2, 1, 2, 2,
#        2, 3, 2, 3, 3, 1, 3, 2, 3, 1, 3, 3, 3, 2], dtype=int64)

# %% [markdown]
# - 데이터 프레임 정보 확인

# %%
df.info() # verbose=True, show_counts=True
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 916 entries, 0 to 915
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   passengerid  916 non-null    int64
#  1   survived     916 non-null    int64
#  2   pclass       916 non-null    int64
#  3   name         916 non-null    object
#  4   gender       916 non-null    object
#  5   age          736 non-null    float64
#  6   sibsp        916 non-null    int64
#  7   parch        916 non-null    int64
#  8   ticket       916 non-null    object
#  9   fare         916 non-null    float64
#  10  cabin        210 non-null    object
#  11  embarked     916 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 86.0+ KB

# %%
df.shape
# Out:
# (916, 12)

# %%
df.head(20)
# Out:
#     passengerid  survived  pclass  \
# 0           494         0       1
# 1           462         0       3
# 2          1286         0       3
# 3          1130         1       2
# 4           461         1       1
# 5           952         0       3
# 6           130         0       3
# 7           331         1       3
# 8           814         0       3
# 9           119         0       1
# 10          815         0       3
# 11           18         1       2
# 12          993         0       2
# 13          802         1       2
# 14          914         1       1
# 15         1215         0       1
# 16          242         1       3
# 17          288         0       3
# 18          562         0       3
# 19          465         0       3
#
#                                            name  gender   age  sibsp  parch  \
# 0                       Artagaveytia, Mr. Ramon    male  71.0      0      0
# 1                           Morley, Mr. William    male  34.0      0      0
# 2                      Kink-Heilmann, Mr. Anton    male  29.0      3      1
# 3                         Hiltunen, Miss. Marta  female  18.0      1      1
# 4                           Anderson, Mr. Harry    male  48.0      0      0
# 5                               Dika, Mr. Mirko    male  17.0      0      0
# 6                            Ekstrom, Mr. Johan    male  45.0      0      0
# 7                            McCoy, Miss. Agnes  female   NaN      2      0
# 8            Andersson, Miss. Ebba Iris Alfrida  female   6.0      4      2
# 9                      Baxter, Mr. Quigg Edmond    male  24.0      0      1
# 10                   Tomlin, Mr. Ernest Portage    male  30.5      0      0
# 11                 Williams, Mr. Charles Eugene    male   NaN      0      0
# 12                           Weisz, Mr. Leopold    male  27.0      1      0
# 13  Collyer, Mrs. Harvey (Charlotte Annie Tate)  female  31.0      1      1
# 14         Flegenheim, Mrs. Alfred (Antoinette)  female   NaN      0      0
# 15                           Rowe, Mr. Alfred G    male  33.0      0      0
# 16               Murphy, Miss. Katherine "Kate"  female   NaN      1      0
# 17                         Naidenoff, Mr. Penko    male  22.0      0      0
# 18                            Sivic, Mr. Husein    male  40.0      0      0
# 19                           Maisner, Mr. Simon    male   NaN      0      0
#
#         ticket      fare    cabin embarked
# 0     PC 17609   49.5042      NaN        C
# 1       364506    8.0500      NaN        S
# 2       315153   22.0250      NaN        S
# 3       250650   13.0000      NaN        S
# 4        19952   26.5500      E12        S
# 5       349232    7.8958      NaN        S
# 6       347061    6.9750      NaN        S
# 7       367226   23.2500      NaN        Q
# 8       347082   31.2750      NaN        S
# 9     PC 17558  247.5208  B58 B60        C
# 10      364499    8.0500      NaN        S
# 11      244373   13.0000      NaN        S
# 12      228414   26.0000      NaN        S
# 13  C.A. 31921   26.2500      NaN        S
# 14    PC 17598   31.6833      NaN        S
# 15      113790   26.5500      NaN        S
# 16      367230   15.5000      NaN        Q
# 17      349206    7.8958      NaN        S
# 18      349251    7.8958      NaN        S
# 19    A/S 2816    8.0500      NaN        S

# %%
df.tail()
# Out:
#      passengerid  survived  pclass                          name gender   age  \
# 911          738         1       1        Lesurer, Mr. Gustave J   male  35.0
# 912          518         0       3             Ryan, Mr. Patrick   male   NaN
# 913          664         0       3              Coleff, Mr. Peju   male  36.0
# 914          109         0       3               Rekic, Mr. Tido   male  38.0
# 915          146         0       2  Nicholls, Mr. Joseph Charles   male  19.0
#
#      sibsp  parch      ticket      fare cabin embarked
# 911      0      0    PC 17755  512.3292  B101        C
# 912      0      0      371110   24.1500   NaN        Q
# 913      0      0      349210    7.4958   NaN        S
# 914      0      0      349249    7.8958   NaN        S
# 915      1      1  C.A. 33112   36.7500   NaN        S

# %% [markdown]
# # 데이터 프레임 다루기

# %% [markdown]
# - copy 메서드
#     - 데이터프레임을 복사(깊은 복사)

# %%
df_cp = df.copy()
df_cp
# Out:
#      passengerid  survived  pclass                          name  gender  \
# 0            494         0       1       Artagaveytia, Mr. Ramon    male
# 1            462         0       3           Morley, Mr. William    male
# 2           1286         0       3      Kink-Heilmann, Mr. Anton    male
# 3           1130         1       2         Hiltunen, Miss. Marta  female
# 4            461         1       1           Anderson, Mr. Harry    male
# ..           ...       ...     ...                           ...     ...
# 911          738         1       1        Lesurer, Mr. Gustave J    male
# 912          518         0       3             Ryan, Mr. Patrick    male
# 913          664         0       3              Coleff, Mr. Peju    male
# 914          109         0       3               Rekic, Mr. Tido    male
# 915          146         0       2  Nicholls, Mr. Joseph Charles    male
#
#       age  sibsp  parch      ticket      fare cabin embarked
# 0    71.0      0      0    PC 17609   49.5042   NaN        C
# 1    34.0      0      0      364506    8.0500   NaN        S
# 2    29.0      3      1      315153   22.0250   NaN        S
# 3    18.0      1      1      250650   13.0000   NaN        S
# 4    48.0      0      0       19952   26.5500   E12        S
# ..    ...    ...    ...         ...       ...   ...      ...
# 911  35.0      0      0    PC 17755  512.3292  B101        C
# 912   NaN      0      0      371110   24.1500   NaN        Q
# 913  36.0      0      0      349210    7.4958   NaN        S
# 914  38.0      0      0      349249    7.8958   NaN        S
# 915  19.0      1      1  C.A. 33112   36.7500   NaN        S
#
# [916 rows x 12 columns]

# %% [markdown]
# - 컬럼명 변경하기

# %%
type(df_cp.columns )
# Out:
# pandas.core.indexes.base.Index

# %%
# 한번에 변경
cols = ["id", "생존", "객실등급", "이름", "성별", "나이", "형제자매_배우자수",
        "부모자식수", "티켓번호", "요금", "객실번호", "탑승항구"]
df_cp.columns = cols
df_cp.head()
# Out:
#      id  생존  객실등급                        이름      성별    나이  형제자매_배우자수  부모자식수  \
# 0   494   0     1   Artagaveytia, Mr. Ramon    male  71.0          0      0
# 1   462   0     3       Morley, Mr. William    male  34.0          0      0
# 2  1286   0     3  Kink-Heilmann, Mr. Anton    male  29.0          3      1
# 3  1130   1     2     Hiltunen, Miss. Marta  female  18.0          1      1
# 4   461   1     1       Anderson, Mr. Harry    male  48.0          0      0
#
#        티켓번호       요금 객실번호 탑승항구
# 0  PC 17609  49.5042  NaN    C
# 1    364506   8.0500  NaN    S
# 2    315153  22.0250  NaN    S
# 3    250650  13.0000  NaN    S
# 4     19952  26.5500  E12    S

# %%
# df_cp.columns[2] = "객실" # 에러 난다.

# %% [markdown]
# - rename 메서드
#     - 지정한 컬럼명들을 변경할 수 있음
#     - 딕셔너리 형태로 인수를 전달하면 된다.
#         - key: 변경전 컬럼이름
#         - value: 변경후 컬럼이름

# %%
rename_dict = {"id": "아이디"}
df_cp.rename(columns=rename_dict)
# Out:
#       아이디  생존  객실등급                            이름      성별    나이  형제자매_배우자수  \
# 0     494   0     1       Artagaveytia, Mr. Ramon    male  71.0          0
# 1     462   0     3           Morley, Mr. William    male  34.0          0
# 2    1286   0     3      Kink-Heilmann, Mr. Anton    male  29.0          3
# 3    1130   1     2         Hiltunen, Miss. Marta  female  18.0          1
# 4     461   1     1           Anderson, Mr. Harry    male  48.0          0
# ..    ...  ..   ...                           ...     ...   ...        ...
# 911   738   1     1        Lesurer, Mr. Gustave J    male  35.0          0
# 912   518   0     3             Ryan, Mr. Patrick    male   NaN          0
# 913   664   0     3              Coleff, Mr. Peju    male  36.0          0
# 914   109   0     3               Rekic, Mr. Tido    male  38.0          0
# 915   146   0     2  Nicholls, Mr. Joseph Charles    male  19.0          1
#
#      부모자식수        티켓번호        요금  객실번호 탑승항구
# 0        0    PC 17609   49.5042   NaN    C
# 1        0      364506    8.0500   NaN    S
# 2        1      315153   22.0250   NaN    S
# 3        1      250650   13.0000   NaN    S
# 4        0       19952   26.5500   E12    S
# ..     ...         ...       ...   ...  ...
# 911      0    PC 17755  512.3292  B101    C
# 912      0      371110   24.1500   NaN    Q
# 913      0      349210    7.4958   NaN    S
# 914      0      349249    7.8958   NaN    S
# 915      1  C.A. 33112   36.7500   NaN    S
#
# [916 rows x 12 columns]

# %% [markdown]
# - add_prefix
#     - 컬럼명 앞부분에 공통된 문자열을 붙혀준다.

# %%
import pandas as pd


df.add_prefix("num_")
# Out:
#      num_passengerid  num_survived  num_pclass                      num_name  \
# 0                494             0           1       Artagaveytia, Mr. Ramon
# 1                462             0           3           Morley, Mr. William
# 2               1286             0           3      Kink-Heilmann, Mr. Anton
# 3               1130             1           2         Hiltunen, Miss. Marta
# 4                461             1           1           Anderson, Mr. Harry
# ..               ...           ...         ...                           ...
# 911              738             1           1        Lesurer, Mr. Gustave J
# 912              518             0           3             Ryan, Mr. Patrick
# 913              664             0           3              Coleff, Mr. Peju
# 914              109             0           3               Rekic, Mr. Tido
# 915              146             0           2  Nicholls, Mr. Joseph Charles
#
#     num_gender  num_age  num_sibsp  num_parch  num_ticket  num_fare num_cabin  \
# 0         male     71.0          0          0    PC 17609   49.5042       NaN
# 1         male     34.0          0          0      364506    8.0500       NaN
# 2         male     29.0          3          1      315153   22.0250       NaN
# 3       female     18.0          1          1      250650   13.0000       NaN
# 4         male     48.0          0          0       19952   26.5500       E12
# ..         ...      ...        ...        ...         ...       ...       ...
# 911       male     35.0          0          0    PC 17755  512.3292      B101
# 912       male      NaN          0          0      371110   24.1500       NaN
# 913       male     36.0          0          0      349210    7.4958       NaN
# 914       male     38.0          0          0      349249    7.8958       NaN
# 915       male     19.0          1          1  C.A. 33112   36.7500       NaN
#
#     num_embarked
# 0              C
# 1              S
# 2              S
# 3              S
# 4              S
# ..           ...
# 911            C
# 912            Q
# 913            S
# 914            S
# 915            S
#
# [916 rows x 12 columns]

# %% [markdown]
# - add_suffix
#     - 컬럼명 뒷부분에 공통된 문자열을 붙혀준다.

# %%
df.add_suffix("_suf")
# Out:
#      passengerid_suf  survived_suf  pclass_suf                      name_suf  \
# 0                494             0           1       Artagaveytia, Mr. Ramon
# 1                462             0           3           Morley, Mr. William
# 2               1286             0           3      Kink-Heilmann, Mr. Anton
# 3               1130             1           2         Hiltunen, Miss. Marta
# 4                461             1           1           Anderson, Mr. Harry
# ..               ...           ...         ...                           ...
# 911              738             1           1        Lesurer, Mr. Gustave J
# 912              518             0           3             Ryan, Mr. Patrick
# 913              664             0           3              Coleff, Mr. Peju
# 914              109             0           3               Rekic, Mr. Tido
# 915              146             0           2  Nicholls, Mr. Joseph Charles
#
#     gender_suf  age_suf  sibsp_suf  parch_suf  ticket_suf  fare_suf cabin_suf  \
# 0         male     71.0          0          0    PC 17609   49.5042       NaN
# 1         male     34.0          0          0      364506    8.0500       NaN
# 2         male     29.0          3          1      315153   22.0250       NaN
# 3       female     18.0          1          1      250650   13.0000       NaN
# 4         male     48.0          0          0       19952   26.5500       E12
# ..         ...      ...        ...        ...         ...       ...       ...
# 911       male     35.0          0          0    PC 17755  512.3292      B101
# 912       male      NaN          0          0      371110   24.1500       NaN
# 913       male     36.0          0          0      349210    7.4958       NaN
# 914       male     38.0          0          0      349249    7.8958       NaN
# 915       male     19.0          1          1  C.A. 33112   36.7500       NaN
#
#     embarked_suf
# 0              C
# 1              S
# 2              S
# 3              S
# 4              S
# ..           ...
# 911            C
# 912            Q
# 913            S
# 914            S
# 915            S
#
# [916 rows x 12 columns]

# %% [markdown]
# - 특정 컬럼들 선택

# %%
cols = ["name","gender","age"]
df[cols]
# Out:
#                              name  gender   age
# 0         Artagaveytia, Mr. Ramon    male  71.0
# 1             Morley, Mr. William    male  34.0
# 2        Kink-Heilmann, Mr. Anton    male  29.0
# 3           Hiltunen, Miss. Marta  female  18.0
# 4             Anderson, Mr. Harry    male  48.0
# ..                            ...     ...   ...
# 911        Lesurer, Mr. Gustave J    male  35.0
# 912             Ryan, Mr. Patrick    male   NaN
# 913              Coleff, Mr. Peju    male  36.0
# 914               Rekic, Mr. Tido    male  38.0
# 915  Nicholls, Mr. Joseph Charles    male  19.0
#
# [916 rows x 3 columns]

# %%
target = df["survived"]
target
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 911    1
# 912    0
# 913    0
# 914    0
# 915    0
# Name: survived, Length: 916, dtype: int64

# %% [markdown]
# - 컬럼 삭제하기

# %%
# axis 를 사용한 방법
df.drop("survived", axis=1) # 열방향
# Out:
#      passengerid  pclass                          name  gender   age  sibsp  \
# 0            494       1       Artagaveytia, Mr. Ramon    male  71.0      0
# 1            462       3           Morley, Mr. William    male  34.0      0
# 2           1286       3      Kink-Heilmann, Mr. Anton    male  29.0      3
# 3           1130       2         Hiltunen, Miss. Marta  female  18.0      1
# 4            461       1           Anderson, Mr. Harry    male  48.0      0
# ..           ...     ...                           ...     ...   ...    ...
# 911          738       1        Lesurer, Mr. Gustave J    male  35.0      0
# 912          518       3             Ryan, Mr. Patrick    male   NaN      0
# 913          664       3              Coleff, Mr. Peju    male  36.0      0
# 914          109       3               Rekic, Mr. Tido    male  38.0      0
# 915          146       2  Nicholls, Mr. Joseph Charles    male  19.0      1
#
#      parch      ticket      fare cabin embarked
# 0        0    PC 17609   49.5042   NaN        C
# 1        0      364506    8.0500   NaN        S
# 2        1      315153   22.0250   NaN        S
# 3        1      250650   13.0000   NaN        S
# 4        0       19952   26.5500   E12        S
# ..     ...         ...       ...   ...      ...
# 911      0    PC 17755  512.3292  B101        C
# 912      0      371110   24.1500   NaN        Q
# 913      0      349210    7.4958   NaN        S
# 914      0      349249    7.8958   NaN        S
# 915      1  C.A. 33112   36.7500   NaN        S
#
# [916 rows x 11 columns]

# %%
df.drop(["name","survived"], axis=1) # 열방향
# Out:
#      passengerid  pclass  gender   age  sibsp  parch      ticket      fare  \
# 0            494       1    male  71.0      0      0    PC 17609   49.5042
# 1            462       3    male  34.0      0      0      364506    8.0500
# 2           1286       3    male  29.0      3      1      315153   22.0250
# 3           1130       2  female  18.0      1      1      250650   13.0000
# 4            461       1    male  48.0      0      0       19952   26.5500
# ..           ...     ...     ...   ...    ...    ...         ...       ...
# 911          738       1    male  35.0      0      0    PC 17755  512.3292
# 912          518       3    male   NaN      0      0      371110   24.1500
# 913          664       3    male  36.0      0      0      349210    7.4958
# 914          109       3    male  38.0      0      0      349249    7.8958
# 915          146       2    male  19.0      1      1  C.A. 33112   36.7500
#
#     cabin embarked
# 0     NaN        C
# 1     NaN        S
# 2     NaN        S
# 3     NaN        S
# 4     E12        S
# ..    ...      ...
# 911  B101        C
# 912   NaN        Q
# 913   NaN        S
# 914   NaN        S
# 915   NaN        S
#
# [916 rows x 10 columns]

# %%
# df.drop(3,axis=0) # 행방향

# %%
df.drop(columns=["name","age"])
# Out:
#      passengerid  survived  pclass  gender  sibsp  parch      ticket  \
# 0            494         0       1    male      0      0    PC 17609
# 1            462         0       3    male      0      0      364506
# 2           1286         0       3    male      3      1      315153
# 3           1130         1       2  female      1      1      250650
# 4            461         1       1    male      0      0       19952
# ..           ...       ...     ...     ...    ...    ...         ...
# 911          738         1       1    male      0      0    PC 17755
# 912          518         0       3    male      0      0      371110
# 913          664         0       3    male      0      0      349210
# 914          109         0       3    male      0      0      349249
# 915          146         0       2    male      1      1  C.A. 33112
#
#          fare cabin embarked
# 0     49.5042   NaN        C
# 1      8.0500   NaN        S
# 2     22.0250   NaN        S
# 3     13.0000   NaN        S
# 4     26.5500   E12        S
# ..        ...   ...      ...
# 911  512.3292  B101        C
# 912   24.1500   NaN        Q
# 913    7.4958   NaN        S
# 914    7.8958   NaN        S
# 915   36.7500   NaN        S
#
# [916 rows x 10 columns]

# %% [markdown]
# - 컬럼을 기준으로 정렬

# %%
df.sort_values(by="age") # 기본 오름차순
# Out:
#      passengerid  survived  pclass  \
# 852         1246         1       3
# 480          756         1       2
# 289          470         1       3
# 41          1173         0       3
# 587           79         1       2
# ..           ...       ...     ...
# 881          508         1       1
# 893          668         0       3
# 895           66         1       3
# 897          458         1       1
# 912          518         0       3
#
#                                               name  gender   age  sibsp  \
# 852        Dean, Miss. Elizabeth Gladys Millvina""  female  0.17      1
# 480                      Hamalainen, Master. Viljo    male  0.67      1
# 289                  Baclini, Miss. Helene Barbara  female  0.75      2
# 41                  Peacock, Master. Alfred Edward    male  0.75      1
# 587                  Caldwell, Master. Alden Gates    male  0.83      0
# ..                                             ...     ...   ...    ...
# 881  Bradley, Mr. George ("George Arthur Brayton")    male   NaN      0
# 893                     Rommetvedt, Mr. Knud Paust    male   NaN      0
# 895                       Moubarek, Master. Gerios    male   NaN      1
# 897              Kenyon, Mrs. Frederick R (Marion)  female   NaN      1
# 912                              Ryan, Mr. Patrick    male   NaN      0
#
#      parch              ticket     fare cabin embarked
# 852      2           C.A. 2315  20.5750   NaN        S
# 480      1              250649  14.5000   NaN        S
# 289      1                2666  19.2583   NaN        C
# 41       1  SOTON/O.Q. 3101315  13.7750   NaN        S
# 587      2              248738  29.0000   NaN        S
# ..     ...                 ...      ...   ...      ...
# 881      0              111427  26.5500   NaN        S
# 893      0              312993   7.7750   NaN        S
# 895      1                2661  15.2458   NaN        C
# 897      0               17464  51.8625   D21        S
# 912      0              371110  24.1500   NaN        Q
#
# [916 rows x 12 columns]

# %%
df.sort_values(by="age", ascending=False) # 내림차순
# Out:
#      passengerid  survived  pclass  \
# 694          631         1       1
# 729          988         1       1
# 375          852         0       3
# 0            494         0       1
# 22            97         0       1
# ..           ...       ...     ...
# 881          508         1       1
# 893          668         0       3
# 895           66         1       3
# 897          458         1       1
# 912          518         0       3
#
#                                                   name  gender   age  sibsp  \
# 694               Barkworth, Mr. Algernon Henry Wilson    male  80.0      0
# 729  Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0      1
# 375                                Svensson, Mr. Johan    male  74.0      0
# 0                              Artagaveytia, Mr. Ramon    male  71.0      0
# 22                           Goldschmidt, Mr. George B    male  71.0      0
# ..                                                 ...     ...   ...    ...
# 881      Bradley, Mr. George ("George Arthur Brayton")    male   NaN      0
# 893                         Rommetvedt, Mr. Knud Paust    male   NaN      0
# 895                           Moubarek, Master. Gerios    male   NaN      1
# 897                  Kenyon, Mrs. Frederick R (Marion)  female   NaN      1
# 912                                  Ryan, Mr. Patrick    male   NaN      0
#
#      parch    ticket     fare cabin embarked
# 694      0     27042  30.0000   A23        S
# 729      0     19877  78.8500   C46        S
# 375      0    347060   7.7750   NaN        S
# 0        0  PC 17609  49.5042   NaN        C
# 22       0  PC 17754  34.6542    A5        C
# ..     ...       ...      ...   ...      ...
# 881      0    111427  26.5500   NaN        S
# 893      0    312993   7.7750   NaN        S
# 895      1      2661  15.2458   NaN        C
# 897      0     17464  51.8625   D21        S
# 912      0    371110  24.1500   NaN        Q
#
# [916 rows x 12 columns]

# %%
df.sort_values(by=["age","gender"], ascending=False)
# Out:
#      passengerid  survived  pclass  \
# 694          631         1       1
# 729          988         1       1
# 375          852         0       3
# 0            494         0       1
# 22            97         0       1
# ..           ...       ...     ...
# 755          236         0       3
# 759          928         1       3
# 793          110         1       3
# 834          416         0       3
# 897          458         1       1
#
#                                                   name  gender   age  sibsp  \
# 694               Barkworth, Mr. Algernon Henry Wilson    male  80.0      0
# 729  Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0      1
# 375                                Svensson, Mr. Johan    male  74.0      0
# 0                              Artagaveytia, Mr. Ramon    male  71.0      0
# 22                           Goldschmidt, Mr. George B    male  71.0      0
# ..                                                 ...     ...   ...    ...
# 755                       Harknett, Miss. Alice Phoebe  female   NaN      0
# 759                                Roth, Miss. Sarah A  female   NaN      0
# 793                                Moran, Miss. Bertha  female   NaN      1
# 834            Meek, Mrs. Thomas (Annie Louise Rowley)  female   NaN      0
# 897                  Kenyon, Mrs. Frederick R (Marion)  female   NaN      1
#
#      parch      ticket     fare cabin embarked
# 694      0       27042  30.0000   A23        S
# 729      0       19877  78.8500   C46        S
# 375      0      347060   7.7750   NaN        S
# 0        0    PC 17609  49.5042   NaN        C
# 22       0    PC 17754  34.6542    A5        C
# ..     ...         ...      ...   ...      ...
# 755      0  W./C. 6609   7.5500   NaN        S
# 759      0      342712   8.0500   NaN        S
# 793      0      371110  24.1500   NaN        Q
# 834      0      343095   8.0500   NaN        S
# 897      0       17464  51.8625   D21        S
#
# [916 rows x 12 columns]

# %%
df.sort_values(by=["age", "gender"], ascending=[True, False])
# Out:
#      passengerid  survived  pclass                                     name  \
# 852         1246         1       3  Dean, Miss. Elizabeth Gladys Millvina""
# 480          756         1       2                Hamalainen, Master. Viljo
# 41          1173         0       3           Peacock, Master. Alfred Edward
# 289          470         1       3            Baclini, Miss. Helene Barbara
# 587           79         1       2            Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                      ...
# 755          236         0       3             Harknett, Miss. Alice Phoebe
# 759          928         1       3                      Roth, Miss. Sarah A
# 793          110         1       3                      Moran, Miss. Bertha
# 834          416         0       3  Meek, Mrs. Thomas (Annie Louise Rowley)
# 897          458         1       1        Kenyon, Mrs. Frederick R (Marion)
#
#      gender   age  sibsp  parch              ticket     fare cabin embarked
# 852  female  0.17      1      2           C.A. 2315  20.5750   NaN        S
# 480    male  0.67      1      1              250649  14.5000   NaN        S
# 41     male  0.75      1      1  SOTON/O.Q. 3101315  13.7750   NaN        S
# 289  female  0.75      2      1                2666  19.2583   NaN        C
# 587    male  0.83      0      2              248738  29.0000   NaN        S
# ..      ...   ...    ...    ...                 ...      ...   ...      ...
# 755  female   NaN      0      0          W./C. 6609   7.5500   NaN        S
# 759  female   NaN      0      0              342712   8.0500   NaN        S
# 793  female   NaN      1      0              371110  24.1500   NaN        Q
# 834  female   NaN      0      0              343095   8.0500   NaN        S
# 897  female   NaN      1      0               17464  51.8625   D21        S
#
# [916 rows x 12 columns]

# %% [markdown]
# - 데이터 프레임 섞기

# %%
df2 = df.sample(frac=1,random_state=42)
df2
# Out:
#      passengerid  survived  pclass  \
# 380           78         0       3
# 879          274         0       1
# 355          782         1       1
# 357          956         0       1
# 362         1234         0       3
# ..           ...       ...     ...
# 106         1249         0       3
# 270           40         1       3
# 860         1114         1       2
# 435           86         1       3
# 102          235         0       2
#
#                                                   name  gender   age  sibsp  \
# 380                           Moutal, Mr. Rahamin Haim    male   NaN      0
# 879                              Natsch, Mr. Charles H    male  37.0      0
# 355          Dick, Mrs. Albert Adrian (Vera Gillespie)  female  17.0      1
# 357                        Ryerson, Master. John Borie    male  13.0      2
# 362                              Sage, Mr. John George    male   NaN      1
# ..                                                 ...     ...   ...    ...
# 106                                Lockyer, Mr. Edward    male   NaN      0
# 270                        Nicola-Yarred, Miss. Jamila  female  14.0      1
# 860                         Cook, Mrs. (Selena Rogers)  female  22.0      0
# 435  Backstrom, Mrs. Karl Alfred (Maria Mathilda Gu...  female  33.0      3
# 102                  Leyson, Mr. Robert William Norman    male  24.0      0
#
#      parch       ticket      fare            cabin embarked
# 380      0       374746    8.0500              NaN        S
# 879      1     PC 17596   29.7000             C118        C
# 355      0        17474   57.0000              B20        S
# 357      2     PC 17608  262.3750  B57 B59 B63 B66        C
# 362      9     CA. 2343   69.5500              NaN        S
# ..     ...          ...       ...              ...      ...
# 106      0         1222    7.8792              NaN        S
# 270      0         2651   11.2417              NaN        C
# 860      0  W./C. 14266   10.5000              F33        S
# 435      0      3101278   15.8500              NaN        S
# 102      0   C.A. 29566   10.5000              NaN        S
#
# [916 rows x 12 columns]

# %% [markdown]
# # 행렬 슬라이싱

# %%
df = pd.read_csv(f"{DATA_PATH}\\titanic_train.csv")
df
# Out:
#      passengerid  survived  pclass                          name  gender  \
# 0            494         0       1       Artagaveytia, Mr. Ramon    male
# 1            462         0       3           Morley, Mr. William    male
# 2           1286         0       3      Kink-Heilmann, Mr. Anton    male
# 3           1130         1       2         Hiltunen, Miss. Marta  female
# 4            461         1       1           Anderson, Mr. Harry    male
# ..           ...       ...     ...                           ...     ...
# 911          738         1       1        Lesurer, Mr. Gustave J    male
# 912          518         0       3             Ryan, Mr. Patrick    male
# 913          664         0       3              Coleff, Mr. Peju    male
# 914          109         0       3               Rekic, Mr. Tido    male
# 915          146         0       2  Nicholls, Mr. Joseph Charles    male
#
#       age  sibsp  parch      ticket      fare cabin embarked
# 0    71.0      0      0    PC 17609   49.5042   NaN        C
# 1    34.0      0      0      364506    8.0500   NaN        S
# 2    29.0      3      1      315153   22.0250   NaN        S
# 3    18.0      1      1      250650   13.0000   NaN        S
# 4    48.0      0      0       19952   26.5500   E12        S
# ..    ...    ...    ...         ...       ...   ...      ...
# 911  35.0      0      0    PC 17755  512.3292  B101        C
# 912   NaN      0      0      371110   24.1500   NaN        Q
# 913  36.0      0      0      349210    7.4958   NaN        S
# 914  38.0      0      0      349249    7.8958   NaN        S
# 915  19.0      1      1  C.A. 33112   36.7500   NaN        S
#
# [916 rows x 12 columns]

# %% [markdown]
# ## iloc
# - 행번호, 열번호를 이용한 슬라이싱

# %%
df.iloc[:4,1:3]
# Out:
#    survived  pclass
# 0         0       1
# 1         0       3
# 2         0       3
# 3         1       2

# %%
index_list = [0,2,3,5]
df.iloc[index_list]
# Out:
#    passengerid  survived  pclass                      name  gender   age  \
# 0          494         0       1   Artagaveytia, Mr. Ramon    male  71.0
# 2         1286         0       3  Kink-Heilmann, Mr. Anton    male  29.0
# 3         1130         1       2     Hiltunen, Miss. Marta  female  18.0
# 5          952         0       3           Dika, Mr. Mirko    male  17.0
#
#    sibsp  parch    ticket     fare cabin embarked
# 0      0      0  PC 17609  49.5042   NaN        C
# 2      3      1    315153  22.0250   NaN        S
# 3      1      1    250650  13.0000   NaN        S
# 5      0      0    349232   7.8958   NaN        S

# %%
df.iloc[:,::-1]
# Out:
#     embarked cabin      fare      ticket  parch  sibsp   age  gender  \
# 0          C   NaN   49.5042    PC 17609      0      0  71.0    male
# 1          S   NaN    8.0500      364506      0      0  34.0    male
# 2          S   NaN   22.0250      315153      1      3  29.0    male
# 3          S   NaN   13.0000      250650      1      1  18.0  female
# 4          S   E12   26.5500       19952      0      0  48.0    male
# ..       ...   ...       ...         ...    ...    ...   ...     ...
# 911        C  B101  512.3292    PC 17755      0      0  35.0    male
# 912        Q   NaN   24.1500      371110      0      0   NaN    male
# 913        S   NaN    7.4958      349210      0      0  36.0    male
# 914        S   NaN    7.8958      349249      0      0  38.0    male
# 915        S   NaN   36.7500  C.A. 33112      1      1  19.0    male
#
#                              name  pclass  survived  passengerid
# 0         Artagaveytia, Mr. Ramon       1         0          494
# 1             Morley, Mr. William       3         0          462
# 2        Kink-Heilmann, Mr. Anton       3         0         1286
# 3           Hiltunen, Miss. Marta       2         1         1130
# 4             Anderson, Mr. Harry       1         1          461
# ..                            ...     ...       ...          ...
# 911        Lesurer, Mr. Gustave J       1         1          738
# 912             Ryan, Mr. Patrick       3         0          518
# 913              Coleff, Mr. Peju       3         0          664
# 914               Rekic, Mr. Tido       3         0          109
# 915  Nicholls, Mr. Joseph Charles       2         0          146
#
# [916 rows x 12 columns]

# %%
display(df.iloc[-1,:])
# Out:
# passengerid                             146
# survived                                  0
# pclass                                    2
# name           Nicholls, Mr. Joseph Charles
# gender                                 male
# age                                    19.0
# sibsp                                     1
# parch                                     1
# ticket                           C.A. 33112
# fare                                  36.75
# cabin                                   NaN
# embarked                                  S
# Name: 915, dtype: object

# %%
df.index[:-1]
# Out:
# RangeIndex(start=0, stop=915, step=1)

# %%
value = df.loc[df.index[:-1], "pclass"]
value
# Out:
# 0      1
# 1      3
# 2      3
# 3      2
# 4      1
#       ..
# 910    3
# 911    1
# 912    3
# 913    3
# 914    3
# Name: pclass, Length: 915, dtype: int64

# %%
df.index[-1]
# Out:
# 915

# %% [markdown]
# ## loc
# - index 명과 column명을 이용한 행렬 선택
# - 마스킹을 이용한 행렬 선택 가능

# %%
df[:100]
# Out:
#     passengerid  survived  pclass                            name  gender  \
# 0           494         0       1         Artagaveytia, Mr. Ramon    male
# 1           462         0       3             Morley, Mr. William    male
# 2          1286         0       3        Kink-Heilmann, Mr. Anton    male
# 3          1130         1       2           Hiltunen, Miss. Marta  female
# 4           461         1       1             Anderson, Mr. Harry    male
# ..          ...       ...     ...                             ...     ...
# 95          266         0       2               Reeves, Mr. David    male
# 96          281         0       3                Duane, Mr. Frank    male
# 97          504         0       3  Laitinen, Miss. Kristina Sofia  female
# 98          576         0       3            Patchett, Mr. George    male
# 99          488         0       1         Kent, Mr. Edward Austin    male
#
#      age  sibsp  parch      ticket     fare cabin embarked
# 0   71.0      0      0    PC 17609  49.5042   NaN        C
# 1   34.0      0      0      364506   8.0500   NaN        S
# 2   29.0      3      1      315153  22.0250   NaN        S
# 3   18.0      1      1      250650  13.0000   NaN        S
# 4   48.0      0      0       19952  26.5500   E12        S
# ..   ...    ...    ...         ...      ...   ...      ...
# 95  36.0      0      0  C.A. 17248  10.5000   NaN        S
# 96  65.0      0      0      336439   7.7500   NaN        Q
# 97  37.0      0      0        4135   9.5875   NaN        S
# 98  19.0      0      0      358585  14.5000   NaN        S
# 99  58.0      0      0       11771  29.7000   B37        C
#
# [100 rows x 12 columns]

# %%
df.loc[:,"pclass"]
# Out:
# 0      1
# 1      3
# 2      3
# 3      2
# 4      1
#       ..
# 911    1
# 912    3
# 913    3
# 914    3
# 915    2
# Name: pclass, Length: 916, dtype: int64

# %%
df.loc[:, :"pclass"] # end 값 포함되서 슬라이싱 됨
# Out:
#      passengerid  survived  pclass
# 0            494         0       1
# 1            462         0       3
# 2           1286         0       3
# 3           1130         1       2
# 4            461         1       1
# ..           ...       ...     ...
# 911          738         1       1
# 912          518         0       3
# 913          664         0       3
# 914          109         0       3
# 915          146         0       2
#
# [916 rows x 3 columns]

# %%
df.loc[:,"pclass"]
# Out:
# 0      1
# 1      3
# 2      3
# 3      2
# 4      1
#       ..
# 911    1
# 912    3
# 913    3
# 914    3
# 915    2
# Name: pclass, Length: 916, dtype: int64

# %%
df.loc[:,["pclass"]]
# Out:
#      pclass
# 0         1
# 1         3
# 2         3
# 3         2
# 4         1
# ..      ...
# 911       1
# 912       3
# 913       3
# 914       3
# 915       2
#
# [916 rows x 1 columns]

# %%
index_list = [458,100,50]
column_list = ["name", "fare"]
df.loc[index_list, column_list]
# Out:
#                               name      fare
# 458              Lingane, Mr. John   12.3500
# 100      Bostandyeff, Mr. Guentcho    7.8958
# 50   Allen, Miss. Elisabeth Walton  211.3375

# %% [markdown]
# - 행번호에 맞게 새로운 인덱스 생성하기

# %%
df.reset_index(drop=True) #drop=True: 기존 인덱스가 삭제되고 새로운 정수 인덱스가 생성됩니다.
# Out:
#      passengerid  survived  pclass                          name  gender  \
# 0            494         0       1       Artagaveytia, Mr. Ramon    male
# 1            462         0       3           Morley, Mr. William    male
# 2           1286         0       3      Kink-Heilmann, Mr. Anton    male
# 3           1130         1       2         Hiltunen, Miss. Marta  female
# 4            461         1       1           Anderson, Mr. Harry    male
# ..           ...       ...     ...                           ...     ...
# 911          738         1       1        Lesurer, Mr. Gustave J    male
# 912          518         0       3             Ryan, Mr. Patrick    male
# 913          664         0       3              Coleff, Mr. Peju    male
# 914          109         0       3               Rekic, Mr. Tido    male
# 915          146         0       2  Nicholls, Mr. Joseph Charles    male
#
#       age  sibsp  parch      ticket      fare cabin embarked
# 0    71.0      0      0    PC 17609   49.5042   NaN        C
# 1    34.0      0      0      364506    8.0500   NaN        S
# 2    29.0      3      1      315153   22.0250   NaN        S
# 3    18.0      1      1      250650   13.0000   NaN        S
# 4    48.0      0      0       19952   26.5500   E12        S
# ..    ...    ...    ...         ...       ...   ...      ...
# 911  35.0      0      0    PC 17755  512.3292  B101        C
# 912   NaN      0      0      371110   24.1500   NaN        Q
# 913  36.0      0      0      349210    7.4958   NaN        S
# 914  38.0      0      0      349249    7.8958   NaN        S
# 915  19.0      1      1  C.A. 33112   36.7500   NaN        S
#
# [916 rows x 12 columns]

# %% [markdown]
# - 마스킹 해보기

# %%
mask = df["survived"] > 0 # 생존자만 찾기
mask
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 911     True
# 912    False
# 913    False
# 914    False
# 915    False
# Name: survived, Length: 916, dtype: bool

# %%
df.loc[mask]
# Out:
#      passengerid  survived  pclass  \
# 3           1130         1       2
# 4            461         1       1
# 7            331         1       3
# 11            18         1       2
# 13           802         1       2
# ..           ...       ...     ...
# 905          982         1       3
# 906          339         1       3
# 907          225         1       1
# 908          377         1       3
# 911          738         1       1
#
#                                                   name  gender   age  sibsp  \
# 3                                Hiltunen, Miss. Marta  female  18.0      1
# 4                                  Anderson, Mr. Harry    male  48.0      0
# 7                                   McCoy, Miss. Agnes  female   NaN      2
# 11                        Williams, Mr. Charles Eugene    male   NaN      0
# 13         Collyer, Mrs. Harvey (Charlotte Annie Tate)  female  31.0      1
# ..                                                 ...     ...   ...    ...
# 905  Dyker, Mrs. Adolf Fredrik (Anna Elisabeth Judi...  female  22.0      1
# 906                              Dahl, Mr. Karl Edwart    male  45.0      0
# 907                       Hoyt, Mr. Frederick Maxfield    male  38.0      1
# 908                    Landergren, Miss. Aurora Adelia  female  22.0      0
# 911                             Lesurer, Mr. Gustave J    male  35.0      0
#
#      parch      ticket      fare cabin embarked
# 3        1      250650   13.0000   NaN        S
# 4        0       19952   26.5500   E12        S
# 7        0      367226   23.2500   NaN        Q
# 11       0      244373   13.0000   NaN        S
# 13       1  C.A. 31921   26.2500   NaN        S
# ..     ...         ...       ...   ...      ...
# 905      0      347072   13.9000   NaN        S
# 906      0        7598    8.0500   NaN        S
# 907      0       19943   90.0000   C93        S
# 908      0      C 7077    7.2500   NaN        S
# 911      0    PC 17755  512.3292  B101        C
#
# [346 rows x 12 columns]

# %%
mask = df["pclass"] == 1
df.loc[mask]
# Out:
#      passengerid  survived  pclass                                  name  \
# 0            494         0       1               Artagaveytia, Mr. Ramon
# 4            461         1       1                   Anderson, Mr. Harry
# 9            119         0       1              Baxter, Mr. Quigg Edmond
# 14           914         1       1  Flegenheim, Mrs. Alfred (Antoinette)
# 15          1215         0       1                    Rowe, Mr. Alfred G
# ..           ...       ...     ...                                   ...
# 888          642         1       1                  Sagesser, Mlle. Emma
# 897          458         1       1     Kenyon, Mrs. Frederick R (Marion)
# 899          497         1       1        Eustis, Miss. Elizabeth Mussey
# 907          225         1       1          Hoyt, Mr. Frederick Maxfield
# 911          738         1       1                Lesurer, Mr. Gustave J
#
#      gender   age  sibsp  parch    ticket      fare    cabin embarked
# 0      male  71.0      0      0  PC 17609   49.5042      NaN        C
# 4      male  48.0      0      0     19952   26.5500      E12        S
# 9      male  24.0      0      1  PC 17558  247.5208  B58 B60        C
# 14   female   NaN      0      0  PC 17598   31.6833      NaN        S
# 15     male  33.0      0      0    113790   26.5500      NaN        S
# ..      ...   ...    ...    ...       ...       ...      ...      ...
# 888  female  24.0      0      0  PC 17477   69.3000      B35        C
# 897  female   NaN      1      0     17464   51.8625      D21        S
# 899  female  54.0      1      0     36947   78.2667      D20        C
# 907    male  38.0      1      0     19943   90.0000      C93        S
# 911    male  35.0      0      0  PC 17755  512.3292     B101        C
#
# [230 rows x 12 columns]

# %% [markdown]
# # 다중 조건을 주어 마스킹
# - DataFrame또는 numpy배열에 대하여 bool에 대한 논리 연산자를 지원하지 않는다.
# - DataFrame또는 numpy배열에 대하여 bool에 대한 연산은 비트 연산자를 사용하면 된다.
# - `and` 대신 `&`: 둘다 True이면 True 아니면 False
# - `or` 대신 `|`: 둘중에 하나라도 True면 True 아니면 False
# - `not` 대신 `~`: True 면 False, False 면 True

# %%
# 생존자 이면서 나이가 20세 미만
mask = (df["survived"] > 0) & (df["age"] < 20)
df.loc[mask]
# Out:
#      passengerid  survived  pclass  \
# 3           1130         1       2
# 30          1175         1       3
# 45           701         1       1
# 55          1095         1       2
# 72           979         1       3
# ..           ...       ...     ...
# 859           85         1       2
# 867          856         1       3
# 874          692         1       3
# 889          531         1       2
# 900          227         1       2
#
#                                                   name  gender   age  sibsp  \
# 3                                Hiltunen, Miss. Marta  female  18.0      1
# 30                          Touma, Miss. Maria Youssef  female   9.0      1
# 45   Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.0      1
# 55                          Quick, Miss. Winifred Vera  female   8.0      1
# 72                          Badman, Miss. Emily Louisa  female  18.0      0
# ..                                                 ...     ...   ...    ...
# 859                                Ilett, Miss. Bertha  female  17.0      0
# 867                         Aks, Mrs. Sam (Leah Rosen)  female  18.0      0
# 874                                 Karun, Miss. Manca  female   4.0      0
# 889                           Quick, Miss. Phyllis May  female   2.0      1
# 900                          Mellors, Mr. William John    male  19.0      0
#
#      parch      ticket      fare    cabin embarked
# 3        1      250650   13.0000      NaN        S
# 30       1        2650   15.2458      NaN        C
# 45       0    PC 17757  227.5250  C62 C64        C
# 55       1       26360   26.0000      NaN        S
# 72       0   A/4 31416    8.0500      NaN        S
# ..     ...         ...       ...      ...      ...
# 859      0  SO/C 14885   10.5000      NaN        S
# 867      1      392091    9.3500      NaN        S
# 874      1      349256   13.4167      NaN        C
# 889      1       26360   26.0000      NaN        S
# 900      0   SW/PP 751   10.5000      NaN        S
#
# [73 rows x 12 columns]

# %%
mask1 = df["survived"] > 0
mask2 = df["age"] < 20
df.loc[mask1 | mask2]
# Out:
#      passengerid  survived  pclass                                name  \
# 3           1130         1       2               Hiltunen, Miss. Marta
# 4            461         1       1                 Anderson, Mr. Harry
# 5            952         0       3                     Dika, Mr. Mirko
# 7            331         1       3                  McCoy, Miss. Agnes
# 8            814         0       3  Andersson, Miss. Ebba Iris Alfrida
# ..           ...       ...     ...                                 ...
# 907          225         1       1        Hoyt, Mr. Frederick Maxfield
# 908          377         1       3     Landergren, Miss. Aurora Adelia
# 909         1086         0       2       Drew, Master. Marshall Brines
# 911          738         1       1              Lesurer, Mr. Gustave J
# 915          146         0       2        Nicholls, Mr. Joseph Charles
#
#      gender   age  sibsp  parch      ticket      fare cabin embarked
# 3    female  18.0      1      1      250650   13.0000   NaN        S
# 4      male  48.0      0      0       19952   26.5500   E12        S
# 5      male  17.0      0      0      349232    7.8958   NaN        S
# 7    female   NaN      2      0      367226   23.2500   NaN        Q
# 8    female   6.0      4      2      347082   31.2750   NaN        S
# ..      ...   ...    ...    ...         ...       ...   ...      ...
# 907    male  38.0      1      0       19943   90.0000   C93        S
# 908  female  22.0      0      0      C 7077    7.2500   NaN        S
# 909    male   8.0      0      2       28220   32.5000   NaN        S
# 911    male  35.0      0      0    PC 17755  512.3292  B101        C
# 915    male  19.0      1      1  C.A. 33112   36.7500   NaN        S
#
# [431 rows x 12 columns]

# %%
mask1 = df["survived"] > 0
mask2 = df["age"] < 20
df.loc[mask1 | mask2,["pclass","parch"]]
# Out:
#      pclass  parch
# 3         2      1
# 4         1      0
# 5         3      0
# 7         3      0
# 8         3      2
# ..      ...    ...
# 907       1      0
# 908       3      0
# 909       2      2
# 911       1      0
# 915       2      1
#
# [431 rows x 2 columns]

# %%
df.loc[~mask1]
# Out:
#      passengerid  survived  pclass                          name  gender  \
# 0            494         0       1       Artagaveytia, Mr. Ramon    male
# 1            462         0       3           Morley, Mr. William    male
# 2           1286         0       3      Kink-Heilmann, Mr. Anton    male
# 5            952         0       3               Dika, Mr. Mirko    male
# 6            130         0       3            Ekstrom, Mr. Johan    male
# ..           ...       ...     ...                           ...     ...
# 910          535         0       3           Cacic, Miss. Marija  female
# 912          518         0       3             Ryan, Mr. Patrick    male
# 913          664         0       3              Coleff, Mr. Peju    male
# 914          109         0       3               Rekic, Mr. Tido    male
# 915          146         0       2  Nicholls, Mr. Joseph Charles    male
#
#       age  sibsp  parch      ticket     fare cabin embarked
# 0    71.0      0      0    PC 17609  49.5042   NaN        C
# 1    34.0      0      0      364506   8.0500   NaN        S
# 2    29.0      3      1      315153  22.0250   NaN        S
# 5    17.0      0      0      349232   7.8958   NaN        S
# 6    45.0      0      0      347061   6.9750   NaN        S
# ..    ...    ...    ...         ...      ...   ...      ...
# 910  30.0      0      0      315084   8.6625   NaN        S
# 912   NaN      0      0      371110  24.1500   NaN        Q
# 913  36.0      0      0      349210   7.4958   NaN        S
# 914  38.0      0      0      349249   7.8958   NaN        S
# 915  19.0      1      1  C.A. 33112  36.7500   NaN        S
#
# [570 rows x 12 columns]

# %% [markdown]
# # 데이터 형식에 기반한 컬럼 선택

# %%
df.select_dtypes("float64")
# Out:
#       age      fare
# 0    71.0   49.5042
# 1    34.0    8.0500
# 2    29.0   22.0250
# 3    18.0   13.0000
# 4    48.0   26.5500
# ..    ...       ...
# 911  35.0  512.3292
# 912   NaN   24.1500
# 913  36.0    7.4958
# 914  38.0    7.8958
# 915  19.0   36.7500
#
# [916 rows x 2 columns]

# %%
df.select_dtypes(["float64", "int64"])
# Out:
#      passengerid  survived  pclass   age  sibsp  parch      fare
# 0            494         0       1  71.0      0      0   49.5042
# 1            462         0       3  34.0      0      0    8.0500
# 2           1286         0       3  29.0      3      1   22.0250
# 3           1130         1       2  18.0      1      1   13.0000
# 4            461         1       1  48.0      0      0   26.5500
# ..           ...       ...     ...   ...    ...    ...       ...
# 911          738         1       1  35.0      0      0  512.3292
# 912          518         0       3   NaN      0      0   24.1500
# 913          664         0       3  36.0      0      0    7.4958
# 914          109         0       3  38.0      0      0    7.8958
# 915          146         0       2  19.0      1      1   36.7500
#
# [916 rows x 7 columns]

# %%
df.select_dtypes("number")
# Out:
#      passengerid  survived  pclass   age  sibsp  parch      fare
# 0            494         0       1  71.0      0      0   49.5042
# 1            462         0       3  34.0      0      0    8.0500
# 2           1286         0       3  29.0      3      1   22.0250
# 3           1130         1       2  18.0      1      1   13.0000
# 4            461         1       1  48.0      0      0   26.5500
# ..           ...       ...     ...   ...    ...    ...       ...
# 911          738         1       1  35.0      0      0  512.3292
# 912          518         0       3   NaN      0      0   24.1500
# 913          664         0       3  36.0      0      0    7.4958
# 914          109         0       3  38.0      0      0    7.8958
# 915          146         0       2  19.0      1      1   36.7500
#
# [916 rows x 7 columns]

# %%
df.select_dtypes("object")
# Out:
#                              name  gender      ticket cabin embarked
# 0         Artagaveytia, Mr. Ramon    male    PC 17609   NaN        C
# 1             Morley, Mr. William    male      364506   NaN        S
# 2        Kink-Heilmann, Mr. Anton    male      315153   NaN        S
# 3           Hiltunen, Miss. Marta  female      250650   NaN        S
# 4             Anderson, Mr. Harry    male       19952   E12        S
# ..                            ...     ...         ...   ...      ...
# 911        Lesurer, Mr. Gustave J    male    PC 17755  B101        C
# 912             Ryan, Mr. Patrick    male      371110   NaN        Q
# 913              Coleff, Mr. Peju    male      349210   NaN        S
# 914               Rekic, Mr. Tido    male      349249   NaN        S
# 915  Nicholls, Mr. Joseph Charles    male  C.A. 33112   NaN        S
#
# [916 rows x 5 columns]

# %% [markdown]
# # 그동안 배운 문자열 간의 연산과 수치 간의 연산들이 Series 단위로 지원 된다.

# %%
df["가족수"] = df["sibsp"] +  df["parch"]
df
# Out:
#      passengerid  survived  pclass                          name  gender  \
# 0            494         0       1       Artagaveytia, Mr. Ramon    male
# 1            462         0       3           Morley, Mr. William    male
# 2           1286         0       3      Kink-Heilmann, Mr. Anton    male
# 3           1130         1       2         Hiltunen, Miss. Marta  female
# 4            461         1       1           Anderson, Mr. Harry    male
# ..           ...       ...     ...                           ...     ...
# 911          738         1       1        Lesurer, Mr. Gustave J    male
# 912          518         0       3             Ryan, Mr. Patrick    male
# 913          664         0       3              Coleff, Mr. Peju    male
# 914          109         0       3               Rekic, Mr. Tido    male
# 915          146         0       2  Nicholls, Mr. Joseph Charles    male
#
#       age  sibsp  parch      ticket      fare cabin embarked  가족수
# 0    71.0      0      0    PC 17609   49.5042   NaN        C    0
# 1    34.0      0      0      364506    8.0500   NaN        S    0
# 2    29.0      3      1      315153   22.0250   NaN        S    4
# 3    18.0      1      1      250650   13.0000   NaN        S    2
# 4    48.0      0      0       19952   26.5500   E12        S    0
# ..    ...    ...    ...         ...       ...   ...      ...  ...
# 911  35.0      0      0    PC 17755  512.3292  B101        C    0
# 912   NaN      0      0      371110   24.1500   NaN        Q    0
# 913  36.0      0      0      349210    7.4958   NaN        S    0
# 914  38.0      0      0      349249    7.8958   NaN        S    0
# 915  19.0      1      1  C.A. 33112   36.7500   NaN        S    2
#
# [916 rows x 13 columns]

# %%
df["gender"] + "_" + df["name"]
# Out:
# 0           male_Artagaveytia, Mr. Ramon
# 1               male_Morley, Mr. William
# 2          male_Kink-Heilmann, Mr. Anton
# 3           female_Hiltunen, Miss. Marta
# 4               male_Anderson, Mr. Harry
#                      ...
# 911          male_Lesurer, Mr. Gustave J
# 912               male_Ryan, Mr. Patrick
# 913                male_Coleff, Mr. Peju
# 914                 male_Rekic, Mr. Tido
# 915    male_Nicholls, Mr. Joseph Charles
# Length: 916, dtype: object

# %%
replace_dict = {"male":1, "female":0}

# %%
df[["gender"]]
# Out:
#      gender
# 0      male
# 1      male
# 2      male
# 3    female
# 4      male
# ..      ...
# 911    male
# 912    male
# 913    male
# 914    male
# 915    male
#
# [916 rows x 1 columns]

# %%
df["gender"]
# Out:
# 0        male
# 1        male
# 2        male
# 3      female
# 4        male
#         ...
# 911      male
# 912      male
# 913      male
# 914      male
# 915      male
# Name: gender, Length: 916, dtype: object

# %%
df["gender"].map(lambda x : 1 if x == "male" else 0 )
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 911    1
# 912    1
# 913    1
# 914    1
# 915    1
# Name: gender, Length: 916, dtype: int64

# %%
df["gender"]
# Out:
# 0        male
# 1        male
# 2        male
# 3      female
# 4        male
#         ...
# 911      male
# 912      male
# 913      male
# 914      male
# 915      male
# Name: gender, Length: 916, dtype: object

# %%
df.loc[:,["gender","name"]]
# Out:
#      gender                          name
# 0      male       Artagaveytia, Mr. Ramon
# 1      male           Morley, Mr. William
# 2      male      Kink-Heilmann, Mr. Anton
# 3    female         Hiltunen, Miss. Marta
# 4      male           Anderson, Mr. Harry
# ..      ...                           ...
# 911    male        Lesurer, Mr. Gustave J
# 912    male             Ryan, Mr. Patrick
# 913    male              Coleff, Mr. Peju
# 914    male               Rekic, Mr. Tido
# 915    male  Nicholls, Mr. Joseph Charles
#
# [916 rows x 2 columns]
